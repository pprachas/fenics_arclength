# %% [markdown]
# # Bilayer Wrinkling
#
# The problem provided in this example is a bilayer wrinkling problem. The domain is a thin stiff film resting on top of a substrate. A small point-force perturbation is applied to the substrate to instigate the instability. The domain is compressed well after the onset of instability.
#
# <img src="imgs/bilayer.png" width="700">

# %%
# %matplotlib inline
from dolfin import *
from mshr import *
import numpy as np
import matplotlib.pyplot as plt
import os
os.chdir('../..') # change directory to main module directory
from arc_length.displacement_control_solver import displacement_control # import displacement control formulation of arc-length solver


parameters["form_compiler"]["cpp_optimize"] = True
ffc_options = {"optimize": True, \
               "eliminate_zeros": True, \
               "precompute_basis_const": True, \
               "precompute_ip_const": True}

# %% [markdown]
# ## Define domain and function spaces
#
# We also split the domain into substrate and film. We To make sure all the assumptions of a bilayer system are valid, we construct the doamin width and depth based on the analytical wavelength.

# %%
# Stiffness ratio
SR = 100

# Elasticity parameters (Plane strain assumptions)
E, nu = 10.0, 0.45
# Lame Constants
mu_f, lmbda_f = Constant(SR*E/(2*(1 + nu))), Constant(SR*E*nu/((1 + nu)*(1 - 2*nu)))
mu_s, lmbda_s = Constant(E/(2*(1 + nu))), Constant(E*nu/((1 + nu)*(1 - 2*nu)))
# define mesh based on analytical wavelength
Hf = 1.0 # film height
ana_wavelength = float(2*np.pi*Hf*((mu_f)/(3*mu_s))**(1/3))
Hs = ana_wavelength*4.0
L = ana_wavelength*3 # length of the domain
SR = 100 # stiffness ratio
d = Hf/2 # mesh size

nx = int(L/d)
ny = int((Hs+Hf)/d)
mesh = RectangleMesh(Point(0,0), Point(L,Hs+Hf), nx, ny, "right")
V = VectorFunctionSpace(mesh, "Lagrange", 2)
plt.figure(figsize=(7,7))
plot(mesh)
# Out:
# [<matplotlib.lines.Line2D at 0x7f4de52fd730>,
#  <matplotlib.lines.Line2D at 0x7f4de52fdbe0>]

# %%
# Define Variational Form
du = TrialFunction(V)            # Incremental displacement
v  = TestFunction(V)             # Test function
u = Function(V)                 # Solution

# Mark boundary subdomians
domain_markers = MeshFunction("size_t", mesh, mesh.topology().dim())
boundary_markers = MeshFunction("size_t", mesh, mesh.topology().dim()-1)

def Film(x, on_boundary):
    return x[1] >= Hs
    
def Substrate(x, on_boundary):
    return x[1] < Hs
    

AutoSubDomain(Film).mark(domain_markers,0)
AutoSubDomain(Substrate).mark(domain_markers,1)

# Check Domain
plt.figure(figsize=(7,7))
plt.title('Domain')
plot(domain_markers)

# %% [markdown]
# ## Define Dirichlet Boundary Conditions
#
# **Note that for the case of displacement control, the FEniCS expression for the applied displacement mujst have be positive to prevent convergence issues.**
#
# For example:
#
# ```
# apply_disp = Expression("t", t = 0.0, degree = 0)
# ```
# is valid and will not have convergence issues while
# ```
# apply_disp = Expression("-t", t = 0.0, degree = 0)
# ```
# can cause convergence issues.
#
# The direction of applied loading will be determined by the initial load step.

# %%
# Dirichlet boundary conditions
def Left(x, on_boundary):
    return on_boundary and near(x[0], 0, 1e-6)

def Right(x, on_boundary):
    return on_boundary and near(x[0], L, 1e-6 )

def Bottom(x, on_boundary):
        return on_boundary and near(x[1], 0, 1e-6)

#-----------------Applied Displacement-----------------------#
apply_disp = Expression("t",t = 0.0, degree = 0) 
#--------------Nonhomogenous Dirichlet Boundary Conditions------------------------------#
bc1 = DirichletBC(V.sub(0), Constant(0), Left)
bc2 = DirichletBC(V.sub(0), apply_disp, Right)
bc3 = DirichletBC(V.sub(1), Constant(0), Bottom)
bcs = [bc1, bc2, bc3]

# %% [markdown]
# ## Define Function for Point Load
# Note that this is an approximation of a point load since the FEniCS UserExpression will be projected into a discontinuous space. To approach a point load the area near the point load will need to have fine mesh. In our case it is not neccessary since the point load is just a perturbation.

# %%
# Function for Point 
class PointLoad(UserExpression):
    def __init__(self, x0, f, tol,**kwargs):
        super().__init__(**kwargs)
        self.x0 = x0
        self.f = f
        self.tol = tol
    def eval(self, values, x):
        if near (x[0], self.x0[0],self.tol) and near(x[1], self.x0[1],self.tol):
            values[0] = self.f[0]
            values[1] = self.f[1]
        else:
            values[0] = 0
            values[1] = 0
    def value_shape(self):
        return (2,)

# %% [markdown]
# ## Kinematics and Weak form

# %%
# Kinematics
I = variable(Identity(mesh.topology().dim()))  # Identity tensor
F = variable(I + grad(u))                        # Deformation gradient
C = variable(F.T*F)                              # Right Cauchy-Green tensor

# Invariants of deformation tensors
Ic = tr(C)
J  = det(F)

# %%
# Define Variational Form
dx = Measure('dx', domain=mesh, subdomain_data=domain_markers)

# Stored strain energy density (compressible neo-Hookean model)
psi_f = (mu_f/2)*(Ic - 2) - mu_f*ln(J) + (lmbda_f/2)*(ln(J))**2
psi_s = (mu_s/2)*(Ic - 2) - mu_s*ln(J) + (lmbda_s/2)*(ln(J))**2

# Applied Traction and Body Force
pert = 8e-2
T = Constant((0,0)) # Traction
B = Constant((0,0)) # Body Force
P = PointLoad(x0 = [L/2,Hf+Hs], f = [0,pert], tol = 1e-4, degree = 0, element=V.ufl_element()) # Point load

F_int = derivative(psi_f*dx(0) + psi_s*dx(1), u, v)
F_ext = derivative(dot(B, u)*dx + dot(T,u)*ds + dot(-P,u)*ds , u, v)
residual = F_int-F_ext
J = derivative(residual, u, du)

# %% [markdown]
# ## Solver
# To use our solver we first have to define the type of solver (i.e. displacement control or force control) and solver parameters before using the solver. Note that the correct type of solver has to first be imported (see first cell).
# ### Solver parameters
# Here the parameters for both types of solvers:
#
# >* `psi` : the scalar arc-legth parameter. When `psi` = 1, the method becomes the shperical arc-length method and when `psi` = 0 the method becomes the cylindrical arc-length method
# >* `tol` : tolerance for the linear solver
# >* `lmbda0` : the initial load parameter
# >* `max_iter` : maximum number of iterations for the linear solver
# >* `solver` : (optional): type of linear solver for the FEniCS linear solve function -- default FEniCS linear solver is used if no argument is used.
#
# Aside from these solver parameters, the arguments need to solve the FEA problem must also be passed into the solver:
# >* `u` : the solution function
# >* `F_int` : First variation of strain energy (internal nodal forces)
# >* `F_ext` : Externally applied load (external applied force)
# >* `J` : The Jacobian of the residual with respect to the deformation (tangential stiffness matrix)
# >* `displacement_factor` : The incremental load factor
#
# The solver can be called by:
# `solver = force_control(psi,tol,lmbda0,max_iter,u,F_int,F_ext,bcs,J,load_factor,solver)`
#
# ### Using the solver
# 1. Initialize the solver by calling solver.initialize()
# 2. Iteratively call solver.solve() until desired stopping condition

# %%
# Solver Parameters
psi = 1.0
tol = 1.0e-6
lmbda0 = -0.07
max_iter = 30

# Set up arc-length solver
solver = displacement_control(psi=psi, tol=tol, lmbda0=lmbda0, max_iter=max_iter, u=u,
                       F_int=F_int, F_ext=F_ext, bcs=bcs, J=J, displacement_factor=apply_disp)

# %%
disp = [u.vector().copy()]
lmbda = [0]
# Function space to compute reaction force at each iteration
v_reac = Function(V)
bcRx = DirichletBC(V.sub(0), Constant(1.0), Left) # take reaction force from the left boundary
f_reac = [0.0]

strain_crit = float((1/3)*((3*mu_s/mu_f))**(2/3))# critial strain
while np.abs(apply_disp.t) < strain_crit*L*1.2 and solver.converged:
    solver.solve()
    if solver.converged:
        # Store whole displacement field
        disp.append(u.vector().copy())
        # Store displacement factor
        lmbda.append(apply_disp.t)
        # Compute and store reaction force
        bcRx.apply(v_reac.vector())
        f_reac.append(assemble(action(residual,v_reac)))
# Out:
# Initializing solver parameters...
# Starting initial Displacement Control Control with Newton Method:
# Iteration 0:
# Residual error: 1.1603e+03
# Iteration 1:
# Residual error: 8.5740e+02
# Iteration 2:
# Residual error: 1.7790e+02
# Iteration 3:
# Residual error: 1.3741e+02
# Iteration 4:
# Residual error: 1.0448e+01
# Iteration 5:
# Residual error: 1.3875e-01
# Iteration 6:
# Residual error: 2.1193e-04
# Iteration 7:
# Residual error: 2.8422e-11
#
# Arc-Length Step 1 :
# Iteration: 1
# |Total Norm: 1.1983e-10 |Residual Norm: 2.8422e-11 |A: -1.1642e-10|
#
# Arc-Length Step 2 :
# Iteration: 1
# |Total Norm: 2.1232e+03 |Residual Norm: 4.2808e-02 |A: 2.1232e+03|
# Iteration: 2
# |Total Norm: 3.1557e+00 |Residual Norm: 8.1457e-04 |A: -3.1557e+00|
# Iteration: 3
# |Total Norm: 1.4395e-02 |Residual Norm: 1.2101e-10 |A: -1.4395e-02|
# Iteration: 4
# |Total Norm: 2.8894e-05 |Residual Norm: 5.2584e-12 |A: 2.8894e-05|
# Iteration: 5
# |Total Norm: 5.8557e-08 |Residual Norm: 5.1599e-12 |A: -5.8557e-08|
#
# Arc-Length Step 3 :
# Iteration: 1
# |Total Norm: 2.1234e+03 |Residual Norm: 3.6197e-02 |A: 2.1234e+03|
# Iteration: 2
# |Total Norm: 3.5900e+00 |Residual Norm: 4.2396e-08 |A: -3.5900e+00|
# Iteration: 3
# |Total Norm: 7.2107e-03 |Residual Norm: 6.3813e-12 |A: 7.2107e-03|
# Iteration: 4
# |Total Norm: 1.4475e-05 |Residual Norm: 6.3625e-12 |A: -1.4475e-05|
# Iteration: 5
# |Total Norm: 2.8755e-08 |Residual Norm: 6.1247e-12 |A: 2.8755e-08|
#
# Arc-Length Step 4 :
# Iteration: 1
# |Total Norm: 2.1233e+03 |Residual Norm: 3.6085e-02 |A: 2.1233e+03|
# Iteration: 2
# |Total Norm: 3.5862e+00 |Residual Norm: 4.4007e-08 |A: -3.5862e+00|
# Iteration: 3
# |Total Norm: 7.2025e-03 |Residual Norm: 9.8461e-12 |A: 7.2025e-03|
# Iteration: 4
# |Total Norm: 1.4458e-05 |Residual Norm: 1.0203e-11 |A: -1.4458e-05|
# Iteration: 5
# |Total Norm: 2.8871e-08 |Residual Norm: 1.0209e-11 |A: 2.8871e-08|
#
# Arc-Length Step 5 :
# Iteration: 1
# |Total Norm: 2.1232e+03 |Residual Norm: 3.5975e-02 |A: 2.1232e+03|
# Iteration: 2
# |Total Norm: 3.5823e+00 |Residual Norm: 4.6964e-08 |A: -3.5823e+00|
# Iteration: 3
# |Total Norm: 7.1942e-03 |Residual Norm: 1.1300e-11 |A: 7.1942e-03|
# Iteration: 4
# |Total Norm: 1.4441e-05 |Residual Norm: 1.1008e-11 |A: -1.4441e-05|
# Iteration: 5
# |Total Norm: 2.9220e-08 |Residual Norm: 1.0796e-11 |A: 2.9220e-08|
#
# Arc-Length Step 6 :
# Iteration: 1
# |Total Norm: 2.1231e+03 |Residual Norm: 3.5864e-02 |A: 2.1231e+03|
# Iteration: 2
# |Total Norm: 3.5784e+00 |Residual Norm: 5.2303e-08 |A: -3.5784e+00|
# Iteration: 3
# |Total Norm: 7.1859e-03 |Residual Norm: 1.2426e-11 |A: 7.1859e-03|
# Iteration: 4
# |Total Norm: 1.4424e-05 |Residual Norm: 1.1474e-11 |A: -1.4424e-05|
# Iteration: 5
# |Total Norm: 2.8755e-08 |Residual Norm: 1.2109e-11 |A: 2.8755e-08|
#
# Arc-Length Step 7 :
# Iteration: 1
# |Total Norm: 2.1230e+03 |Residual Norm: 3.5753e-02 |A: 2.1230e+03|
# Iteration: 2
# |Total Norm: 3.5746e+00 |Residual Norm: 6.1754e-08 |A: -3.5746e+00|
# Iteration: 3
# |Total Norm: 7.1776e-03 |Residual Norm: 1.7862e-11 |A: 7.1776e-03|
# Iteration: 4
# |Total Norm: 1.4407e-05 |Residual Norm: 1.7242e-11 |A: -1.4407e-05|
# Iteration: 5
# |Total Norm: 2.9220e-08 |Residual Norm: 1.7267e-11 |A: 2.9220e-08|
#
# Arc-Length Step 8 :
# Iteration: 1
# |Total Norm: 2.1229e+03 |Residual Norm: 3.5643e-02 |A: 2.1229e+03|
# Iteration: 2
# |Total Norm: 3.5707e+00 |Residual Norm: 7.8105e-08 |A: -3.5707e+00|
# Iteration: 3
# |Total Norm: 7.1691e-03 |Residual Norm: 1.9738e-11 |A: 7.1691e-03|
# Iteration: 4
# |Total Norm: 1.4387e-05 |Residual Norm: 1.9871e-11 |A: -1.4387e-05|
# Iteration: 5
# |Total Norm: 2.8638e-08 |Residual Norm: 2.0604e-11 |A: 2.8638e-08|
#
# Arc-Length Step 9 :
# Iteration: 1
# |Total Norm: 2.1228e+03 |Residual Norm: 3.5533e-02 |A: 2.1228e+03|
# Iteration: 2
# |Total Norm: 3.5670e+00 |Residual Norm: 1.0585e-07 |A: -3.5670e+00|
# Iteration: 3
# |Total Norm: 7.1607e-03 |Residual Norm: 2.1370e-11 |A: 7.1607e-03|
# Iteration: 4
# |Total Norm: 1.4369e-05 |Residual Norm: 2.1032e-11 |A: -1.4369e-05|
# Iteration: 5
# |Total Norm: 2.8987e-08 |Residual Norm: 2.1706e-11 |A: 2.8987e-08|
#
# Arc-Length Step 10 :
# Iteration: 1
# |Total Norm: 2.1226e+03 |Residual Norm: 3.5422e-02 |A: 2.1226e+03|
# Iteration: 2
# |Total Norm: 3.5633e+00 |Residual Norm: 1.5262e-07 |A: -3.5633e+00|
# Iteration: 3
# |Total Norm: 7.1522e-03 |Residual Norm: 2.1712e-11 |A: 7.1522e-03|
# Iteration: 4
# |Total Norm: 1.4352e-05 |Residual Norm: 2.0836e-11 |A: -1.4352e-05|
# Iteration: 5
# |Total Norm: 2.8056e-08 |Residual Norm: 2.2356e-11 |A: 2.8056e-08|
#
# Arc-Length Step 11 :
# Iteration: 1
# |Total Norm: 2.1225e+03 |Residual Norm: 3.5312e-02 |A: 2.1225e+03|
# Iteration: 2
# |Total Norm: 3.5599e+00 |Residual Norm: 2.3238e-07 |A: -3.5599e+00|
# Iteration: 3
# |Total Norm: 7.1440e-03 |Residual Norm: 2.4298e-11 |A: 7.1440e-03|
# Iteration: 4
# |Total Norm: 1.4334e-05 |Residual Norm: 2.2429e-11 |A: -1.4334e-05|
# Iteration: 5
# |Total Norm: 2.9104e-08 |Residual Norm: 2.2049e-11 |A: 2.9104e-08|
#
# Arc-Length Step 12 :
# Iteration: 1
# |Total Norm: 2.1223e+03 |Residual Norm: 3.5200e-02 |A: 2.1223e+03|
# Iteration: 2
# |Total Norm: 3.5569e+00 |Residual Norm: 3.7247e-07 |A: -3.5569e+00|
# Iteration: 3
# |Total Norm: 7.1361e-03 |Residual Norm: 2.2757e-11 |A: 7.1361e-03|
# Iteration: 4
# |Total Norm: 1.4317e-05 |Residual Norm: 2.3018e-11 |A: -1.4317e-05|
# Iteration: 5
# |Total Norm: 3.0152e-08 |Residual Norm: 2.3046e-11 |A: 3.0152e-08|
#
# Arc-Length Step 13 :
# Iteration: 1
# |Total Norm: 2.1222e+03 |Residual Norm: 3.5088e-02 |A: 2.1222e+03|
# Iteration: 2
# |Total Norm: 3.5548e+00 |Residual Norm: 6.2993e-07 |A: -3.5548e+00|
# Iteration: 3
# |Total Norm: 7.1290e-03 |Residual Norm: 2.8699e-11 |A: 7.1290e-03|
# Iteration: 4
# |Total Norm: 1.4301e-05 |Residual Norm: 2.8416e-11 |A: -1.4301e-05|
# Iteration: 5
# |Total Norm: 2.7358e-08 |Residual Norm: 2.7954e-11 |A: 2.7358e-08|
#
# Arc-Length Step 14 :
# Iteration: 1
# |Total Norm: 2.1220e+03 |Residual Norm: 3.4973e-02 |A: 2.1220e+03|
# Iteration: 2
# |Total Norm: 3.5545e+00 |Residual Norm: 1.1330e-06 |A: -3.5545e+00|
# Iteration: 3
# |Total Norm: 7.1236e-03 |Residual Norm: 3.5162e-11 |A: 7.1236e-03|
# Iteration: 4
# |Total Norm: 1.4290e-05 |Residual Norm: 3.3946e-11 |A: -1.4290e-05|
# Iteration: 5
# |Total Norm: 2.9337e-08 |Residual Norm: 3.5972e-11 |A: 2.9337e-08|
#
# Arc-Length Step 15 :
# Iteration: 1
# |Total Norm: 2.1218e+03 |Residual Norm: 3.4855e-02 |A: 2.1218e+03|
# Iteration: 2
# |Total Norm: 3.5579e+00 |Residual Norm: 2.1973e-06 |A: -3.5579e+00|
# Iteration: 3
# |Total Norm: 7.1214e-03 |Residual Norm: 3.8026e-11 |A: 7.1214e-03|
# Iteration: 4
# |Total Norm: 1.4285e-05 |Residual Norm: 3.7727e-11 |A: -1.4285e-05|
# Iteration: 5
# |Total Norm: 2.9220e-08 |Residual Norm: 3.8121e-11 |A: 2.9220e-08|
#
# Arc-Length Step 16 :
# Iteration: 1
# |Total Norm: 2.1216e+03 |Residual Norm: 3.4728e-02 |A: 2.1216e+03|
# Iteration: 2
# |Total Norm: 3.5699e+00 |Residual Norm: 4.6974e-06 |A: -3.5699e+00|
# Iteration: 3
# |Total Norm: 7.1233e-03 |Residual Norm: 3.9392e-11 |A: 7.1233e-03|
# Iteration: 4
# |Total Norm: 1.4286e-05 |Residual Norm: 3.9261e-11 |A: -1.4286e-05|
# Iteration: 5
# |Total Norm: 2.9570e-08 |Residual Norm: 3.8263e-11 |A: 2.9569e-08|
#
# Arc-Length Step 17 :
# Iteration: 1
# |Total Norm: 2.1214e+03 |Residual Norm: 3.4584e-02 |A: 2.1214e+03|
# Iteration: 2
# |Total Norm: 3.6030e+00 |Residual Norm: 1.1468e-05 |A: -3.6030e+00|
# Iteration: 3
# |Total Norm: 7.1208e-03 |Residual Norm: 5.5744e-11 |A: 7.1208e-03|
# Iteration: 4
# |Total Norm: 1.4279e-05 |Residual Norm: 3.9751e-11 |A: -1.4279e-05|
# Iteration: 5
# |Total Norm: 2.6659e-08 |Residual Norm: 3.8487e-11 |A: 2.6659e-08|
#
# Arc-Length Step 18 :
# Iteration: 1
# |Total Norm: 2.1211e+03 |Residual Norm: 3.4398e-02 |A: 2.1211e+03|
# Iteration: 2
# |Total Norm: 3.6962e+00 |Residual Norm: 3.4000e-05 |A: -3.6962e+00|
# Iteration: 3
# |Total Norm: 7.0135e-03 |Residual Norm: 1.9205e-10 |A: 7.0135e-03|
# Iteration: 4
# |Total Norm: 1.4067e-05 |Residual Norm: 4.0469e-11 |A: -1.4067e-05|
# Iteration: 5
# |Total Norm: 2.7008e-08 |Residual Norm: 4.1866e-11 |A: 2.7008e-08|
#
# Arc-Length Step 19 :
# Iteration: 1
# |Total Norm: 2.1208e+03 |Residual Norm: 3.4092e-02 |A: 2.1208e+03|
# Iteration: 2
# |Total Norm: 3.9966e+00 |Residual Norm: 1.3823e-04 |A: -3.9966e+00|
# Iteration: 3
# |Total Norm: 5.7595e-03 |Residual Norm: 1.5401e-09 |A: 5.7595e-03|
# Iteration: 4
# |Total Norm: 1.1573e-05 |Residual Norm: 4.2985e-11 |A: -1.1573e-05|
# Iteration: 5
# |Total Norm: 2.2352e-08 |Residual Norm: 4.3723e-11 |A: 2.2352e-08|
#
# Arc-Length Step 20 :
# Iteration: 1
# |Total Norm: 2.1201e+03 |Residual Norm: 3.3338e-02 |A: 2.1201e+03|
# Iteration: 2
# |Total Norm: 5.3120e+00 |Residual Norm: 1.0296e-03 |A: -5.3120e+00|
# Iteration: 3
# |Total Norm: 1.3499e-02 |Residual Norm: 3.3193e-08 |A: -1.3499e-02|
# Iteration: 4
# |Total Norm: 2.7672e-05 |Residual Norm: 4.2483e-11 |A: 2.7672e-05|
# Iteration: 5
# |Total Norm: 5.5414e-08 |Residual Norm: 4.4143e-11 |A: -5.5414e-08|
#
# Arc-Length Step 21 :
# Iteration: 1
# |Total Norm: 2.1180e+03 |Residual Norm: 2.9969e-02 |A: 2.1180e+03|
# Iteration: 2
# |Total Norm: 1.8493e+01 |Residual Norm: 3.9738e-02 |A: -1.8493e+01|
# Iteration: 3
# |Total Norm: 1.1711e+00 |Residual Norm: 1.3147e-05 |A: -1.1711e+00|
# Iteration: 4
# |Total Norm: 8.3386e-03 |Residual Norm: 4.9800e-09 |A: 8.3386e-03|
# Iteration: 5
# |Total Norm: 1.6345e-05 |Residual Norm: 4.5958e-11 |A: -1.6345e-05|
# Iteration: 6
# |Total Norm: 2.9104e-08 |Residual Norm: 4.3887e-11 |A: 2.9104e-08|
#
# Arc-Length Step 22 :
# Iteration: 1
# |Total Norm: 2.1017e+03 |Residual Norm: 1.0620e-01 |A: 2.1017e+03|
# Iteration: 2
# |Total Norm: 1.3920e+02 |Residual Norm: 1.4753e+00 |A: 1.3920e+02|
# Iteration: 3
# |Total Norm: 8.2069e+01 |Residual Norm: 2.1121e+00 |A: -8.2042e+01|
# Iteration: 4
# |Total Norm: 5.0584e+02 |Residual Norm: 1.2935e+01 |A: -5.0567e+02|
# Iteration: 5
# |Total Norm: 5.7802e+02 |Residual Norm: 2.0530e-02 |A: -5.7802e+02|
# Iteration: 6
# |Total Norm: 3.2218e+02 |Residual Norm: 6.1237e-01 |A: -3.2218e+02|
# Iteration: 7
# |Total Norm: 3.3445e+01 |Residual Norm: 1.4510e-02 |A: 3.3445e+01|
# Iteration: 8
# |Total Norm: 1.0291e+01 |Residual Norm: 5.5474e-04 |A: 1.0291e+01|
# Iteration: 9
# |Total Norm: 9.2142e-02 |Residual Norm: 8.4984e-08 |A: 9.2142e-02|
# Iteration: 10
# |Total Norm: 4.8232e-05 |Residual Norm: 4.5339e-11 |A: 4.8232e-05|
# Iteration: 11
# |Total Norm: 1.1991e-08 |Residual Norm: 4.6748e-11 |A: 1.1991e-08|
#
# Arc-Length Step 23 :
# Iteration: 1
# |Total Norm: 8.7006e+02 |Residual Norm: 4.7428e+01 |A: 8.6876e+02|
# Iteration: 2
# |Total Norm: 1.7038e+03 |Residual Norm: 1.3156e-01 |A: -1.7038e+03|
# Iteration: 3
# |Total Norm: 5.8139e+02 |Residual Norm: 5.3843e-01 |A: 5.8139e+02|
# Iteration: 4
# |Total Norm: 3.9780e+01 |Residual Norm: 6.6247e-03 |A: 3.9780e+01|
# Iteration: 5
# |Total Norm: 3.5177e+00 |Residual Norm: 2.7393e-05 |A: 3.5177e+00|
# Iteration: 6
# |Total Norm: 5.1063e-03 |Residual Norm: 3.1828e-10 |A: 5.1063e-03|
# Iteration: 7
# |Total Norm: 9.4227e-07 |Residual Norm: 4.9465e-11 |A: 9.4227e-07|
#
# Arc-Length Step 24 :
# Iteration: 1
# |Total Norm: 1.5132e+02 |Residual Norm: 2.9476e+01 |A: -1.4842e+02|
# Iteration: 2
# |Total Norm: 6.9015e+02 |Residual Norm: 1.9051e-01 |A: -6.9015e+02|
# Iteration: 3
# |Total Norm: 6.3485e+02 |Residual Norm: 4.2235e-01 |A: 6.3485e+02|
# Iteration: 4
# |Total Norm: 3.9017e+01 |Residual Norm: 3.4629e-03 |A: 3.9017e+01|
# Iteration: 5
# |Total Norm: 1.5919e+00 |Residual Norm: 3.6610e-06 |A: 1.5919e+00|
# Iteration: 6
# |Total Norm: 8.6826e-04 |Residual Norm: 6.0072e-11 |A: 8.6826e-04|
# Iteration: 7
# |Total Norm: 1.2445e-07 |Residual Norm: 5.5173e-11 |A: 1.2445e-07|
#
# Arc-Length Step 25 :
# Iteration: 1
# |Total Norm: 1.3318e+02 |Residual Norm: 1.4316e+01 |A: -1.3241e+02|
# Iteration: 2
# |Total Norm: 2.0608e+02 |Residual Norm: 9.3473e-02 |A: -2.0608e+02|
# Iteration: 3
# |Total Norm: 1.9715e+02 |Residual Norm: 3.2933e-02 |A: 1.9715e+02|
# Iteration: 4
# |Total Norm: 3.2879e+00 |Residual Norm: 1.9443e-05 |A: 3.2879e+00|
# Iteration: 5
# |Total Norm: 8.3677e-03 |Residual Norm: 2.1157e-10 |A: 8.3677e-03|
# Iteration: 6
# |Total Norm: 1.0472e-06 |Residual Norm: 5.9424e-11 |A: 1.0472e-06|
# Iteration: 7
# |Total Norm: 7.0115e-10 |Residual Norm: 6.1051e-11 |A: -6.9849e-10|
#
# Arc-Length Step 26 :
# Iteration: 1
# |Total Norm: 1.1688e+02 |Residual Norm: 9.4880e+00 |A: -1.1650e+02|
# Iteration: 2
# |Total Norm: 8.9529e+01 |Residual Norm: 4.8316e-02 |A: -8.9529e+01|
# Iteration: 3
# |Total Norm: 8.4197e+01 |Residual Norm: 4.8963e-03 |A: 8.4197e+01|
# Iteration: 4
# |Total Norm: 5.0529e-01 |Residual Norm: 4.6408e-07 |A: 5.0529e-01|
# Iteration: 5
# |Total Norm: 2.1869e-04 |Residual Norm: 6.2454e-11 |A: 2.1869e-04|
# Iteration: 6
# |Total Norm: 2.3516e-08 |Residual Norm: 6.3797e-11 |A: 2.3516e-08|
#
# Arc-Length Step 27 :
# Iteration: 1
# |Total Norm: 1.0533e+02 |Residual Norm: 7.1019e+00 |A: -1.0509e+02|
# Iteration: 2
# |Total Norm: 4.7410e+01 |Residual Norm: 2.7048e-02 |A: -4.7410e+01|
# Iteration: 3
# |Total Norm: 4.2826e+01 |Residual Norm: 1.0681e-03 |A: 4.2826e+01|
# Iteration: 4
# |Total Norm: 1.1315e-01 |Residual Norm: 2.9722e-08 |A: 1.1315e-01|
# Iteration: 5
# |Total Norm: 1.9480e-05 |Residual Norm: 6.0935e-11 |A: 1.9480e-05|
# Iteration: 6
# |Total Norm: 1.0497e-09 |Residual Norm: 6.3821e-11 |A: 1.0477e-09|
#
# Arc-Length Step 28 :
# Iteration: 1
# |Total Norm: 9.6746e+01 |Residual Norm: 5.6776e+00 |A: -9.6579e+01|
# Iteration: 2
# |Total Norm: 2.8684e+01 |Residual Norm: 1.6319e-02 |A: -2.8684e+01|
# Iteration: 3
# |Total Norm: 2.4478e+01 |Residual Norm: 3.0251e-04 |A: 2.4478e+01|
# Iteration: 4
# |Total Norm: 3.3018e-02 |Residual Norm: 3.8694e-09 |A: 3.3018e-02|
# Iteration: 5
# |Total Norm: 3.8145e-06 |Residual Norm: 6.3434e-11 |A: 3.8145e-06|
# Iteration: 6
# |Total Norm: 2.4170e-10 |Residual Norm: 6.4886e-11 |A: -2.3283e-10|
#
# Arc-Length Step 29 :
# Iteration: 1
# |Total Norm: 9.0063e+01 |Residual Norm: 4.7308e+00 |A: -8.9939e+01|
# Iteration: 2
# |Total Norm: 1.9123e+01 |Residual Norm: 1.0480e-02 |A: -1.9123e+01|
# Iteration: 3
# |Total Norm: 1.5210e+01 |Residual Norm: 1.0344e-04 |A: 1.5210e+01|
# Iteration: 4
# |Total Norm: 1.1751e-02 |Residual Norm: 8.2503e-10 |A: 1.1751e-02|
# Iteration: 5
# |Total Norm: 1.1268e-06 |Residual Norm: 6.5291e-11 |A: 1.1268e-06|
# Iteration: 6
# |Total Norm: 1.3986e-09 |Residual Norm: 6.6950e-11 |A: 1.3970e-09|
#
# Arc-Length Step 30 :
# Iteration: 1
# |Total Norm: 8.4676e+01 |Residual Norm: 4.0558e+00 |A: -8.4579e+01|
# Iteration: 2
# |Total Norm: 1.3718e+01 |Residual Norm: 7.0819e-03 |A: -1.3718e+01|
# Iteration: 3
# |Total Norm: 1.0061e+01 |Residual Norm: 4.0751e-05 |A: 1.0061e+01|
# Iteration: 4
# |Total Norm: 4.8877e-03 |Residual Norm: 2.5336e-10 |A: 4.8877e-03|
# Iteration: 5
# |Total Norm: 4.1956e-07 |Residual Norm: 6.6670e-11 |A: 4.1956e-07|
#
# Arc-Length Step 31 :
# Iteration: 1
# |Total Norm: 8.0213e+01 |Residual Norm: 3.5501e+00 |A: -8.0134e+01|
# Iteration: 2
# |Total Norm: 1.0415e+01 |Residual Norm: 4.9881e-03 |A: -1.0415e+01|
# Iteration: 3
# |Total Norm: 6.9849e+00 |Residual Norm: 1.7921e-05 |A: 6.9849e+00|
# Iteration: 4
# |Total Norm: 2.3066e-03 |Residual Norm: 1.1237e-10 |A: 2.3066e-03|
# Iteration: 5
# |Total Norm: 1.8522e-07 |Residual Norm: 6.8780e-11 |A: 1.8522e-07|
#
# Arc-Length Step 32 :
# Iteration: 1
# |Total Norm: 7.6436e+01 |Residual Norm: 3.1572e+00 |A: -7.6371e+01|
# Iteration: 2
# |Total Norm: 8.2665e+00 |Residual Norm: 3.6353e-03 |A: -8.2665e+00|
# Iteration: 3
# |Total Norm: 5.0397e+00 |Residual Norm: 8.6031e-06 |A: 5.0397e+00|
# Iteration: 4
# |Total Norm: 1.2081e-03 |Residual Norm: 8.3111e-11 |A: 1.2081e-03|
# Iteration: 5
# |Total Norm: 9.0688e-08 |Residual Norm: 7.6915e-11 |A: 9.0688e-08|
#
# Arc-Length Step 33 :
# Iteration: 1
# |Total Norm: 7.3183e+01 |Residual Norm: 2.8432e+00 |A: -7.3128e+01|
# Iteration: 2
# |Total Norm: 6.7956e+00 |Residual Norm: 2.7257e-03 |A: -6.7956e+00|
# Iteration: 3
# |Total Norm: 3.7518e+00 |Residual Norm: 4.4358e-06 |A: 3.7518e+00|
# Iteration: 4
# |Total Norm: 6.9006e-04 |Residual Norm: 7.8345e-11 |A: 6.9006e-04|
# Iteration: 5
# |Total Norm: 5.1339e-08 |Residual Norm: 7.5466e-11 |A: 5.1339e-08|
#
# Arc-Length Step 34 :
# Iteration: 1
# |Total Norm: 7.0342e+01 |Residual Norm: 2.5863e+00 |A: -7.0294e+01|
# Iteration: 2
# |Total Norm: 5.7452e+00 |Residual Norm: 2.0933e-03 |A: -5.7452e+00|
# Iteration: 3
# |Total Norm: 2.8663e+00 |Residual Norm: 2.4267e-06 |A: 2.8663e+00|
# Iteration: 4
# |Total Norm: 4.2373e-04 |Residual Norm: 7.9176e-11 |A: 4.2373e-04|
# Iteration: 5
# |Total Norm: 2.9104e-08 |Residual Norm: 7.6407e-11 |A: 2.9104e-08|
#
# Arc-Length Step 35 :
# Iteration: 1
# |Total Norm: 6.7830e+01 |Residual Norm: 2.3724e+00 |A: -6.7789e+01|
# Iteration: 2
# |Total Norm: 4.9677e+00 |Residual Norm: 1.6409e-03 |A: -4.9677e+00|
# Iteration: 3
# |Total Norm: 2.2380e+00 |Residual Norm: 1.3954e-06 |A: 2.2380e+00|
# Iteration: 4
# |Total Norm: 2.7632e-04 |Residual Norm: 7.8175e-11 |A: 2.7632e-04|
# Iteration: 5
# |Total Norm: 1.8859e-08 |Residual Norm: 7.7832e-11 |A: 1.8859e-08|

# %% [markdown]
# ## Optional: Stop at at specific criterion
# To strongly impose the stop condition, we add Newton solver at the end with a specific prescribed displacement and replace the final solution with the solution from the Newton Solver. In this case, we enforced the stop criterion with the applied displacement is slightly over the analytical critical strain.

# %%
apply_disp.t = -strain_crit*L*1.2 # stop simulation after bifurcation
problem = NonlinearVariationalProblem(residual, u, bcs, J)
newton_solver = NonlinearVariationalSolver(problem)
newton_solver.solve()

disp.pop()
lmbda.pop()
f_reac.pop()
disp.append(u.vector())
lmbda.append(apply_disp.t)
f_reac.append(assemble(action(residual,v_reac)))
# Out:
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.279e+02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 3.669e-01 (tol = 1.000e-10) r (rel) = 8.574e-04 (tol = 1.000e-09)
#   Newton iteration 2: r (abs) = 4.341e-05 (tol = 1.000e-10) r (rel) = 1.014e-07 (tol = 1.000e-09)
#   Newton iteration 3: r (abs) = 9.731e-10 (tol = 1.000e-10) r (rel) = 2.274e-12 (tol = 1.000e-09)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.

# %% [markdown]
# ## Post Processing
# Here we plot the final deformed shape, equilibrium path, and the wavelength. We obtain the analytical solutions from: https://royalsocietypublishing.org/doi/epdf/10.1098/rsta.2016.0163 and https://groups.seas.harvard.edu/hutchinson/papers/WrinklingPhenonmena-JAMF.pdf

# %%
plt.figure(figsize=(7,7))
plot(u, mode = 'displacement', cmap='Reds', edgecolor = 'k', linewidth = 0.2)
plt.title('Final Deformation')
# Out:
# Text(0.5, 1.0, 'Final Deformation')

# %%
strain_crit = float((1/4)*((3*mu_s/mu_f))**(2/3))

test_y = np.diff(np.array(f_reac))

test_x = np.diff(-np.array(lmbda)/L)

fea_soln = np.nanargmax(np.abs((np.diff(np.diff(((np.array(f_reac[1:])/(Hs+Hf))/(-np.array(lmbda[1:]))/L)))))) # find the inflection point from FEA solution and use that as critical strain

plt.figure(figsize=(7,5))
plt.plot(-np.array(lmbda)/L, np.array(f_reac)/(Hs+Hf), c='k', marker = 'o', label = 'Equilibrium Path')
plt.plot(-np.array(lmbda[fea_soln+2])/L, np.array(f_reac[fea_soln+2])/(Hs+Hf), marker = 'd', c =(0.4,0,0) , ls = 'None', markersize = 10, label='FEA critical strain')
plt.axvline(strain_crit, ls = ':', c = (0.7,0,0), label = 'Analytical Critical Strain')
plt.xlabel('Applied Strain')
plt.ylabel('Stress per unit depth')
plt.title('Equilibrium path')
plt.legend()

percent_diff_crit_strain = ((strain_crit-(-np.array(lmbda[fea_soln+2])/L))/strain_crit) * 100
print('Percent Error between analytical critical strain and FEA critical strain:',percent_diff_crit_strain,'%')
# Out:
# Percent Error between analytical critical strain and FEA critical strain: 1.5933169703227894 %

# %% [markdown]
# Here we extract and compare the post-bifurcation wrinkling wavelength from FEA and analytical solution.

# %%
post_bif = np.argwhere(-np.array(lmbda)/L > strain_crit).reshape(-1) # get index after bifurcation
# get solution after onset of bifurcation:
disp_bif = disp[post_bif[0]]
u_bif = Function(V) 
u_bif.vector()[:] = disp_bif[:]


# Get dof coordinates:
x_dofs = V.sub(0).dofmap().dofs()
y_dofs = V.sub(1).dofmap().dofs()
theta_dofs = V.sub(1).dofmap().dofs()
dofs = V.tabulate_dof_coordinates()
dof_coords = dofs.reshape((-1, 2))

x_nodal_coord = dof_coords[x_dofs][:,0]
y_nodal_coord = dof_coords[y_dofs][:,1]
# Get nodal values 

top_layer = np.argwhere(np.abs(y_nodal_coord-(Hs+Hf)) < 1e-6)

# Plot displacement field
disp_x = x_nodal_coord[top_layer].reshape(-1)#(x_nodal_coord + u_bif.vector()[x_dofs])[top_layer].reshape(-1)
disp_y = (y_nodal_coord + u_bif.vector()[y_dofs])[top_layer].reshape(-1)

# Fit to sine functions
from scipy import optimize

def fit_func(x, amp, wave, phi, offset):
    return amp * np.cos((2*np.pi)/wave * x + phi) + offset

params, params_covariance = optimize.curve_fit(fit_func, disp_x, disp_y,
                                               p0=[1.0,ana_wavelength,0.0,Hf+Hs])

plt.figure(figsize = (7,7))

plt.title('FEA wavelength vs Analytical Wavelength')
plt.scatter(disp_x,disp_y, marker = '.', c = 'r', s = 50, label='FEA data')
plt.scatter(disp_x,fit_func(disp_x, params[0], params[1], params[2], params[3]), c = 'None', marker = 's',edgecolor = 'k', s = 50, linewidth = 2, label = 'Fitted FEA data')
plt.scatter(disp_x,fit_func(disp_x, params[0], ana_wavelength, params[2], params[3]), c = 'None', marker = 'd', edgecolor = (0.5,0,0), s = 50, linewidth = 2, label = 'Analytical Wavelength')
plt.xlabel('x displacement')
plt.ylabel('y displacement')
plt.legend(loc = (1.01,0.5))

print('Percent Error between analytical wavelength and fitted FEM wavelength:',((params[1]-ana_wavelength)/ana_wavelength)*100, '%')
# Out:
# Percent Error between analytical wavelength and fitted FEM wavelength: 0.26496657540253155 %

# %% [markdown]
# ## Optional: Creating an animation from solution snapshots

# %%
from matplotlib import animation, rc

plt.rcParams["animation.html"] = "jshtml"

u_plot = Function(V)

fig = plt.figure(figsize=(12,5))
ax = fig.gca()

ax.set_xlim([0,L])
ax.set_ylim([(Hf+Hs)/3,Hs+Hf+5])

def drawframe(n):
    fig.clf()
    ax = fig.gca()
    ax.set_xlim([0,L])
    ax.set_ylim([(Hf+Hs)/3,Hf+Hs+5])
    u_plot = Function(V)
    u_plot.vector()[:] = disp[n][:]
    return plot(u_plot, mode = 'displacement', cmap = 'Reds'),
# blit=True re-draws only the parts that have changed.
anim = animation.FuncAnimation(fig, drawframe, frames=len(lmbda), interval=40, blit=True)
anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img88add858d0624eba91fc6732d4840821">
#   <div class="anim-controls">
#     <input id="_anim_slider88add858d0624eba91fc6732d4840821" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim88add858d0624eba91fc6732d4840821.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim88add858d0624eba91fc6732d4840821.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim88add858d0624eba91fc6732d4840821.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim88add858d0624eba91fc6732d4840821.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim88add858d0624eba91fc6732d4840821.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim88add858d0624eba91fc6732d4840821.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim88add858d0624eba91fc6732d4840821.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim88add858d0624eba91fc6732d4840821.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim88add858d0624eba91fc6732d4840821.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim88add858d0624eba91fc6732d4840821.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select88add858d0624eba91fc6732d4840821" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_88add858d0624eba91fc6732d4840821"
#              >
#       <label for="_anim_radio1_88add858d0624eba91fc6732d4840821">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_88add858d0624eba91fc6732d4840821"
#              checked>
#       <label for="_anim_radio2_88add858d0624eba91fc6732d4840821">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_88add858d0624eba91fc6732d4840821"
#              >
#       <label for="_anim_radio3_88add858d0624eba91fc6732d4840821">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img88add858d0624eba91fc6732d4840821";
#     var slider_id = "_anim_slider88add858d0624eba91fc6732d4840821";
#     var loop_select_id = "_anim_loop_select88add858d0624eba91fc6732d4840821";
#     var frames = new Array(36);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy8li6FKAAAV+UlEQVR4nO3dX2ie9eH38U9nN0Gdc6tNvLsaM7do\
# Y+tsbbTsYA+dN3cRJsmqXTf/QKaWgOxAGTsoCHM70SAb0w1PAkUCgmU9acVpsUZFVi3lXpsOcUpA\
# y6zeJP07tVpq0zwHD+vvGfob6tLvldTXCwq5Lrjgc5C2vLm+uTNnampqKgAAAJx2X6p6AAAAwBeF\
# AAMAAChEgAEAABQiwAAAAAoRYAAAAIUIMAAAgEIEGAAAQCECDAAAoBABBgAAUIgAAwAAKESAAQAA\
# FCLAAAAAChFgAAAAhQgwAACAQgQYAABAIQIMAACgEAEGAABQiAADAAAoRIABAAAUIsAAAAAKEWAA\
# AACFCDAAAIBCBBgAAEAhAgwAAKAQAQYAAFCIAAMAAChEgAEAABQiwAAAAAoRYAAAAIUIMAAAgEIE\
# GAAAQCECDAAAoBABBgAAUIgAAw
