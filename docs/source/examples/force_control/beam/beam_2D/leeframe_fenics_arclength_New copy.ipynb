# %% [markdown]
# # Lee's Frame
#
# The problem provided in this example is a L frame with pinned-pinned boundary conditions subjected to a point load at the center on top of the frame. The frame is modeled with 2D geometrically exact beams (i.e. Simo-Reissner Beams). For more information on beams [see here](../README.md).
#
#
# <img src="imgs/lee_frame.png" width="600">

# %%
# %matplotlib inline
from dolfin import *
import numpy as np
import matplotlib.pyplot as plt
from ufl import diag, Jacobian, shape
import os
os.chdir('../../../..') # change directory to main module directory
from arc_length.force_control_solver import force_control # import force control formulation of arc-length solver

parameters["form_compiler"]["cpp_optimize"] = True
parameters["form_compiler"]["quadrature_degree"] = 1
parameters['reorder_dofs_serial'] = False


ffc_options = {"optimize": True, \
               "eliminate_zeros": True, \
               "precompute_basis_const": True, \
               "precompute_ip_const": True}

# %% [markdown]
# ## Import Mesh and define function spaces
# In the case of 2D beams we also define the rotation matrix about the $z$ axis and directional derivative with respect to the beam centerline.

# %%
mesh = Mesh()
with XDMFFile(os.getcwd()+'/examples/force_control/beam/beam_2D/mesh/lee_frame.xdmf') as infile:
    infile.read(mesh)
    

Ue = VectorElement("CG", mesh.ufl_cell(), 1, dim=2) # displacement
Te = FiniteElement("CG", mesh.ufl_cell(), 1) # rotation
V = FunctionSpace(mesh, MixedElement([Ue, Te]))   

v_ = TestFunction(V)
u_, theta_ = split(v_)
dv = TrialFunction(V)
v = Function(V, name="Generalized displacement")
u, theta = split(v)

VR = TensorFunctionSpace(mesh, "DG", 0, shape=(2, 2))

V0 = FunctionSpace(mesh, "DG", 0)


Vu = V.sub(0).collapse()
disp = Function(Vu)

Jac = Jacobian(mesh)
gdim = mesh.geometry().dim()
Jac = as_vector([Jac[i, 0] for i in range(gdim)])
g01 = Jac/sqrt(dot(Jac, Jac))
g02 = as_vector([-g01[1],g01[0]])

r01 = outer(g01,as_vector([1,0]))
r02 = outer(g02, as_vector([0,1]))

R0 = r01+r02

#-----------------------Define Functions for beams-----------------------------------#
def tgrad(u): # directional derivative w.r.t. beam centerline
    return dot(grad(u), g01)

def rotation_matrix(theta): # 2D rotation matrix -- there is no need to do rotation parametrization for 2D beams
    return as_tensor([[cos(theta), -sin(theta)],[sin(theta), cos(theta)]])
Rot = rotation_matrix(theta)

# %% [markdown]
# ## Define Dirichlet Boundary Conditions

# %%
# Beam Geometry
Lx = 120
Ly = 120
Lf = 24

# %%
def Pinned_Bottom(x, on_boundary):
    return near(x[0], 0, 1e-6) and near(x[1], 0, 1e-6)
    
def Pinned_Top(x, on_boundary):
    return near(x[0], Lx, 1e-6) and near(x[1],Ly, 1e-6)

def load(x, on_boundary):
    return near(x[0],Lf, 1e-6)

facets = MeshFunction("size_t", mesh, 0)
facets.set_all(0)
AutoSubDomain(load).mark(facets,1)

Pinned_bot = DirichletBC(V.sub(0), Constant((0.0, 0.0)), Pinned_Bottom, method='pointwise') # displacement + rotation
Pinned_top = DirichletBC(V.sub(0), Constant((0.0, 0.0)), Pinned_Top, method='pointwise') # displacement + rotation
bcs = [Pinned_bot,Pinned_top]

# %% [markdown]
# ## Kinematics and Weak form

# %%
# 2D beam Kinematics
defo = dot(R0.T,dot(Rot.T, g01 + tgrad(u)) - g01)
curv =  tgrad(theta)

# %%
# Geometrical properties
S = 6.0 # cross-sectional area
I = 2.0 # Area moment
E = 720.0 # Elastic modulus
nu = 0.3 # Poisson's Ratio

G = E/(2*(1+nu)) # Shear Modulus
kappa = 1.0 # Shear correction



# Stiffness moduli
ES = E*S
GS = G*S
GS_2 = G*S*kappa
GS_3 = G*S*kappa
EI = E*I

# %%
# Constitutive Equations
C_N = diag(as_vector([ES, GS_2]))

# Applied Load:
F_max = Constant((0.0,-1.0))
M_max = Constant(0.0)
load = Expression("t", t=0, degree = 0)

dS = Measure("dS", domain=mesh, subdomain_data=facets) # Note its dS not ds -- interior facet
dx = Measure("dx", domain=mesh)

elastic_energy = 0.5 * (dot(defo, dot(C_N, defo)) + (EI*curv**2))*dx

F_int = derivative(elastic_energy, v, v_)
F_ext = avg(load * (-M_max*theta_ + dot(F_max, u_))) * dS(1) # avg function is used to integrte over disconticuous interior facets
residual = F_int - F_ext
tangent_form = derivative(residual, v, dv)

# %%
# Get dof coordinates:
x_dofs = V.sub(0).sub(0).dofmap().dofs()
y_dofs = V.sub(0).sub(1).dofmap().dofs()
theta_dofs = V.sub(1).dofmap().dofs()
dofs = V.tabulate_dof_coordinates()
dof_coords = dofs.reshape((-1, 2))

eps = 1e-5
dof = []
# Identify y-dof at the center for force application
for ii in y_dofs:
    if abs(dof_coords[ii,1]-Ly) <= eps:
        if abs(dof_coords[ii,0]-Lf) <=eps:
            force_dof = ii

# %% [markdown]
# ## Solver
# To use our solver we first have to define the type of solver (i.e. displacement control or force control) and solver parameters before using the solver. Note that the correct type of solver has to first be imported (see first cell).
# ### Solver parameters
# Here the parameters for both types of solvers:
#
# >* `psi` : the scalar arc-legth parameter. When psi = 1, the method becomes the shperical arc-length method and when psi = 0 the method becomes the cylindrical arc-length method
# >* `tol` : tolerance for the linear solver
# >* `lmbda0` : the initial load parameter
# >* `max_iter` : maximum number of iterations for the linear solver
# >* `solver` : (optional): type of linear solver for the FEniCS linear solve function -- default FEniCS linear solver is used if no argument is used.
#
# Aside from these solver parameters, the arguments need to solve the FEA problem must also be passed into the solver:
# >* `u` : the solution function
# >* `F_int` : First variation of strain energy (internal nodal forces)
# >* `F_ext` : Externally applied load (external applied force)
# >* `J` : The Jacobian of the residual with respect to the deformation (tangential stiffness matrix)
# >* `load_factor` : The incremental load factor
#
# The solver can be called by:
# `solver = force_control(psi,tol,lmbda0,max_iter,u,F_int,F_ext,bcs,J,load_factor,solver)`
#
# ### Using the solver
# 1. Initialize the solver by calling solver.initialize()
# 2. Iteratively call solver.solve() until desired stopping condition

# %%
# Solver Parameters
psi = 1.0
tol = 1.0e-10
lmbda0 = 0.5
max_iter = 20
solver = 'mumps' # optional

# Set up arc-length solver
solver = force_control(psi=psi, tol=tol, lmbda0=lmbda0, max_iter=max_iter, u=v,
                       F_int=F_int, F_ext=F_ext, bcs=bcs, J=tangent_form, load_factor=load, solver=solver)

# %%
disp = [v.vector()[:]]
lmbda = [0]

for ii in range(47):
    solver.solve()
    if solver.converged: # We only want to save the solution step if the solver coverges       
        disp.append(v.vector()[:])
        lmbda.append(load.t)
# Out:
# Initializing solver parameters...
# Starting initial Force Control with Newton Method:
# Iteration 0:
# Residual error: 5.0000e-01
# Iteration 1:
# Residual error: 5.4001e+01
# Iteration 2:
# Residual error: 4.5229e-01
# Iteration 3:
# Residual error: 1.9289e+00
# Iteration 4:
# Residual error: 3.9445e-03
# Iteration 5:
# Residual error: 4.0046e-04
# Iteration 6:
# Residual error: 1.9783e-10
# Iteration 7:
# Residual error: 2.5038e-12
#
# Arc-Length Step 1 :
# Iteration: 1
# |Total Norm: 2.5038e-12 |Residual Norm: 2.5038e-12 |A: 0.0000e+00|
#
# Arc-Length Step 2 :
# Iteration: 1
# |Total Norm: 1.7172e+02 |Residual Norm: 1.7172e+02 |A: 0.0000e+00|
# Iteration: 2
# |Total Norm: 9.9491e+00 |Residual Norm: 3.4885e+00 |A: 9.3175e+00|
# Iteration: 3
# |Total Norm: 3.9705e+00 |Residual Norm: 1.3821e+00 |A: 3.7222e+00|
# Iteration: 4
# |Total Norm: 2.1698e-02 |Residual Norm: 9.0788e-03 |A: 1.9707e-02|
# Iteration: 5
# |Total Norm: 3.0068e-04 |Residual Norm: 1.2656e-04 |A: 2.7275e-04|
# Iteration: 6
# |Total Norm: 2.1394e-09 |Residual Norm: 9.2730e-10 |A: 1.9280e-09|
# Iteration: 7
# |Total Norm: 3.0352e-12 |Residual Norm: 3.0340e-12 |A: 8.5265e-14|
#
# Arc-Length Step 3 :
# Iteration: 1
# |Total Norm: 1.4570e+02 |Residual Norm: 1.4570e+02 |A: 8.5265e-14|
# Iteration: 2
# |Total Norm: 8.0083e+00 |Residual Norm: 2.4449e+00 |A: 7.6259e+00|
# Iteration: 3
# |Total Norm: 1.2841e+00 |Residual Norm: 5.0455e-01 |A: 1.1808e+00|
# Iteration: 4
# |Total Norm: 1.3094e-02 |Residual Norm: 4.3318e-03 |A: 1.2356e-02|
# Iteration: 5
# |Total Norm: 7.4796e-05 |Residual Norm: 1.5359e-05 |A: 7.3202e-05|
# Iteration: 6
# |Total Norm: 5.4214e-11 |Residual Norm: 1.5486e-11 |A: 5.1955e-11|
#
# Arc-Length Step 4 :
# Iteration: 1
# |Total Norm: 1.1935e+02 |Residual Norm: 1.1935e+02 |A: 5.1983e-11|
# Iteration: 2
# |Total Norm: 6.3104e+00 |Residual Norm: 2.8690e+00 |A: 5.6205e+00|
# Iteration: 3
# |Total Norm: 3.7789e-01 |Residual Norm: 1.8299e-01 |A: 3.3063e-01|
# Iteration: 4
# |Total Norm: 3.7002e-03 |Residual Norm: 9.9497e-04 |A: 3.5639e-03|
# Iteration: 5
# |Total Norm: 8.4051e-07 |Residual Norm: 1.7424e-07 |A: 8.2225e-07|
# Iteration: 6
# |Total Norm: 5.2818e-12 |Residual Norm: 5.2805e-12 |A: 1.1369e-13|
#
# Arc-Length Step 5 :
# Iteration: 1
# |Total Norm: 9.7272e+01 |Residual Norm: 9.7272e+01 |A: 1.4211e-13|
# Iteration: 2
# |Total Norm: 4.7515e+00 |Residual Norm: 2.5372e+00 |A: 4.0174e+00|
# Iteration: 3
# |Total Norm: 1.8428e-01 |Residual Norm: 8.6827e-02 |A: 1.6254e-01|
# Iteration: 4
# |Total Norm: 3.4694e-04 |Residual Norm: 2.9875e-04 |A: 1.7640e-04|
# Iteration: 5
# |Total Norm: 3.4552e-08 |Residual Norm: 1.8095e-08 |A: 2.9435e-08|
# Iteration: 6
# |Total Norm: 4.2454e-12 |Residual Norm: 4.2450e-12 |A: 5.6843e-14|
#
# Arc-Length Step 6 :
# Iteration: 1
# |Total Norm: 8.0188e+01 |Residual Norm: 8.0188e+01 |A: 2.8422e-14|
# Iteration: 2
# |Total Norm: 3.6319e+00 |Residual Norm: 1.9844e+00 |A: 3.0418e+00|
# Iteration: 3
# |Total Norm: 1.8237e-01 |Residual Norm: 8.2015e-02 |A: 1.6289e-01|
# Iteration: 4
# |Total Norm: 1.6881e-03 |Residual Norm: 6.0209e-04 |A: 1.5770e-03|
# Iteration: 5
# |Total Norm: 8.5256e-07 |Residual Norm: 2.5856e-07 |A: 8.1241e-07|
# Iteration: 6
# |Total Norm: 7.6818e-12 |Residual Norm: 7.6810e-12 |A: 1.1369e-13|
#
# Arc-Length Step 7 :
# Iteration: 1
# |Total Norm: 6.7515e+01 |Residual Norm: 6.7515e+01 |A: 1.4211e-13|
# Iteration: 2
# |Total Norm: 2.9540e+00 |Residual Norm: 1.4898e+00 |A: 2.5508e+00|
# Iteration: 3
# |Total Norm: 1.9761e-01 |Residual Norm: 9.2417e-02 |A: 1.7467e-01|
# Iteration: 4
# |Total Norm: 2.0827e-03 |Residual Norm: 6.1166e-04 |A: 1.9909e-03|
# Iteration: 5
# |Total Norm: 1.5844e-06 |Residual Norm: 4.3482e-07 |A: 1.5235e-06|
# Iteration: 6
# |Total Norm: 6.5607e-12 |Residual Norm: 6.5605e-12 |A: 5.6843e-14|
#
# Arc-Length Step 8 :
# Iteration: 1
# |Total Norm: 5.8122e+01 |Residual Norm: 5.8122e+01 |A: -5.6843e-14|
# Iteration: 2
# |Total Norm: 2.6429e+00 |Residual Norm: 1.1033e+00 |A: 2.4016e+00|
# Iteration: 3
# |Total Norm: 1.6677e-01 |Residual Norm: 7.7366e-02 |A: 1.4774e-01|
# Iteration: 4
# |Total Norm: 1.7292e-03 |Residual Norm: 4.6856e-04 |A: 1.6645e-03|
# Iteration: 5
# |Total Norm: 9.2442e-07 |Residual Norm: 2.4134e-07 |A: 8.9236e-07|
# Iteration: 6
# |Total Norm: 9.2138e-12 |Residual Norm: 9.2137e-12 |A: 2.8422e-14|
#
# Arc-Length Step 9 :
# Iteration: 1
# |Total Norm: 5.0857e+01 |Residual Norm: 5.0857e+01 |A: 1.1369e-13|
# Iteration: 2
# |Total Norm: 2.6901e+00 |Residual Norm: 8.2523e-01 |A: 2.5604e+00|
# Iteration: 3
# |Total Norm: 8.7612e-02 |Residual Norm: 4.0419e-02 |A: 7.7731e-02|
# Iteration: 4
# |Total Norm: 8.6740e-04 |Residual Norm: 2.1917e-04 |A: 8.3925e-04|
# Iteration: 5
# |Total Norm: 6.5059e-08 |Residual Norm: 1.6094e-08 |A: 6.3037e-08|
# Iteration: 6
# |Total Norm: 8.2144e-12 |Residual Norm: 8.2142e-12 |A: -5.6843e-14|
#
# Arc-Length Step 10 :
# Iteration: 1
# |Total Norm: 4.4807e+01 |Residual Norm: 4.4807e+01 |A: -2.2737e-13|
# Iteration: 2
# |Total Norm: 3.2031e+00 |Residual Norm: 7.6482e-01 |A: 3.1105e+00|
# Iteration: 3
# |Total Norm: 5.1422e-02 |Residual Norm: 3.4089e-02 |A: 3.8499e-02|
# Iteration: 4
# |Total Norm: 7.7723e-04 |Residual Norm: 2.0268e-04 |A: 7.5034e-04|
# Iteration: 5
# |Total Norm: 3.2553e-09 |Residual Norm: 1.1350e-09 |A: 3.0511e-09|
# Iteration: 6
# |Total Norm: 7.2558e-12 |Residual Norm: 7.2558e-12 |A: 0.0000e+00|
#
# Arc-Length Step 11 :
# Iteration: 1
# |Total Norm: 3.9416e+01 |Residual Norm: 3.9416e+01 |A: -2.8422e-14|
# Iteration: 2
# |Total Norm: 4.0474e+00 |Residual Norm: 1.0748e+00 |A: 3.9021e+00|
# Iteration: 3
# |Total Norm: 1.2316e-01 |Residual Norm: 7.5335e-02 |A: 9.7430e-02|
# Iteration: 4
# |Total Norm: 2.9434e-02 |Residual Norm: 7.4632e-03 |A: 2.8472e-02|
# Iteration: 5
# |Total Norm: 1.3513e-05 |Residual Norm: 3.7606e-06 |A: 1.2979e-05|
# Iteration: 6
# |Total Norm: 1.8376e-10 |Residual Norm: 4.3125e-11 |A: 1.7863e-10|
# Iteration: 7
# |Total Norm: 1.2714e-11 |Residual Norm: 1.2714e-11 |A: -5.6843e-14|
#
# Arc-Length Step 12 :
# Iteration: 1
# |Total Norm: 3.4508e+01 |Residual Norm: 3.4508e+01 |A: -5.6843e-14|
# Iteration: 2
# |Total Norm: 3.7348e+00 |Residual Norm: 1.1806e+00 |A: 3.5433e+00|
# Iteration: 3
# |Total Norm: 1.4186e-01 |Residual Norm: 8.9161e-02 |A: 1.1033e-01|
# Iteration: 4
# |Total Norm: 3.5039e-02 |Residual Norm: 8.8288e-03 |A: 3.3908e-02|
# Iteration: 5
# |Total Norm: 2.6747e-05 |Residual Norm: 7.1268e-06 |A: 2.5780e-05|
# Iteration: 6
# |Total Norm: 5.0687e-10 |Residual Norm: 1.1535e-10 |A: 4.9357e-10|
# Iteration: 7
# |Total Norm: 1.3689e-11 |Residual Norm: 1.3689e-11 |A: 0.0000e+00|
#
# Arc-Length Step 13 :
# Iteration: 1
# |Total Norm: 3.0193e+01 |Residual Norm: 3.0193e+01 |A: 1.1369e-13|
# Iteration: 2
# |Total Norm: 2.1007e+00 |Residual Norm: 8.7456e-01 |A: 1.9100e+00|
# Iteration: 3
# |Total Norm: 4.2850e-02 |Residual Norm: 2.8108e-02 |A: 3.2343e-02|
# Iteration: 4
# |Total Norm: 1.1161e-03 |Residual Norm: 3.2199e-04 |A: 1.0687e-03|
# Iteration: 5
# |Total Norm: 3.2760e-08 |Residual Norm: 8.7869e-09 |A: 3.1560e-08|
# Iteration: 6
# |Total Norm: 1.2471e-11 |Residual Norm: 1.2471e-11 |A: 5.6843e-14|
#
# Arc-Length Step 14 :
# Iteration: 1
# |Total Norm: 2.6719e+01 |Residual Norm: 2.6719e+01 |A: 0.0000e+00|
# Iteration: 2
# |Total Norm: 1.0998e+00 |Residual Norm: 6.2790e-01 |A: 9.0297e-01|
# Iteration: 3
# |Total Norm: 1.0731e-01 |Residual Norm: 3.4330e-02 |A: 1.0167e-01|
# Iteration: 4
# |Total Norm: 3.3027e-04 |Residual Norm: 6.5629e-05 |A: 3.2369e-04|
# Iteration: 5
# |Total Norm: 1.0264e-08 |Residual Norm: 2.1175e-09 |A: 1.0043e-08|
# Iteration: 6
# |Total Norm: 1.6170e-11 |Residual Norm: 1.6170e-11 |A: 0.0000e+00|
#
# Arc-Length Step 15 :
# Iteration: 1
# |Total Norm: 2.4291e+01 |Residual Norm: 2.4291e+01 |A: 2.8422e-14|
# Iteration: 2
# |Total Norm: 7.2487e-01 |Residual Norm: 4.6312e-01 |A: 5.5764e-01|
# Iteration: 3
# |Total Norm: 2.2705e-01 |Residual Norm: 5.3670e-02 |A: 2.2062e-01|
# Iteration: 4
# |Total Norm: 3.8771e-04 |Residual Norm: 8.3976e-05 |A: 3.7851e-04|
# Iteration: 5
# |Total Norm: 6.6281e-08 |Residual Norm: 1.4040e-08 |A: 6.4777e-08|
# Iteration: 6
# |Total Norm: 1.3154e-11 |Residual Norm: 1.3154e-11 |A: -8.5265e-14|
#
# Arc-Length Step 16 :
# Iteration: 1
# |Total Norm: 2.2947e+01 |Residual Norm: 2.2947e+01 |A: -1.9895e-13|
# Iteration: 2
# |Total Norm: 5.7709e-01 |Residual Norm: 3.4485e-01 |A: 4.6272e-01|
# Iteration: 3
# |Total Norm: 2.7838e-01 |Residual Norm: 6.4852e-02 |A: 2.7072e-01|
# Iteration: 4
# |Total Norm: 2.9435e-04 |Residual Norm: 6.7775e-05 |A: 2.8644e-04|
# Iteration: 5
# |Total Norm: 4.8967e-08 |Residual Norm: 1.0868e-08 |A: 4.7746e-08|
# Iteration: 6
# |Total Norm: 8.7148e-12 |Residual Norm: 8.7147e-12 |A: 2.8422e-14|
#
# Arc-Length Step 17 :
# Iteration: 1
# |Total Norm: 2.2538e+01 |Residual Norm: 2.2538e+01 |A: -5.6843e-14|
# Iteration: 2
# |Total Norm: 5.1977e-01 |Residual Norm: 2.6388e-01 |A: 4.4780e-01|
# Iteration: 3
# |Total Norm: 2.8430e-01 |Residual Norm: 6.7904e-02 |A: 2.7607e-01|
# Iteration: 4
# |Total Norm: 2.1609e-04 |Residual Norm: 5.1260e-05 |A: 2.0993e-04|
# Iteration: 5
# |Total Norm: 2.0854e-08 |Residual Norm: 4.9344e-09 |A: 2.0262e-08|
# Iteration: 6
# |Total Norm: 1.1908e-11 |Residual Norm: 1.1908e-11 |A: 2.8422e-14|
#
# Arc-Length Step 18 :
# Iteration: 1
# |Total Norm: 2.2827e+01 |Residual Norm: 2.2827e+01 |A: 8.5265e-14|
# Iteration: 2
# |Total Norm: 5.0838e-01 |Residual Norm: 2.1776e-01 |A: 4.5939e-01|
# Iteration: 3
# |Total Norm: 2.8299e-01 |Residual Norm: 6.9817e-02 |A: 2.7425e-01|
# Iteration: 4
# |Total Norm: 1.6497e-04 |Residual Norm: 3.9151e-05 |A: 1.6026e-04|
# Iteration: 5
# |Total Norm: 6.8556e-09 |Residual Norm: 1.8096e-09 |A: 6.6125e-09|
# Iteration: 6
# |Total Norm: 1.5622e-11 |Residual Norm: 1.5622e-11 |A: 5.6843e-14|
#
# Arc-Length Step 19 :
# Iteration: 1
# |Total Norm: 2.3614e+01 |Residual Norm: 2.3614e+01 |A: 5.6843e-14|
# Iteration: 2
# |Total Norm: 5.2222e-01 |Residual Norm: 2.0173e-01 |A: 4.8168e-01|
# Iteration: 3
# |Total Norm: 2.9978e-01 |Residual Norm: 7.6448e-02 |A: 2.8986e-01|
# Iteration: 4
# |Total Norm: 1.4709e-04 |Residual Norm: 3.2847e-05 |A: 1.4337e-04|
# Iteration: 5
# |Total Norm: 1.4450e-09 |Residual Norm: 5.3243e-10 |A: 1.3434e-09|
# Iteration: 6
# |Total Norm: 1.2668e-11 |Residual Norm: 1.2668e-11 |A: -5.6843e-14|
#
# Arc-Length Step 20 :
# Iteration: 1
# |Total Norm: 2.4800e+01 |Residual Norm: 2.4800e+01 |A: -1.7053e-13|
# Iteration: 2
# |Total Norm: 5.5188e-01 |Residual Norm: 2.0614e-01 |A: 5.1193e-01|
# Iteration: 3
# |Total Norm: 3.5770e-01 |Residual Norm: 9.4105e-02 |A: 3.4510e-01|
# Iteration: 4
# |Total Norm: 1.7489e-04 |Residual Norm: 3.2944e-05 |A: 1.7176e-04|
# Iteration: 5
# |Total Norm: 1.0319e-09 |Residual Norm: 4.9138e-10 |A: 9.0742e-10|
# Iteration: 6
# |Total Norm: 1.5237e-11 |Residual Norm: 1.5237e-11 |A: 1.1369e-13|
#
# Arc-Length Step 21 :
# Iteration: 1
# |Total Norm: 2.6412e+01 |Residual Norm: 2.6412e+01 |A: 2.5580e-13|
# Iteration: 2
# |Total Norm: 5.9775e-01 |Residual Norm: 2.2273e-01 |A: 5.5471e-01|
# Iteration: 3
# |Total Norm: 4.9543e-01 |Residual Norm: 1.3417e-01 |A: 4.7691e-01|
# Iteration: 4
# |Total Norm: 3.0268e-04 |Residual Norm: 4.2580e-05 |A: 2.9967e-04|
# Iteration: 5
# |Total Norm: 1.9572e-08 |Residual Norm: 5.0255e-09 |A: 1.8916e-08|
# Iteration: 6
# |Total Norm: 1.6015e-11 |Residual Norm: 1.6015e-11 |A: 0.0000e+00|
#
# Arc-Length Step 22 :
# Iteration: 1
# |Total Norm: 2.8615e+01 |Residual Norm: 2.8615e+01 |A: 0.0000e+00|
# Iteration: 2
# |Total Norm: 6.7385e-01 |Residual Norm: 2.5232e-01 |A: 6.2483e-01|
# Iteration: 3
# |Total Norm: 7.9647e-01 |Residual Norm: 2.2191e-01 |A: 7.6493e-01|
# Iteration: 4
# |Total Norm: 7.6818e-04 |Residual Norm: 9.4129e-05 |A: 7.6239e-04|
# Iteration: 5
# |Total Norm: 2.6787e-07 |Residual Norm: 6.8015e-08 |A: 2.5909e-07|
# Iteration: 6
# |Total Norm: 1.4797e-11 |Residual Norm: 1.4797e-11 |A: -2.8422e-14|
#
# Arc-Length Step 23 :
# Iteration: 1
# |Total Norm: 3.1760e+01 |Residual Norm: 3.1760e+01 |A: -2.2737e-13|
# Iteration: 2
# |Total Norm: 8.2066e-01 |Residual Norm: 3.0928e-01 |A: 7.6016e-01|
# Iteration: 3
# |Total Norm: 1.4467e+00 |Residual Norm: 4.1409e-01 |A: 1.3861e+00|
# Iteration: 4
# |Total Norm: 2.7856e-03 |Residual Norm: 5.3614e-04 |A: 2.7335e-03|
# Iteration: 5
# |Total Norm: 4.2288e-06 |Residual Norm: 1.1408e-06 |A: 4.0721e-06|
# Iteration: 6
# |Total Norm: 1.4707e-11 |Residual Norm: 1.4706e-11 |A: 1.7053e-13|
#
# Arc-Length Step 24 :
# Iteration: 1
# |Total Norm: 3.6487e+01 |Residual Norm: 3.6487e+01 |A: 2.8422e-13|
# Iteration: 2
# |Total Norm: 1.1364e+00 |Residual Norm: 4.2602e-01 |A: 1.0536e+00|
# Iteration: 3
# |Total Norm: 2.8588e+00 |Residual Norm: 8.3538e-01 |A: 2.7340e+00|
# Iteration: 4
# |Total Norm: 1.3990e-02 |Residual Norm: 4.0674e-03 |A: 1.3386e-02|
# Iteration: 5
# |Total Norm: 7.9985e-05 |Residual Norm: 2.3911e-05 |A: 7.6327e-05|
# Iteration: 6
# |Total Norm: 2.1969e-11 |Residual Norm: 1.6071e-11 |A: 1.4978e-11|
#
# Arc-Length Step 25 :
# Iteration: 1
# |Total Norm: 4.3946e+01 |Residual Norm: 4.3946e+01 |A: 1.4722e-11|
# Iteration: 2
# |Total Norm: 1.8667e+00 |Residual Norm: 6.7816e-01 |A: 1.7391e+00|
# Iteration: 3
# |Total Norm: 6.0522e+00 |Residual Norm: 1.7889e+00 |A: 5.7818e+00|
# Iteration: 4
# |Total Norm: 9.3134e-02 |Residual Norm: 3.2826e-02 |A: 8.7157e-02|
# Iteration: 5
# |Total Norm: 1.7913e-03 |Residual Norm: 6.2033e-04 |A: 1.6804e-03|
# Iteration: 6
# |Total Norm: 6.4990e-09 |Residual Norm: 2.6205e-09 |A: 5.9473e-09|
# Iteration: 7
# |Total Norm: 1.4719e-11 |Residual Norm: 1.4719e-11 |A: 0.0000e+00|
#
# Arc-Length Step 26 :
# Iteration: 1
# |Total Norm: 5.6232e+01 |Residual Norm: 5.6232e+01 |A: -1.7053e-13|
# Iteration: 2
# |Total Norm: 3.7113e+00 |Residual Norm: 1.2862e+00 |A: 3.4813e+00|
# Iteration: 3
# |Total Norm: 1.4772e+01 |Residual Norm: 4.4069e+00 |A: 1.4099e+01|
# Iteration: 4
# |Total Norm: 8.7608e-01 |Residual Norm: 3.3603e-01 |A: 8.0908e-01|
# Iteration: 5
# |Total Norm: 6.1306e-02 |Residual Norm: 2.4407e-02 |A: 5.6238e-02|
# Iteration: 6
# |Total Norm: 1.2700e-04 |Residual Norm: 3.7163e-05 |A: 1.2144e-04|
# Iteration: 7
# |Total Norm: 6.4689e-10 |Residual Norm: 1.6537e-10 |A: 6.2539e-10|
# Iteration: 8
# |Total Norm: 1.5677e-11 |Residual Norm: 1.5677e-11 |A: -5.6843e-14|
#
# Arc-Length Step 27 :
# Iteration: 1
# |Total Norm: 7.7012e+01 |Residual Norm: 7.7012e+01 |A: 8.5265e-14|
# Iteration: 2
# |Total Norm: 8.6888e+00 |Residual Norm: 2.8358e+00 |A: 8.2129e+00|
# Iteration: 3
# |Total Norm: 5.7627e+01 |Residual Norm: 1.7967e+01 |A: 5.4754e+01|
# Iteration: 4
# |Total Norm: 1.1496e+01 |Residual Norm: 5.0569e+00 |A: 1.0324e+01|
# Iteration: 5
# |Total Norm: 2.4594e+01 |Residual Norm: 6.2715e+00 |A: 2.3781e+01|
# Iteration: 6
# |Total Norm: 2.0221e+01 |Residual Norm: 6.6243e+00 |A: 1.9105e+01|
# Iteration: 7
# |Total Norm: 1.9236e+00 |Residual Norm: 1.1017e+00 |A: 1.5768e+00|
# Iteration: 8
# |Total Norm: 6.1535e-01 |Residual Norm: 2.2650e-01 |A: 5.7215e-01|
# Iteration: 9
# |Total Norm: 1.8305e-02 |Residual Norm: 5.8862e-03 |A: 1.7333e-02|
# Iteration: 10
# |Total Norm: 8.6351e-07 |Residual Norm: 3.2907e-07 |A: 7.9835e-07|
# Iteration: 11
# |Total Norm: 2.1364e-11 |Residual Norm: 2.1332e-11 |A: 1.1653e-12|
#
# Arc-Length Step 28 :
# Iteration: 1
# |Total Norm: 1.1043e+02 |Residual Norm: 1.1043e+02 |A: 1.4495e-12|
# Iteration: 2
# |Total Norm: 1.9767e+01 |Residual Norm: 6.0153e+00 |A: 1.8829e+01|
# Iteration: 3
# |Total Norm: 3.1631e+02 |Residual Norm: 1.2203e+02 |A: 2.9182e+02|
# Iteration: 4
# |Total Norm: 3.3971e+02 |Residual Norm: 1.0003e+02 |A: 3.2465e+02|
# Iteration: 5
# |Total Norm: 9.4798e+04 |Residual Norm: 7.0409e+04 |A: 6.3476e+04|
# Iteration: 6
# |Total Norm: 4.6882e+05 |Residual Norm: 4.5320e+05 |A: 1.2003e+05|
# Iteration: 7
# |Total Norm: 3.5079e+05 |Residual Norm: 3.4795e+05 |A: 4.4507e+04|
# Iteration: 8
# |Total Norm: 1.2972e+06 |Residual Norm: 1.2834e+06 |A: 1.8857e+05|
# Iteration: 9
# |Total Norm: 4.1767e+05 |Residual Norm: 4.0492e+05 |A: 1.0244e+05|
# Iteration: 10
# |Total Norm: 8.8426e+05 |Residual Norm: 7.8651e+05 |A: 4.0413e+05|
# Iteration: 11
# |Total Norm: 2.7169e+06 |Residual Norm: 2.5811e+06 |A: 8.4828e+05|
# Iteration: 12
# |Total Norm: 2.4096e+06 |Residual Norm: 1.9106e+06 |A: 1.4683e+06|
# Iteration: 13
# |Total Norm: 7.0599e+05 |Residual Norm: 4.5019e+05 |A: 5.4383e+05|
# Iteration: 14
# |Total Norm: 1.6603e+05 |Residual Norm: 5.5881e+04 |A: 1.5635e+05|
# Iteration: 15
# |Total Norm: 2.3408e+05 |Residual Norm: 2.2942e+05 |A: 4.6446e+04|
# Iteration: 16
# |Total Norm: 2.0242e+09 |Residual Norm: 2.0181e+09 |A: 1.5660e+08|
# Iteration: 17
# |Total Norm: 1.4725e+10 |Residual Norm: 1.1890e+10 |A: 8.6856e+09|
# Iteration: 18
# |Total Norm: 4.0968e+09 |Residual Norm: 3.1835e+09 |A: 2.5786e+09|
# Iteration: 19
# |Total Norm: 7.5110e+08 |Residual Norm: 2.9247e+08 |A: 6.9181e+08|
# Iteration: 20
# |Total Norm: 2.1126e+08 |Residual Norm: 6.5389e+07 |A: 2.0089e+08|
#
# Arc-Length Step 28 :
# Iteration: 1
# |Total Norm: 3.5098e+01 |Residual Norm: 3.5098e+01 |A: 2.7001e-13|
# Iteration: 2
# |Total Norm: 2.2498e+00 |Residual Norm: 6.8928e-01 |A: 2.1416e+00|
# Iteration: 3
# |Total Norm: 2.3191e+00 |Residual Norm: 6.9806e-01 |A: 2.2115e+00|
# Iteration: 4
# |Total Norm: 4.2223e-02 |Residual Norm: 1.6638e-02 |A: 3.8807e-02|
# Iteration: 5
# |Total Norm: 9.0312e-04 |Residual Norm: 2.5078e-04 |A: 8.6760e-04|
# Iteration: 6
# |Total Norm: 1.9077e-08 |Residual Norm: 7.2196e-09 |A: 1.7658e-08|
# Iteration: 7
# |Total Norm: 2.1031e-11 |Residual Norm: 2.1031e-11 |A: 0.0000e+00|
#
# Arc-Length Step 29 :
# Iteration: 1
# |Total Norm: 2.7338e+01 |Residual Norm: 2.7338e+01 |A: 1.4211e-14|
# Iteration: 2
# |Total Norm: 1.3327e+00 |Residual Norm: 3.9577e-01 |A: 1.2725e+00|
# Iteration: 3
# |Total Norm: 4.7094e-01 |Residual Norm: 1.5135e-01 |A: 4.4596e-01|
# Iteration: 4
# |Total Norm: 1.9027e-03 |Residual Norm: 8.0535e-04 |A: 1.7239e-03|
# Iteration: 5
# |Total Norm: 1.4581e-06 |Residual Norm: 3.9491e-07 |A: 1.4036e-06|
# Iteration: 6
# |Total Norm: 2.0958e-11 |Residual Norm: 2.0958e-11 |A: 1.0658e-13|
#
# Arc-Length Step 30 :
# Iteration: 1
# |Total Norm: 1.0778e+02 |Residual Norm: 1.0778e+02 |A: 4.2633e-13|
# Iteration: 2
# |Total Norm: 1.3614e+01 |Residual Norm: 3.8573e+00 |A: 1.3056e+01|
# Iteration: 3
# |Total Norm: 1.3680e+00 |Residual Norm: 7.6185e-01 |A: 1.1362e+00|
# Iteration: 4
# |Total Norm: 4.6927e-02 |Residual Norm: 2.3621e-02 |A: 4.0549e-02|
# Iteration: 5
# |Total Norm: 6.6833e-04 |Residual Norm: 2.3533e-04 |A: 6.2553e-04|
# Iteration: 6
# |Total Norm: 7.0156e-09 |Residual Norm: 2.6282e-09 |A: 6.5048e-09|
# Iteration: 7
# |Total Norm: 1.3221e-11 |Residual Norm: 1.3221e-11 |A: -5.6843e-14|
#
# Arc-Length Step 31 :
# Iteration: 1
# |Total Norm: 1.5287e+02 |Residual Norm: 1.5287e+02 |A: 1.9895e-13|
# Iteration: 2
# |Total Norm: 1.6986e+01 |Residual Norm: 4.4984e+00 |A: 1.6379e+01|
# Iteration: 3
# |Total Norm: 6.5886e+00 |Residual Norm: 2.3800e+00 |A: 6.1437e+00|
# Iteration: 4
# |Total Norm: 1.2248e-01 |Residual Norm: 3.8303e-02 |A: 1.1634e-01|
# Iteration: 5
# |Total Norm: 1.1423e-01 |Residual Norm: 2.8862e-02 |A: 1.1053e-01|
# Iteration: 6
# |Total Norm: 4.8126e-05 |Residual Norm: 2.2376e-05 |A: 4.2608e-05|
# Iteration: 7
# |Total Norm: 5.0744e-08 |Residual Norm: 1.2961e-08 |A: 4.9061e-08|
# Iteration: 8
# |Total Norm: 1.6226e-11 |Residual Norm: 1.6226e-11 |A: -2.8422e-14|
#
# Arc-Length Step 32 :
# Iteration: 1
# |Total Norm: 1.0515e+02 |Residual Norm: 1.0515e+02 |A: -2.8422e-13|
# Iteration: 2
# |Total Norm: 7.8999e+00 |Residual Norm: 2.0631e+00 |A: 7.6258e+00|
# Iteration: 3
# |Total Norm: 7.5349e+00 |Residual Norm: 2.2180e+00 |A: 7.2010e+00|
# Iteration: 4
# |Total Norm: 1.1834e-01 |Residual Norm: 4.0741e-02 |A: 1.1111e-01|
# Iteration: 5
# |Total Norm: 1.7440e-01 |Residual Norm: 4.5086e-02 |A: 1.6848e-01|
# Iteration: 6
# |Total Norm: 9.4193e-05 |Residual Norm: 4.2804e-05 |A: 8.3906e-05|
# Iteration: 7
# |Total Norm: 1.8443e-07 |Residual Norm: 4.8593e-08 |A: 1.7792e-07|
# Iteration: 8
# |Total Norm: 1.9806e-11 |Residual Norm: 1.9806e-11 |A: 0.0000e+00|
#
# Arc-Length Step 33 :
# Iteration: 1
# |Total Norm: 6.4867e+01 |Residual Norm: 6.4867e+01 |A: -8.5265e-14|
# Iteration: 2
# |Total Norm: 3.7454e+00 |Residual Norm: 1.2589e+00 |A: 3.5275e+00|
# Iteration: 3
# |Total Norm: 2.0078e+00 |Residual Norm: 8.2296e-01 |A: 1.8313e+00|
# Iteration: 4
# |Total Norm: 2.8810e-02 |Residual Norm: 9.5637e-03 |A: 2.7176e-02|
# Iteration: 5
# |Total Norm: 5.3415e-03 |Residual Norm: 1.4188e-03 |A: 5.1496e-03|
# Iteration: 6
# |Total Norm: 2.0724e-07 |Residual Norm: 7.4162e-08 |A: 1.9351e-07|
# Iteration: 7
# |Total Norm: 1.6501e-11 |Residual Norm: 1.6498e-11 |A: 2.8422e-13|
#
# Arc-Length Step 34 :
# Iteration: 1
# |Total Norm: 5.0424e+01 |Residual Norm: 5.0424e+01 |A: 1.4211e-13|
# Iteration: 2
# |Total Norm: 2.7954e+00 |Residual Norm: 7.7547e-01 |A: 2.6857e+00|
# Iteration: 3
# |Total Norm: 3.2296e-01 |Residual Norm: 2.5084e-01 |A: 2.0344e-01|
# Iteration: 4
# |Total Norm: 9.3012e-04 |Residual Norm: 5.0181e-04 |A: 7.8314e-04|
# Iteration: 5
# |Total Norm: 3.3345e-06 |Residual Norm: 1.3256e-06 |A: 3.0597e-06|
# Iteration: 6
# |Total Norm: 1.6261e-11 |Residual Norm: 1.6260e-11 |A: 1.7053e-13|
#
# Arc-Length Step 35 :
# Iteration: 1
# |Total Norm: 4.6135e+01 |Residual Norm: 4.6135e+01 |A: -5.6843e-14|
# Iteration: 2
# |Total Norm: 2.5442e+00 |Residual Norm: 5.3314e-01 |A: 2.4877e+00|
# Iteration: 3
# |Total Norm: 1.3451e-01 |Residual Norm: 8.6866e-02 |A: 1.0269e-01|
# Iteration: 4
# |Total Norm: 1.6000e-03 |Residual Norm: 3.3330e-04 |A: 1.5649e-03|
# Iteration: 5
# |Total Norm: 1.3114e-07 |Residual Norm: 2.8455e-08 |A: 1.2801e-07|
# Iteration: 6
# |Total Norm: 1.8591e-11 |Residual Norm: 1.8591e-11 |A: 0.0000e+00|
#
# Arc-Length Step 36 :
# Iteration: 1
# |Total Norm: 4.3147e+01 |Residual Norm: 4.3147e+01 |A: 0.0000e+00|
# Iteration: 2
# |Total Norm: 2.2654e+00 |Residual Norm: 4.4314e-01 |A: 2.2216e+00|
# Iteration: 3
# |Total Norm: 2.2249e-01 |Residual Norm: 6.5269e-02 |A: 2.1270e-01|
# Iteration: 4
# |Total Norm: 2.4201e-03 |Residual Norm: 4.8789e-04 |A: 2.3704e-03|
# Iteration: 5
# |Total Norm: 1.2231e-06 |Residual Norm: 2.4926e-07 |A: 1.1974e-06|
# Iteration: 6
# |Total Norm: 2.0962e-11 |Residual Norm: 2.0961e-11 |A: 1.9895e-13|
#
# Arc-Length Step 37 :
# Iteration: 1
# |Total Norm: 4.0005e+01 |Residual Norm: 4.0005e+01 |A: 2.8422e-13|
# Iteration: 2
# |Total Norm: 2.0067e+00 |Residual Norm: 4.2313e-01 |A: 1.9615e+00|
# Iteration: 3
# |Total Norm: 2.7051e-01 |Residual Norm: 7.7172e-02 |A: 2.5927e-01|
# Iteration: 4
# |Total Norm: 1.6779e-03 |Residual Norm: 3.5865e-04 |A: 1.6391e-03|
# Iteration: 5
# |Total Norm: 1.3023e-06 |Residual Norm: 2.6985e-07 |A: 1.2740e-06|
# Iteration: 6
# |Total Norm: 2.0527e-11 |Residual Norm: 2.0527e-11 |A: 2.8422e-14|
#
# Arc-Length Step 38 :
# Iteration: 1
# |Total Norm: 3.7320e+01 |Residual Norm: 3.7320e+01 |A: -1.4211e-13|
# Iteration: 2
# |Total Norm: 1.8443e+00 |Residual Norm: 4.8955e-01 |A: 1.7781e+00|
# Iteration: 3
# |Total Norm: 2.5136e-01 |Residual Norm: 7.9652e-02 |A: 2.3841e-01|
# Iteration: 4
# |Total Norm: 9.0916e-04 |Residual Norm: 2.0962e-04 |A: 8.8467e-04|
# Iteration: 5
# |Total Norm: 6.0277e-07 |Residual Norm: 1.2701e-07 |A: 5.8924e-07|
# Iteration: 6
# |Total Norm: 2.1260e-11 |Residual Norm: 2.1260e-11 |A: 0.0000e+00|
#
# Arc-Length Step 39 :
# Iteration: 1
# |Total Norm: 3.5613e+01 |Residual Norm: 3.5613e+01 |A: -1.4211e-13|
# Iteration: 2
# |Total Norm: 1.7504e+00 |Residual Norm: 5.8489e-01 |A: 1.6498e+00|
# Iteration: 3
# |Total Norm: 2.0346e-01 |Residual Norm: 7.1220e-02 |A: 1.9059e-01|
# Iteration: 4
# |Total Norm: 5.0394e-04 |Residual Norm: 1.2631e-04 |A: 4.8786e-04|
# Iteration: 5
# |Total Norm: 2.2691e-07 |Residual Norm: 4.8871e-08 |A: 2.2158e-07|
# Iteration: 6
# |Total Norm: 2.3656e-11 |Residual Norm: 2.3656e-11 |A: -2.8422e-14|
#
# Arc-Length Step 40 :
# Iteration: 1
# |Total Norm: 3.4983e+01 |Residual Norm: 3.4983e+01 |A: -8.5265e-14|
# Iteration: 2
# |Total Norm: 1.6980e+00 |Residual Norm: 6.9680e-01 |A: 1.5485e+00|
# Iteration: 3
# |Total Norm: 1.5627e-01 |Residual Norm: 6.0959e-02 |A: 1.4389e-01|
# Iteration: 4
# |Total Norm: 3.1927e-04 |Residual Norm: 8.6744e-05 |A: 3.0726e-04|
# Iteration: 5
# |Total Norm: 9.1883e-08 |Residual Norm: 2.0410e-08 |A: 8.9588e-08|
# Iteration: 6
# |Total Norm: 2.7269e-11 |Residual Norm: 2.7269e-11 |A: 2.8422e-14|
#
# Arc-Length Step 41 :
# Iteration: 1
# |Total Norm: 3.5319e+01 |Residual Norm: 3.5319e+01 |A: 2.5580e-13|
# Iteration: 2
# |Total Norm: 1.6815e+00 |Residual Norm: 8.3932e-01 |A: 1.4570e+00|
# Iteration: 3
# |Total Norm: 1.2257e-01 |Residual Norm: 5.3570e-02 |A: 1.1025e-01|
# Iteration: 4
# |Total Norm: 2.5327e-04 |Residual Norm: 7.3731e-05 |A: 2.4230e-04|
# Iteration: 5
# |Total Norm: 4.8776e-08 |Residual Norm: 1.1298e-08 |A: 4.7450e-08|
# Iteration: 6
# |Total Norm: 2.7359e-11 |Residual Norm: 2.7359e-11 |A: -2.8422e-14|
#
# Arc-Length Step 42 :
# Iteration: 1
# |Total Norm: 3.6534e+01 |Residual Norm: 3.6534e+01 |A: 5.6843e-14|
# Iteration: 2
# |Total Norm: 1.7215e+00 |Residual Norm: 1.0450e+00 |A: 1.3680e+00|
# Iteration: 3
# |Total Norm: 1.0838e-01 |Residual Norm: 5.1387e-02 |A: 9.5424e-02|
# Iteration: 4
# |Total Norm: 2.8926e-04 |Residual Norm: 8.8884e-05 |A: 2.7526e-04|
# Iteration: 5
# |Total Norm: 4.3876e-08 |Residual Norm: 1.0722e-08 |A: 4.2545e-08|
# Iteration: 6
# |Total Norm: 2.2870e-11 |Residual Norm: 2.2870e-11 |A: 2.8422e-14|
#
# Arc-Length Step 43 :
# Iteration: 1
# |Total Norm: 3.8726e+01 |Residual Norm: 3.8726e+01 |A: 1.1369e-13|
# Iteration: 2
# |Total Norm: 1.8943e+00 |Residual Norm: 1.3849e+00 |A: 1.2924e+00|
# Iteration: 3
# |Total Norm: 1.2622e-01 |Residual Norm: 5.8019e-02 |A: 1.1210e-01|
# Iteration: 4
# |Total Norm: 5.8250e-04 |Residual Norm: 1.8682e-04 |A: 5.5173e-04|
# Iteration: 5
# |Total Norm: 9.6051e-08 |Residual Norm: 2.5049e-08 |A: 9.2728e-08|
# Iteration: 6
# |Total Norm: 1.8603e-11 |Residual Norm: 1.8603e-11 |A: -8.5265e-14|
#
# Arc-Length Step 44 :
# Iteration: 1
# |Total Norm: 4.2335e+01 |Residual Norm: 4.2335e+01 |A: -3.4106e-13|
# Iteration: 2
# |Total Norm: 2.4522e+00 |Residual Norm: 2.0487e+00 |A: 1.3477e+00|
# Iteration: 3
# |Total Norm: 2.3920e-01 |Residual Norm: 8.4841e-02 |A: 2.2365e-01|
# Iteration: 4
# |Total Norm: 2.6305e-03 |Residual Norm: 8.8207e-04 |A: 2.4782e-03|
# Iteration: 5
# |Total Norm: 7.9455e-07 |Residual Norm: 2.2531e-07 |A: 7.6194e-07|
# Iteration: 6
# |Total Norm: 2.8611e-11 |Residual Norm: 2.8611e-11 |A: 2.8422e-14|
#
# Arc-Length Step 45 :
# Iteration: 1
# |Total Norm: 4.8568e+01 |Residual Norm: 4.8568e+01 |A: -8.5265e-14|
# Iteration: 2
# |Total Norm: 4.5336e+00 |Residual Norm: 3.7242e+00 |A: 2.5854e+00|
# Iteration: 3
# |Total Norm: 9.2459e-01 |Residual Norm: 1.7722e-01 |A: 9.0744e-01|
# Iteration: 4
# |Total Norm: 3.2711e-02 |Residual Norm: 1.1802e-02 |A: 3.0508e-02|
# Iteration: 5
# |Total Norm: 3.5362e-05 |Residual Norm: 1.1494e-05 |A: 3.3441e-05|
# Iteration: 6
# |Total Norm: 3.6594e-10 |Residual Norm: 1.0660e-10 |A: 3.5007e-10|
# Iteration: 7
# |Total Norm: 2.5906e-11 |Residual Norm: 2.5906e-11 |A: 0.0000e+00|
#
# Arc-Length Step 46 :
# Iteration: 1
# |Total Norm: 6.1121e+01 |Residual Norm: 6.1121e+01 |A: -8.5265e-14|
# Iteration: 2
# |Total Norm: 2.4311e+01 |Residual Norm: 1.0453e+01 |A: 2.1948e+01|
# Iteration: 3
# |Total Norm: 1.0069e+01 |Residual Norm: 6.2584e-01 |A: 1.0050e+01|
# Iteration: 4
# |Total Norm: 1.0705e+00 |Residual Norm: 4.6269e-01 |A: 9.6537e-01|
# Iteration: 5
# |Total Norm: 6.5728e-03 |Residual Norm: 3.0212e-03 |A: 5.8373e-03|
# Iteration: 6
# |Total Norm: 4.9659e-05 |Residual Norm: 1.4534e-05 |A: 4.7485e-05|
# Iteration: 7
# |Total Norm: 2.8277e-11 |Residual Norm: 2.3949e-11 |A: 1.5035e-11|

# %% [markdown]
# ## Post Processing
# Here we plot the final deformed shape and the equilibrium path. To verify or solution, we also compare our solutions to ones found in literature.
#
# Solutions are obtained from the paper: [A simple extrapolated predictor for overcoming the starting and tracking issues in the arc-length method for nonlinear structural mechanics](https://www.sciencedirect.com/science/article/pii/S014102962034356X)

# %%
x_nodal_coord = dof_coords[x_dofs][:,0]
y_nodal_coord = dof_coords[y_dofs][:,1]
# Get nodal values 

# Plot displacement field
disp_x = x_nodal_coord + disp[-1][x_dofs]
disp_y = y_nodal_coord + disp[-1][y_dofs]



plt.scatter(x_nodal_coord,y_nodal_coord)
plt.scatter(disp_x, disp_y)

plt.xlabel('x-coordinates')
plt.ylabel('y-coordinates')
plt.axis('equal')
plt.show()

print(x_nodal_coord.shape)
# Out:
# (21,)

# %%
# get paper solution
import scipy.io
paper_soln = scipy.io.loadmat(os.getcwd()+'/examples/force_control/beam/beam_2D/lit_soln/solution_lee.mat')

# %%
plt.figure(figsize=(7,7))

plt.rcParams.update({
    "text.usetex": True,
    "font.family": 'serif',
    'font.serif': 'Times',
    'font.size' : '15'
})

plt.scatter(paper_soln['soln'][:,0],paper_soln['soln'][:,1], label = 'Kadapa 2021', facecolors = 'None', edgecolors = 'r', marker = 's', s = 70, linewidth = 2)
plt.scatter(disp_x, disp_y, marker = '.', label = 'Our implementation', s = 70, color = 'k')
plt.scatter(x_nodal_coord,y_nodal_coord,label = 'Undeformed', color = (0.4,0,0), marker = '^', s = 70)

plt.xlabel('x-coordinates')
plt.ylabel('y-coordinates')
plt.title('Beam Deformation',fontsize = 20)
#plt.axis('equal')
plt.legend(loc = 'center')

plt.savefig('deformation.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# get paper equilibrium path
paper_eq = np.loadtxt(os.getcwd()+'/examples/force_control/beam/beam_2D/lit_soln/path_lee.dat')

# Get displacment at force application
force_disp = []
for ii in range(len(disp)):
    force_disp.append(-disp[ii][force_dof])

# %%
plt.figure(figsize=(7,7))
plt.scatter(-paper_eq[:,2], paper_eq[:,0],label = 'Kadapa 2021', facecolors = 'None', edgecolors = 'r', marker = 's', s = 70, linewidth = 2)

plt.scatter(force_disp, lmbda, marker = '.', s = 70, color = 'k', label='Our Implementation')
plt.title('Equilibrium Path',fontsize = 20)
plt.ylabel('Load')
plt.xlabel('Displacement')
plt.legend()

plt.savefig('fd_curve.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Optional: Creating an animation from solution snapshots

# %%
from matplotlib import animation, rc

plt.rcParams["animation.html"] = "jshtml"

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)

ax.set_xlim([-25,150])
ax.set_ylim([-25,150])

deformed, = ax.plot([], [], lw = 7, c = 'r', label = 'Deformed Configuration', ls = 'None', marker = 'o')
init, = ax.plot(x_nodal_coord, y_nodal_coord, c='k', lw = 5, ls = 'None', label = 'Initial Configuration', marker = 'o')
ax.legend(loc = 'lower right')

def drawframe(n):
    disp_x = x_nodal_coord + disp[n][x_dofs]
    disp_y = y_nodal_coord + disp[n][y_dofs]
    
    deformed.set_data(disp_x,disp_y)
    return deformed,

plt.close()
# blit=True re-draws only the parts that have changed.
anim = animation.FuncAnimation(fig, drawframe, frames=len(lmbda), interval=40, blit=True)

anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img2e855d7822f44a32807a23fc96a0649c">
#   <div class="anim-controls">
#     <input id="_anim_slider2e855d7822f44a32807a23fc96a0649c" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim2e855d7822f44a32807a23fc96a0649c.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim2e855d7822f44a32807a23fc96a0649c.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim2e855d7822f44a32807a23fc96a0649c.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim2e855d7822f44a32807a23fc96a0649c.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim2e855d7822f44a32807a23fc96a0649c.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim2e855d7822f44a32807a23fc96a0649c.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim2e855d7822f44a32807a23fc96a0649c.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim2e855d7822f44a32807a23fc96a0649c.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim2e855d7822f44a32807a23fc96a0649c.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim2e855d7822f44a32807a23fc96a0649c.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select2e855d7822f44a32807a23fc96a0649c"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_2e855d7822f44a32807a23fc96a0649c"
#              >
#       <label for="_anim_radio1_2e855d7822f44a32807a23fc96a0649c">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_2e855d7822f44a32807a23fc96a0649c"
#              checked>
#       <label for="_anim_radio2_2e855d7822f44a32807a23fc96a0649c">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_2e855d7822f44a32807a23fc96a0649c"
#              >
#       <label for="_anim_radio3_2e855d7822f44a32807a23fc96a0649c">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img2e855d7822f44a32807a23fc96a0649c";
#     var slider_id = "_anim_slider2e855d7822f44a32807a23fc96a0649c";
#     var loop_select_id = "_anim_loop_select2e855d7822f44a32807a23fc96a0649c";
#     var frames = new Array(47);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABFnElEQ

# %%
writer = animation.PillowWriter(fps=15,
                                metadata=dict(artist='Jeffrey'),
                                bitrate=900)
anim.save('lees_frame.gif', writer=writer)
