# %% [markdown]
# # 215 degree arc
#
# The problem provided in this example is a $215^\circ$ arch with pinned-fixed boundary conditions subjected to a point load at the center of the arch. The arch is modeled with 2D geometrically exact beams (i.e. Simo-Reissner Beams). For more information on beams [see here](../README.md).
#
#
# <img src="imgs/arch_215.png" width="600">

# %%
# %matplotlib inline
from dolfin import *
import numpy as np
import matplotlib.pyplot as plt
from ufl import diag, Jacobian, shape
import os
os.chdir('../../../..') # change directory to main module directory
from arc_length.force_control_solver import force_control # import force control formulation of arc-length solver

parameters["form_compiler"]["representation"] = "uflacs"
parameters["form_compiler"]["optimize"] = True
parameters["form_compiler"]["cpp_optimize"] = True
parameters["form_compiler"]["quadrature_degree"] = 1
parameters['reorder_dofs_serial'] = False


ffc_options = {"optimize": True, \
               "eliminate_zeros": True, \
               "precompute_basis_const": True, \
               "precompute_ip_const": True}

# %% [markdown]
# ## Import Mesh and define function spaces
# In the case of 2D beams we also define the rotation matrix about the $z$ axis and directional derivative with respect to the beam centerline.

# %%
mesh_215 = Mesh()
with XDMFFile(os.getcwd()+'/examples/force_control/beam/beam_2D/mesh/215_arch2D.xdmf') as infile:
    infile.read(mesh_215)
    

Ue = VectorElement("CG", mesh_215.ufl_cell(), 1, dim=2) # displacement
Te = FiniteElement("CG", mesh_215.ufl_cell(), 1) # rotation
V = FunctionSpace(mesh_215, MixedElement([Ue, Te]))   

v_ = TestFunction(V)
u_, theta_ = split(v_)
dv = TrialFunction(V)
v = Function(V, name="Generalized displacement")
u, theta = split(v)

VR = TensorFunctionSpace(mesh_215, "DG", 0, shape=(2, 2))

V0 = FunctionSpace(mesh_215, "DG", 0)


Vu = V.sub(0).collapse()
disp = Function(Vu)

Jac = Jacobian(mesh_215)
gdim = mesh_215.geometry().dim()
Jac = as_vector([Jac[i, 0] for i in range(gdim)])
g01 = Jac/sqrt(dot(Jac, Jac))
g02 = as_vector([-g01[1],g01[0]])

r01 = outer(g01,as_vector([1,0]))
r02 = outer(g02, as_vector([0,1]))

R0 = r01+r02

#-----------------------Define Functions for beams-----------------------------------#
def tgrad(u): # directional derivative w.r.t. beam centerline
    return dot(grad(u), g01)

def rotation_matrix(theta): # 2D rotation matrix -- there is no need to do rotation parametrization for 2D beams
    return as_tensor([[cos(theta), -sin(theta)],[sin(theta), cos(theta)]])
Rot = rotation_matrix(theta)

# %% [markdown]
# ## Define Dirichlet Boundary Conditions

# %%
r = 100
arch = 215

left_theta =180+(90-(360-arch)/2)
right_theta = -(90-(360-arch)/2)

def x_coord(r,theta):
        return r*np.cos(np.deg2rad(theta))

def y_coord(r,theta):
        return r*np.sin(np.deg2rad(theta))
    
x_coord_left = x_coord(r,left_theta)
y_coord_left = y_coord(r,left_theta)
x_coord_right = x_coord(r,right_theta)
y_coord_right = y_coord(r,right_theta)

# %%
def pinned_left(x, on_boundary):
    return near(x[0], x_coord_left, 1e-6)   

def fixed_right(x, on_boundary):
    return near(x[0], x_coord_right, 1e-6)

def load_center(x, on_boundary):
    return near(x[1], r, 1e-6)

# Mark integration boundary
facets = MeshFunction("size_t", mesh_215, 0)
facets.set_all(0)
AutoSubDomain(load_center).mark(facets,1)

Pinned = DirichletBC(V.sub(0), Constant((0.0, 0.0)), pinned_left, method='pointwise') # Fixed displacement
Fixed = DirichletBC(V, Constant((0.0, 0.0, 0.0)), fixed_right, method='pointwise') # Fixed displacement and rotation
bcs = [Pinned, Fixed]

# %% [markdown]
# ## Kinematics and Weak form

# %%
# 2D beam Kinematics
defo = dot(R0.T,dot(Rot.T, g01 + tgrad(u)) - g01)
curv =  tgrad(theta)

# %%
# Geometrical properties
S = 2.29 # cross-sectional area
I = 1.0 # Area moment
J = 2.0 # Polar Moment
E = 1.0e6 # Elastic modulus
nu = 0 # Poisson's Ratio

G = E/(2*(1+nu)) # Shear Modulus
kappa = 1.0 # Shear correction

# Stiffness moduli
ES = E*S
GS = G*S
GS_2 = G*S*kappa
GS_3 = G*S*kappa
EI = E*I

# %%
# Constitutive Equations
C_N = diag(as_vector([ES, GS_2]))

# Applied Load:
F_max = Constant((0.0,-1.0))
M_max = Constant(0.0)
load = Expression("t", t=0, degree = 0)

dS = Measure("dS", domain=mesh_215, subdomain_data=facets) # Note its dS not ds -- interior facet
dx = Measure("dx", domain=mesh_215)

elastic_energy = 0.5 * (dot(defo, dot(C_N, defo)) + (EI*curv**2))*dx

F_int = derivative(elastic_energy, v, v_)
F_ext = avg(load * (-M_max*theta_ + dot(F_max, u_))) * dS(1) # avg function is used to integrte over disconticuous interior facets
residual = F_int - F_ext
tangent_form = derivative(residual, v, dv)

# %% [markdown]
# ## Solver
# To use our solver we first have to define the type of solver (i.e. displacement control or force control) and solver parameters before using the solver. Note that the correct type of solver has to first be imported (see first cell).
# ### Solver parameters
# Here the parameters for both types of solvers:
#
# >* `psi` : the scalar arc-legth parameter. When psi = 1, the method becomes the shperical arc-length method and when psi = 0 the method becomes the cylindrical arc-length method
# >* `tol` : tolerance for the linear solver
# >* `lmbda0` : the initial load parameter
# >* `max_iter` : maximum number of iterations for the linear solver
# >* `solver` : (optional): type of linear solver for the FEniCS linear solve function -- default FEniCS linear solver is used if no argument is used.
#
# Aside from these solver parameters, the arguments need to solve the FEA problem must also be passed into the solver:
# >* `u` : the solution function
# >* `F_int` : First variation of strain energy (internal nodal forces)
# >* `F_ext` : Externally applied load (external applied force)
# >* `J` : The Jacobian of the residual with respect to the deformation (tangential stiffness matrix)
# >* `load_factor` : The incremental load factor
#
# The solver can be called by:
# `solver = force_control(psi,tol,lmbda0,max_iter,u,F_int,F_ext,bcs,J,load_factor,solver)`
#
# ### Using the solver
# 1. Initialize the solver by calling solver.initialize()
# 2. Iteratively call solver.solve() until desired stopping condition

# %%
# Solver Parameters
psi = 1.0
tol = 1.0e-6
lmbda0 = 50.0
max_iter = 10
solver = 'mumps' # optional

# Set up force control arc-length solver
solver = force_control(psi=psi, tol=tol, lmbda0=lmbda0, max_iter=max_iter, u=v,
                       F_int=F_int, F_ext=F_ext, bcs=bcs, J=tangent_form, load_factor=load, solver=solver)

# %%
# Iterative solving 
disp = [v.vector()[:]]
lmbda = [0]
solver.initial_step()

for ii in range(99):
    solver.solve()
    if solver.converged: # We only want to save the solution step if the solver coverges 
        disp.append(v.vector()[:])
        lmbda.append(load.t)
# Out:
# Starting initial Force Control with Newton Method:
# Iteration 0:
# Residual error: 5.0000e+01
# Iteration 1:
# Residual error: 8.7164e+02
# Iteration 2:
# Residual error: 7.6766e+00
# Iteration 3:
# Residual error: 1.4991e+00
# Iteration 4:
# Residual error: 4.7541e-05
# Iteration 5:
# Residual error: 2.9493e-09
#
# Arc-Length Step 1 :
# Iteration: 1
# |Total Norm: 2.9493e-09 |Residual Norm: 2.9493e-09 |A: -4.5475e-13|
#
# Arc-Length Step 2 :
# Iteration: 1
# |Total Norm: 2.1210e+03 |Residual Norm: 2.1210e+03 |A: -4.5475e-13|
# Iteration: 2
# |Total Norm: 1.9729e+01 |Residual Norm: 1.9726e+01 |A: 3.5863e-01|
# Iteration: 3
# |Total Norm: 9.3217e+00 |Residual Norm: 9.0868e+00 |A: 2.0795e+00|
# Iteration: 4
# |Total Norm: 2.0805e-03 |Residual Norm: 2.0373e-03 |A: 4.2200e-04|
# Iteration: 5
# |Total Norm: 1.0529e-07 |Residual Norm: 1.0298e-07 |A: 2.1918e-08|
#
# Arc-Length Step 3 :
# Iteration: 1
# |Total Norm: 2.7079e+03 |Residual Norm: 2.7079e+03 |A: 2.1919e-08|
# Iteration: 2
# |Total Norm: 2.2988e+01 |Residual Norm: 2.2983e+01 |A: 4.6549e-01|
# Iteration: 3
# |Total Norm: 1.3520e+01 |Residual Norm: 1.3124e+01 |A: 3.2483e+00|
# Iteration: 4
# |Total Norm: 5.9263e-03 |Residual Norm: 5.8374e-03 |A: 1.0226e-03|
# Iteration: 5
# |Total Norm: 9.8712e-07 |Residual Norm: 9.6154e-07 |A: 2.2326e-07|
#
# Arc-Length Step 4 :
# Iteration: 1
# |Total Norm: 3.5206e+03 |Residual Norm: 3.5206e+03 |A: 2.2326e-07|
# Iteration: 2
# |Total Norm: 2.6965e+01 |Residual Norm: 2.6958e+01 |A: 6.2205e-01|
# Iteration: 3
# |Total Norm: 1.8936e+01 |Residual Norm: 1.8287e+01 |A: 4.9154e+00|
# Iteration: 4
# |Total Norm: 1.4918e-02 |Residual Norm: 1.4735e-02 |A: 2.3300e-03|
# Iteration: 5
# |Total Norm: 7.1139e-06 |Residual Norm: 6.8967e-06 |A: 1.7444e-06|
# Iteration: 6
# |Total Norm: 3.6050e-09 |Residual Norm: 3.6050e-09 |A: 0.0000e+00|
#
# Arc-Length Step 5 :
# Iteration: 1
# |Total Norm: 4.6449e+03 |Residual Norm: 4.6449e+03 |A: 0.0000e+00|
# Iteration: 2
# |Total Norm: 3.2055e+01 |Residual Norm: 3.2044e+01 |A: 8.5831e-01|
# Iteration: 3
# |Total Norm: 2.5121e+01 |Residual Norm: 2.4108e+01 |A: 7.0620e+00|
# Iteration: 4
# |Total Norm: 3.2443e-02 |Residual Norm: 3.2087e-02 |A: 4.7918e-03|
# Iteration: 5
# |Total Norm: 3.7471e-05 |Residual Norm: 3.6118e-05 |A: 9.9773e-06|
# Iteration: 6
# |Total Norm: 4.5253e-09 |Residual Norm: 4.5253e-09 |A: 0.0000e+00|
#
# Arc-Length Step 6 :
# Iteration: 1
# |Total Norm: 6.1719e+03 |Residual Norm: 6.1719e+03 |A: 9.0949e-13|
# Iteration: 2
# |Total Norm: 3.8743e+01 |Residual Norm: 3.8724e+01 |A: 1.2201e+00|
# Iteration: 3
# |Total Norm: 3.0747e+01 |Residual Norm: 2.9285e+01 |A: 9.3699e+00|
# Iteration: 4
# |Total Norm: 5.8359e-02 |Residual Norm: 5.7750e-02 |A: 8.4111e-03|
# Iteration: 5
# |Total Norm: 1.3111e-04 |Residual Norm: 1.2549e-04 |A: 3.7970e-05|
# Iteration: 6
# |Total Norm: 5.2361e-09 |Residual Norm: 5.2361e-09 |A: 0.0000e+00|
#
# Arc-Length Step 7 :
# Iteration: 1
# |Total Norm: 8.1579e+03 |Residual Norm: 8.1579e+03 |A: 2.2737e-12|
# Iteration: 2
# |Total Norm: 4.7240e+01 |Residual Norm: 4.7207e+01 |A: 1.7637e+00|
# Iteration: 3
# |Total Norm: 3.3683e+01 |Residual Norm: 3.1797e+01 |A: 1.1113e+01|
# Iteration: 4
# |Total Norm: 8.2232e-02 |Residual Norm: 8.1381e-02 |A: 1.1800e-02|
# Iteration: 5
# |Total Norm: 2.7098e-04 |Residual Norm: 2.5720e-04 |A: 8.5311e-05|
# Iteration: 6
# |Total Norm: 6.3008e-09 |Residual Norm: 6.3008e-09 |A: 9.0949e-13|
#
# Arc-Length Step 8 :
# Iteration: 1
# |Total Norm: 1.0562e+04 |Residual Norm: 1.0562e+04 |A: 0.0000e+00|
# Iteration: 2
# |Total Norm: 5.6970e+01 |Residual Norm: 5.6914e+01 |A: 2.5276e+00|
# Iteration: 3
# |Total Norm: 3.2160e+01 |Residual Norm: 3.0062e+01 |A: 1.1424e+01|
# Iteration: 4
# |Total Norm: 8.6039e-02 |Residual Norm: 8.5136e-02 |A: 1.2437e-02|
# Iteration: 5
# |Total Norm: 2.9619e-04 |Residual Norm: 2.7851e-04 |A: 1.0081e-04|
# Iteration: 6
# |Total Norm: 8.4869e-09 |Residual Norm: 8.4869e-09 |A: 1.8190e-12|
#
# Arc-Length Step 9 :
# Iteration: 1
# |Total Norm: 1.3197e+04 |Residual Norm: 1.3197e+04 |A: -4.5475e-13|
# Iteration: 2
# |Total Norm: 6.6540e+01 |Residual Norm: 6.6449e+01 |A: 3.4870e+00|
# Iteration: 3
# |Total Norm: 2.6413e+01 |Residual Norm: 2.4462e+01 |A: 9.9636e+00|
# Iteration: 4
# |Total Norm: 6.4323e-02 |Residual Norm: 6.3626e-02 |A: 9.4446e-03|
# Iteration: 5
# |Total Norm: 1.5906e-04 |Residual Norm: 1.4820e-04 |A: 5.7757e-05|
# Iteration: 6
# |Total Norm: 8.9893e-09 |Residual Norm: 8.9893e-09 |A: 1.3642e-12|
#
# Arc-Length Step 10 :
# Iteration: 1
# |Total Norm: 1.5770e+04 |Residual Norm: 1.5770e+04 |A: 2.2737e-12|
# Iteration: 2
# |Total Norm: 7.4474e+01 |Residual Norm: 7.4336e+01 |A: 4.5323e+00|
# Iteration: 3
# |Total Norm: 1.8754e+01 |Residual Norm: 1.7270e+01 |A: 7.3128e+00|
# Iteration: 4
# |Total Norm: 3.3902e-02 |Residual Norm: 3.3517e-02 |A: 5.0894e-03|
# Iteration: 5
# |Total Norm: 4.1234e-05 |Residual Norm: 3.8150e-05 |A: 1.5645e-05|
# Iteration: 6
# |Total Norm: 1.0807e-08 |Residual Norm: 1.0807e-08 |A: -4.5475e-13|
#
# Arc-Length Step 11 :
# Iteration: 1
# |Total Norm: 1.7991e+04 |Residual Norm: 1.7991e+04 |A: 1.8190e-12|
# Iteration: 2
# |Total Norm: 7.9979e+01 |Residual Norm: 7.9789e+01 |A: 5.5075e+00|
# Iteration: 3
# |Total Norm: 1.1721e+01 |Residual Norm: 1.0819e+01 |A: 4.5099e+00|
# Iteration: 4
# |Total Norm: 1.2683e-02 |Residual Norm: 1.2534e-02 |A: 1.9408e-03|
# Iteration: 5
# |Total Norm: 5.3014e-06 |Residual Norm: 4.8903e-06 |A: 2.0469e-06|
# Iteration: 6
# |Total Norm: 1.3409e-08 |Residual Norm: 1.3409e-08 |A: 0.0000e+00|
#
# Arc-Length Step 12 :
# Iteration: 1
# |Total Norm: 1.9686e+04 |Residual Norm: 1.9686e+04 |A: 1.8190e-12|
# Iteration: 2
# |Total Norm: 8.3047e+01 |Residual Norm: 8.2809e+01 |A: 6.2818e+00|
# Iteration: 3
# |Total Norm: 6.5959e+00 |Residual Norm: 6.1755e+00 |A: 2.3170e+00|
# Iteration: 4
# |Total Norm: 3.3833e-03 |Residual Norm: 3.3439e-03 |A: 5.1473e-04|
# Iteration: 5
# |Total Norm: 3.4560e-07 |Residual Norm: 3.1935e-07 |A: 1.3212e-07|
#
# Arc-Length Step 13 :
# Iteration: 1
# |Total Norm: 2.0817e+04 |Residual Norm: 2.0817e+04 |A: 1.3212e-07|
# Iteration: 2
# |Total Norm: 8.4144e+01 |Residual Norm: 8.3870e+01 |A: 6.7890e+00|
# Iteration: 3
# |Total Norm: 3.4450e+00 |Residual Norm: 3.3083e+00 |A: 9.6083e-01|
# Iteration: 4
# |Total Norm: 6.3383e-04 |Residual Norm: 6.2747e-04 |A: 8.9612e-05|
# Iteration: 5
# |Total Norm: 1.8051e-08 |Residual Norm: 1.7570e-08 |A: 4.1387e-09|
#
# Arc-Length Step 14 :
# Iteration: 1
# |Total Norm: 2.1441e+04 |Residual Norm: 2.1441e+04 |A: 4.1427e-09|
# Iteration: 2
# |Total Norm: 8.3941e+01 |Residual Norm: 8.3646e+01 |A: 7.0243e+00|
# Iteration: 3
# |Total Norm: 1.8800e+00 |Residual Norm: 1.8536e+00 |A: 3.1365e-01|
# Iteration: 4
# |Total Norm: 9.4344e-05 |Residual Norm: 9.3794e-05 |A: 1.0171e-05|
# Iteration: 5
# |Total Norm: 1.6380e-08 |Residual Norm: 1.6379e-08 |A: 7.5488e-11|
#
# Arc-Length Step 15 :
# Iteration: 1
# |Total Norm: 2.1663e+04 |Residual Norm: 2.1663e+04 |A: 8.5493e-11|
# Iteration: 2
# |Total Norm: 8.3227e+01 |Residual Norm: 8.2931e+01 |A: 7.0215e+00|
# Iteration: 3
# |Total Norm: 1.6610e+00 |Residual Norm: 1.6556e+00 |A: 1.3327e-01|
# Iteration: 4
# |Total Norm: 3.5556e-05 |Residual Norm: 3.5488e-05 |A: 2.1883e-06|
# Iteration: 5
# |Total Norm: 1.3769e-08 |Residual Norm: 1.3769e-08 |A: 3.6380e-12|
#
# Arc-Length Step 16 :
# Iteration: 1
# |Total Norm: 2.1608e+04 |Residual Norm: 2.1608e+04 |A: 8.1855e-12|
# Iteration: 2
# |Total Norm: 8.2916e+01 |Residual Norm: 8.2634e+01 |A: 6.8358e+00|
# Iteration: 3
# |Total Norm: 2.3598e+00 |Residual Norm: 2.3518e+00 |A: 1.9446e-01|
# Iteration: 4
# |Total Norm: 4.3755e-05 |Residual Norm: 4.3551e-05 |A: 4.2206e-06|
# Iteration: 5
# |Total Norm: 2.0440e-08 |Residual Norm: 2.0440e-08 |A: 3.6380e-12|
#
# Arc-Length Step 17 :
# Iteration: 1
# |Total Norm: 2.1417e+04 |Residual Norm: 2.1417e+04 |A: 9.0949e-12|
# Iteration: 2
# |Total Norm: 8.4100e+01 |Residual Norm: 8.3846e+01 |A: 6.5348e+00|
# Iteration: 3
# |Total Norm: 3.5850e+00 |Residual Norm: 3.5693e+00 |A: 3.3457e-01|
# Iteration: 4
# |Total Norm: 1.3634e-04 |Residual Norm: 1.3573e-04 |A: 1.2979e-05|
# Iteration: 5
# |Total Norm: 2.1947e-08 |Residual Norm: 2.1947e-08 |A: 1.2733e-11|
#
# Arc-Length Step 18 :
# Iteration: 1
# |Total Norm: 2.1260e+04 |Residual Norm: 2.1260e+04 |A: 9.0949e-12|
# Iteration: 2
# |Total Norm: 8.8182e+01 |Residual Norm: 8.7964e+01 |A: 6.1981e+00|
# Iteration: 3
# |Total Norm: 5.5198e+00 |Residual Norm: 5.4991e+00 |A: 4.7726e-01|
# Iteration: 4
# |Total Norm: 6.1423e-04 |Residual Norm: 6.1328e-04 |A: 3.4152e-05|
# Iteration: 5
# |Total Norm: 1.9633e-08 |Residual Norm: 1.9631e-08 |A: 2.9922e-10|
#
# Arc-Length Step 19 :
# Iteration: 1
# |Total Norm: 2.1369e+04 |Residual Norm: 2.1369e+04 |A: 2.9740e-10|
# Iteration: 2
# |Total Norm: 9.7222e+01 |Residual Norm: 9.7041e+01 |A: 5.9266e+00|
# Iteration: 3
# |Total Norm: 9.3950e+00 |Residual Norm: 9.3686e+00 |A: 7.0463e-01|
# Iteration: 4
# |Total Norm: 2.2011e-03 |Residual Norm: 2.1975e-03 |A: 1.2598e-04|
# Iteration: 5
# |Total Norm: 9.7097e-08 |Residual Norm: 9.6807e-08 |A: 7.5074e-09|
#
# Arc-Length Step 20 :
# Iteration: 1
# |Total Norm: 2.2127e+04 |Residual Norm: 2.2127e+04 |A: 7.5061e-09|
# Iteration: 2
# |Total Norm: 1.1496e+02 |Residual Norm: 1.1481e+02 |A: 5.8745e+00|
# Iteration: 3
# |Total Norm: 2.0923e+01 |Residual Norm: 2.0865e+01 |A: 1.5517e+00|
# Iteration: 4
# |Total Norm: 4.9522e-03 |Residual Norm: 4.8623e-03 |A: 9.3936e-04|
# Iteration: 5
# |Total Norm: 1.4741e-07 |Residual Norm: 1.4528e-07 |A: 2.4923e-08|
#
# Arc-Length Step 21 :
# Iteration: 1
# |Total Norm: 2.4293e+04 |Residual Norm: 2.4293e+04 |A: 2.4921e-08|
# Iteration: 2
# |Total Norm: 1.4996e+02 |Residual Norm: 1.4982e+02 |A: 6.3548e+00|
# Iteration: 3
# |Total Norm: 6.5457e+01 |Residual Norm: 6.5244e+01 |A: 5.2829e+00|
# Iteration: 4
# |Total Norm: 8.6427e-02 |Residual Norm: 8.5672e-02 |A: 1.1394e-02|
# Iteration: 5
# |Total Norm: 1.1813e-03 |Residual Norm: 1.1699e-03 |A: 1.6399e-04|
# Iteration: 6
# |Total Norm: 2.6183e-08 |Residual Norm: 2.6183e-08 |A: 4.5475e-12|
#
# Arc-Length Step 22 :
# Iteration: 1
# |Total Norm: 2.9795e+04 |Residual Norm: 2.9795e+04 |A: -9.0949e-12|
# Iteration: 2
# |Total Norm: 2.2701e+02 |Residual Norm: 2.2686e+02 |A: 8.2212e+00|
# Iteration: 3
# |Total Norm: 2.6332e+02 |Residual Norm: 2.6239e+02 |A: 2.2123e+01|
# Iteration: 4
# |Total Norm: 1.1136e+00 |Residual Norm: 1.1035e+00 |A: 1.4948e-01|
# Iteration: 5
# |Total Norm: 4.0326e-01 |Residual Norm: 3.9988e-01 |A: 5.2053e-02|
# Iteration: 6
# |Total Norm: 1.3966e-06 |Residual Norm: 1.3429e-06 |A: 3.8359e-07|
# Iteration: 7
# |Total Norm: 2.7681e-08 |Residual Norm: 2.7681e-08 |A: 0.0000e+00|
#
# Arc-Length Step 23 :
# Iteration: 1
# |Total Norm: 4.5147e+04 |Residual Norm: 4.5147e+04 |A: 0.0000e+00|
# Iteration: 2
# |Total Norm: 4.4606e+02 |Residual Norm: 4.4581e+02 |A: 1.4993e+01|
# Iteration: 3
# |Total Norm: 1.2914e+03 |Residual Norm: 1.2873e+03 |A: 1.0369e+02|
# Iteration: 4
# |Total Norm: 7.6766e+00 |Residual Norm: 7.0354e+00 |A: 3.0713e+00|
# Iteration: 5
# |Total Norm: 2.9492e+01 |Residual Norm: 2.9160e+01 |A: 4.4086e+00|
# Iteration: 6
# |Total Norm: 3.5891e-02 |Residual Norm: 3.5817e-02 |A: 2.3050e-03|
# Iteration: 7
# |Total Norm: 7.0098e-04 |Residual Norm: 6.9036e-04 |A: 1.2159e-04|
# Iteration: 8
# |Total Norm: 2.7544e-08 |Residual Norm: 2.7544e-08 |A: 1.8190e-12|
#
# Arc-Length Step 24 :
# Iteration: 1
# |Total Norm: 1.0137e+05 |Residual Norm: 1.0137e+05 |A: 9.0949e-13|
# Iteration: 2
# |Total Norm: 1.5449e+03 |Residual Norm: 1.5438e+03 |A: 5.7229e+01|
# Iteration: 3
# |Total Norm: 5.4545e+03 |Residual Norm: 5.4352e+03 |A: 4.5858e+02|
# Iteration: 4
# |Total Norm: 2.3817e+02 |Residual Norm: 8.5509e+01 |A: 2.2229e+02|
# Iteration: 5
# |Total Norm: 4.5485e+01 |Residual Norm: 4.2302e+01 |A: 1.6716e+01|
# Iteration: 6
# |Total Norm: 4.7627e-01 |Residual Norm: 4.7539e-01 |A: 2.8807e-02|
# Iteration: 7
# |Total Norm: 5.8756e-03 |Residual Norm: 2.9036e-03 |A: 5.1081e-03|
# Iteration: 8
# |Total Norm: 5.7322e-08 |Residual Norm: 5.6974e-08 |A: 6.3119e-09|
#
# Arc-Length Step 25 :
# Iteration: 1
# |Total Norm: 2.4140e+05 |Residual Norm: 2.4140e+05 |A: 6.3123e-09|
# Iteration: 2
# |Total Norm: 7.4635e+03 |Residual Norm: 5.3955e+03 |A: 5.1568e+03|
# Iteration: 3
# |Total Norm: 4.6509e+03 |Residual Norm: 4.3447e+03 |A: 1.6595e+03|
# Iteration: 4
# |Total Norm: 7.9982e+02 |Residual Norm: 3.4366e+02 |A: 7.2222e+02|
# Iteration: 5
# |Total Norm: 4.1375e+03 |Residual Norm: 3.6461e+03 |A: 1.9558e+03|
# Iteration: 6
# |Total Norm: 4.0463e+02 |Residual Norm: 9.7616e+01 |A: 3.9268e+02|
# Iteration: 7
# |Total Norm: 7.1484e+02 |Residual Norm: 7.1375e+02 |A: 3.9419e+01|
# Iteration: 8
# |Total Norm: 2.8292e+00 |Residual Norm: 2.8045e+00 |A: 3.7334e-01|
# Iteration: 9
# |Total Norm: 3.3809e+00 |Residual Norm: 3.3450e+00 |A: 4.9193e-01|
# Iteration: 10
# |Total Norm: 7.2058e-04 |Residual Norm: 7.2021e-04 |A: 2.3090e-05|
#
# Arc-Length Step 25 :
# Iteration: 1
# |Total Norm: 6.6015e+04 |Residual Norm: 6.6015e+04 |A: 1.5770e-09|
# Iteration: 2
# |Total Norm: 1.0401e+03 |Residual Norm: 6.4031e+02 |A: 8.1960e+02|
# Iteration: 3
# |Total Norm: 2.4155e+02 |Residual Norm: 1.4331e+02 |A: 1.9444e+02|
# Iteration: 4
# |Total Norm: 6.0630e+02 |Residual Norm: 6.0480e+02 |A: 4.2645e+01|
# Iteration: 5
# |Total Norm: 1.8339e+01 |Residual Norm: 1.8325e+01 |A: 7.1047e-01|
# Iteration: 6
# |Total Norm: 2.8268e+02 |Residual Norm: 2.8054e+02 |A: 3.4757e+01|
# Iteration: 7
# |Total Norm: 1.2370e+01 |Residual Norm: 1.0946e+01 |A: 5.7618e+00|
# Iteration: 8
# |Total Norm: 2.9246e+01 |Residual Norm: 2.8251e+01 |A: 7.5626e+00|
# Iteration: 9
# |Total Norm: 1.5302e-01 |Residual Norm: 1.4958e-01 |A: 3.2237e-02|
# Iteration: 10
# |Total Norm: 5.1552e-03 |Residual Norm: 5.0232e-03 |A: 1.1590e-03|
#
# Arc-Length Step 25 :
# Iteration: 1
# |Total Norm: 8.9483e+03 |Residual Norm: 8.9483e+03 |A: 9.8488e-11|
# Iteration: 2
# |Total Norm: 9.1139e+02 |Residual Norm: 2.2628e+02 |A: 8.8285e+02|
# Iteration: 3
# |Total Norm: 5.0036e+04 |Residual Norm: 4.9990e+04 |A: 2.1447e+03|
# Iteration: 4
# |Total Norm: 1.3839e+04 |Residual Norm: 1.3803e+03 |A: 1.3770e+04|
# Iteration: 5
# |Total Norm: 8.1557e+05 |Residual Norm: 8.1522e+05 |A: 2.3741e+04|
# Iteration: 6
# |Total Norm: 8.4064e+06 |Residual Norm: 7.5080e+04 |A: 8.4061e+06|
# Iteration: 7
# |Total Norm: 4.0253e+06 |Residual Norm: 3.4274e+06 |A: 2.1108e+06|
# Iteration: 8
# |Total Norm: 1.4000e+06 |Residual Norm: 1.2952e+06 |A: 5.3146e+05|
# Iteration: 9
# |Total Norm: 1.3729e+05 |Residual Norm: 2.8146e+04 |A: 1.3438e+05|
# Iteration: 10
# |Total Norm: 2.1361e+05 |Residual Norm: 2.1073e+05 |A: 3.4969e+04|
#
# Arc-Length Step 25 :
# Iteration: 1
# |Total Norm: 1.8689e+03 |Residual Norm: 1.8689e+03 |A: 6.1271e-12|
# Iteration: 2
# |Total Norm: 5.0828e+00 |Residual Norm: 5.0641e+00 |A: 4.3660e-01|
# Iteration: 3
# |Total Norm: 5.9475e+00 |Residual Norm: 5.2997e+00 |A: 2.6993e+00|
# Iteration: 4
# |Total Norm: 5.3195e+00 |Residual Norm: 5.3080e+00 |A: 3.4895e-01|
# Iteration: 5
# |Total Norm: 9.7896e-02 |Residual Norm: 9.7079e-02 |A: 1.2624e-02|
# Iteration: 6
# |Total Norm: 9.5520e-05 |Residual Norm: 4.6915e-05 |A: 8.3205e-05|
# Iteration: 7
# |Total Norm: 3.2610e-08 |Residual Norm: 3.2603e-08 |A: 6.7900e-10|
#
# Arc-Length Step 26 :
# Iteration: 1
# |Total Norm: 7.3364e+01 |Residual Norm: 7.3364e+01 |A: 6.7887e-10|
# Iteration: 2
# |Total Norm: 8.9900e-02 |Residual Norm: 8.9828e-02 |A: 3.6144e-03|
# Iteration: 3
# |Total Norm: 2.2797e-03 |Residual Norm: 2.1179e-03 |A: 8.4350e-04|
# Iteration: 4
# |Total Norm: 9.7863e-07 |Residual Norm: 9.7617e-07 |A: 6.9389e-08|
#
# Arc-Length Step 27 :
# Iteration: 1
# |Total Norm: 2.1918e+02 |Residual Norm: 2.1918e+02 |A: 2.7755e-07|
# Iteration: 2
# |Total Norm: 5.7245e-01 |Residual Norm: 5.7235e-01 |A: 1.0634e-02|
# Iteration: 3
# |Total Norm: 9.6389e-02 |Residual Norm: 8.9499e-02 |A: 3.5789e-02|
# Iteration: 4
# |Total Norm: 4.2264e-04 |Residual Norm: 4.2149e-04 |A: 3.1154e-05|
# Iteration: 5
# |Total Norm: 2.7864e-08 |Residual Norm: 2.7864e-08 |A: 8.5286e-11|
#
# Arc-Length Step 28 :
# Iteration: 1
# |Total Norm: 8.8742e+02 |Residual Norm: 8.8742e+02 |A: 3.4094e-10|
# Iteration: 2
# |Total Norm: 1.4129e+00 |Residual Norm: 1.4129e+00 |A: 8.0080e-03|
# Iteration: 3
# |Total Norm: 3.4231e-01 |Residual Norm: 3.2625e-01 |A: 1.0363e-01|
# Iteration: 4
# |Total Norm: 8.4127e-04 |Residual Norm: 8.3872e-04 |A: 6.5473e-05|
# Iteration: 5
# |Total Norm: 2.9419e-08 |Residual Norm: 2.9371e-08 |A: 1.6775e-09|
#
# Arc-Length Step 29 :
# Iteration: 1
# |Total Norm: 3.7624e+03 |Residual Norm: 3.7624e+03 |A: 6.7126e-09|
# Iteration: 2
# |Total Norm: 1.1319e+01 |Residual Norm: 1.1318e+01 |A: 1.6537e-01|
# Iteration: 3
# |Total Norm: 4.0048e+00 |Residual Norm: 3.8898e+00 |A: 9.5270e-01|
# Iteration: 4
# |Total Norm: 1.5971e-02 |Residual Norm: 1.5910e-02 |A: 1.3936e-03|
# Iteration: 5
# |Total Norm: 2.0736e-05 |Residual Norm: 2.0358e-05 |A: 3.9436e-06|
# Iteration: 6
# |Total Norm: 2.9616e-08 |Residual Norm: 2.9616e-08 |A: 1.4211e-13|
#
# Arc-Length Step 30 :
# Iteration: 1
# |Total Norm: 1.7552e+04 |Residual Norm: 1.7552e+04 |A: 4.4338e-12|
# Iteration: 2
# |Total Norm: 8.4898e+01 |Residual Norm: 8.4857e+01 |A: 2.6416e+00|
# Iteration: 3
# |Total Norm: 4.9698e+01 |Residual Norm: 4.9038e+01 |A: 8.0723e+00|
# Iteration: 4
# |Total Norm: 4.1715e-01 |Residual Norm: 4.1642e-01 |A: 2.4563e-02|
# Iteration: 5
# |Total Norm: 7.1417e-02 |Residual Norm: 7.0936e-02 |A: 8.2750e-03|
# Iteration: 6
# |Total Norm: 1.6297e-06 |Residual Norm: 1.6281e-06 |A: 7.2038e-08|
# Iteration: 7
# |Total Norm: 3.0942e-08 |Residual Norm: 3.0942e-08 |A: -1.1369e-13|
#
# Arc-Length Step 31 :
# Iteration: 1
# |Total Norm: 8.7084e+04 |Residual Norm: 8.7084e+04 |A: -1.4552e-11|
# Iteration: 2
# |Total Norm: 8.6011e+02 |Residual Norm: 8.5958e+02 |A: 3.0113e+01|
# Iteration: 3
# |Total Norm: 5.0802e+02 |Residual Norm: 5.0552e+02 |A: 5.0335e+01|
# Iteration: 4
# |Total Norm: 3.4628e+00 |Residual Norm: 3.4515e+00 |A: 2.7905e-01|
# Iteration: 5
# |Total Norm: 7.1546e+00 |Residual Norm: 7.1352e+00 |A: 5.2597e-01|
# Iteration: 6
# |Total Norm: 1.7574e-03 |Residual Norm: 1.7572e-03 |A: 3.0303e-05|
# Iteration: 7
# |Total Norm: 2.1458e-06 |Residual Norm: 2.1397e-06 |A: 1.6172e-07|
# Iteration: 8
# |Total Norm: 3.1286e-08 |Residual Norm: 3.1286e-08 |A: 0.0000e+00|
#
# Arc-Length Step 32 :
# Iteration: 1
# |Total Norm: 9.1066e+04 |Residual Norm: 9.1066e+04 |A: -3.1832e-12|
# Iteration: 2
# |Total Norm: 8.5337e+02 |Residual Norm: 8.5297e+02 |A: 2.6175e+01|
# Iteration: 3
# |Total Norm: 3.1832e+02 |Residual Norm: 3.1742e+02 |A: 2.4018e+01|
# Iteration: 4
# |Total Norm: 1.9095e+00 |Residual Norm: 1.9086e+00 |A: 5.6558e-02|
# Iteration: 5
# |Total Norm: 2.4840e+00 |Residual Norm: 2.4800e+00 |A: 1.4105e-01|
# Iteration: 6
# |Total Norm: 1.6501e-04 |Residual Norm: 1.6499e-04 |A: 2.3621e-06|
# Iteration: 7
# |Total Norm: 3.6772e-08 |Residual Norm: 3.6752e-08 |A: 1.2128e-09|
#
# Arc-Length Step 33 :
# Iteration: 1
# |Total Norm: 6.3846e+04 |Residual Norm: 6.3846e+04 |A: 1.2001e-09|
# Iteration: 2
# |Total Norm: 4.3912e+02 |Residual Norm: 4.3891e+02 |A: 1.3335e+01|
# Iteration: 3
# |Total Norm: 1.0589e+02 |Residual Norm: 1.0564e+02 |A: 7.2923e+00|
# Iteration: 4
# |Total Norm: 4.1402e+00 |Residual Norm: 4.1375e+00 |A: 1.5107e-01|
# Iteration: 5
# |Total Norm: 5.1976e+00 |Residual Norm: 5.1915e+00 |A: 2.5175e-01|
# Iteration: 6
# |Total Norm: 7.9734e-03 |Residual Norm: 7.9679e-03 |A: 2.9442e-04|
# Iteration: 7
# |Total Norm: 1.6263e-05 |Residual Norm: 1.6243e-05 |A: 7.9908e-07|
# Iteration: 8
# |Total Norm: 2.8482e-08 |Residual Norm: 2.8482e-08 |A: -4.5475e-13|
#
# Arc-Length Step 34 :
# Iteration: 1
# |Total Norm: 5.0661e+04 |Residual Norm: 5.0661e+04 |A: -2.7285e-12|
# Iteration: 2
# |Total Norm: 2.8349e+02 |Residual Norm: 2.8336e+02 |A: 8.5173e+00|
# Iteration: 3
# |Total Norm: 4.2359e+01 |Residual Norm: 4.2258e+01 |A: 2.9283e+00|
# Iteration: 4
# |Total Norm: 1.5828e-01 |Residual Norm: 1.5819e-01 |A: 5.3238e-03|
# Iteration: 5
# |Total Norm: 1.6725e-02 |Residual Norm: 1.6709e-02 |A: 7.2229e-04|
# Iteration: 6
# |Total Norm: 4.1679e-08 |Residual Norm: 4.1676e-08 |A: 4.6521e-10|
#
# Arc-Length Step 35 :
# Iteration: 1
# |Total Norm: 4.3295e+04 |Residual Norm: 4.3295e+04 |A: 4.6111e-10|
# Iteration: 2
# |Total Norm: 2.0932e+02 |Residual Norm: 2.0923e+02 |A: 6.2241e+00|
# Iteration: 3
# |Total Norm: 1.8360e+01 |Residual Norm: 1.8308e+01 |A: 1.3724e+00|
# Iteration: 4
# |Total Norm: 1.9069e-02 |Residual Norm: 1.9058e-02 |A: 6.2711e-04|
# Iteration: 5
# |Total Norm: 2.8499e-04 |Residual Norm: 2.8477e-04 |A: 1.1181e-05|
# Iteration: 6
# |Total Norm: 2.7956e-08 |Residual Norm: 2.7956e-08 |A: 0.0000e+00|
#
# Arc-Length Step 36 :
# Iteration: 1
# |Total Norm: 3.8870e+04 |Residual Norm: 3.8870e+04 |A: -6.3665e-12|
# Iteration: 2
# |Total Norm: 1.6883e+02 |Residual Norm: 1.6875e+02 |A: 4.9767e+00|
# Iteration: 3
# |Total Norm: 8.3354e+00 |Residual Norm: 8.3047e+00 |A: 7.1527e-01|
# Iteration: 4
# |Total Norm: 2.7970e-03 |Residual Norm: 2.7947e-03 |A: 1.1491e-04|
# Iteration: 5
# |Total Norm: 6.2639e-06 |Residual Norm: 6.2598e-06 |A: 2.2669e-07|
# Iteration: 6
# |Total Norm: 3.3028e-08 |Residual Norm: 3.3028e-08 |A: -4.5475e-13|
#
# Arc-Length Step 37 :
# Iteration: 1
# |Total Norm: 3.6170e+04 |Residual Norm: 3.6170e+04 |A: 5.4570e-12|
# Iteration: 2
# |Total Norm: 1.4516e+02 |Residual Norm: 1.4509e+02 |A: 4.2495e+00|
# Iteration: 3
# |Total Norm: 4.2778e+00 |Residual Norm: 4.2578e+00 |A: 4.1334e-01|
# Iteration: 4
# |Total Norm: 1.7209e-04 |Residual Norm: 1.7076e-04 |A: 2.1304e-05|
# Iteration: 5
# |Total Norm: 3.2306e-08 |Residual Norm: 3.2304e-08 |A: 3.5470e-10|
#
# Arc-Length Step 38 :
# Iteration: 1
# |Total Norm: 3.4612e+04 |Residual Norm: 3.4612e+04 |A: 3.4970e-10|
# Iteration: 2
# |Total Norm: 1.3126e+02 |Residual Norm: 1.3120e+02 |A: 3.8197e+00|
# Iteration: 3
# |Total Norm: 2.8353e+00 |Residual Norm: 2.8218e+00 |A: 2.7614e-01|
# Iteration: 4
# |Total Norm: 2.3900e-04 |Residual Norm: 2.3882e-04 |A: 9.3840e-06|
# Iteration: 5
# |Total Norm: 3.7412e-08 |Residual Norm: 3.7409e-08 |A: 4.7248e-10|
#
# Arc-Length Step 39 :
# Iteration: 1
# |Total Norm: 3.3903e+04 |Residual Norm: 3.3903e+04 |A: 4.7066e-10|
# Iteration: 2
# |Total Norm: 1.2390e+02 |Residual Norm: 1.2385e+02 |A: 3.5824e+00|
# Iteration: 3
# |Total Norm: 2.5774e+00 |Residual Norm: 2.5672e+00 |A: 2.2836e-01|
# Iteration: 4
# |Total Norm: 7.5988e-04 |Residual Norm: 7.5959e-04 |A: 2.0927e-05|
# Iteration: 5
# |Total Norm: 6.7664e-08 |Residual Norm: 6.7641e-08 |A: 1.7485e-09|
#
# Arc-Length Step 40 :
# Iteration: 1
# |Total Norm: 3.3901e+04 |Residual Norm: 3.3901e+04 |A: 1.7508e-09|
# Iteration: 2
# |Total Norm: 1.2163e+02 |Residual Norm: 1.2158e+02 |A: 3.4864e+00|
# Iteration: 3
# |Total Norm: 3.9943e+00 |Residual Norm: 3.9871e+00 |A: 2.3999e-01|
# Iteration: 4
# |Total Norm: 2.1299e-03 |Residual Norm: 2.1294e-03 |A: 4.7324e-05|
# Iteration: 5
# |Total Norm: 1.4254e-06 |Residual Norm: 1.4248e-06 |A: 4.1704e-08|
# Iteration: 6
# |Total Norm: 4.0525e-08 |Residual Norm: 4.0525e-08 |A: -9.0949e-13|
#
# Arc-Length Step 41 :
# Iteration: 1
# |Total Norm: 3.4559e+04 |Residual Norm: 3.4559e+04 |A: -9.0949e-12|
# Iteration: 2
# |Total Norm: 1.2403e+02 |Residual Norm: 1.2398e+02 |A: 3.5097e+00|
# Iteration: 3
# |Total Norm: 7.5214e+00 |Residual Norm: 7.5152e+00 |A: 3.0324e-01|
# Iteration: 4
# |Total Norm: 5.4359e-03 |Residual Norm: 5.4350e-03 |A: 9.8985e-05|
# Iteration: 5
# |Total Norm: 1.9945e-05 |Residual Norm: 1.9937e-05 |A: 5.5771e-07|
# Iteration: 6
# |Total Norm: 3.0169e-08 |Residual Norm: 3.0169e-08 |A: 4.5475e-13|
#
# Arc-Length Step 42 :
# Iteration: 1
# |Total Norm: 3.5907e+04 |Residual Norm: 3.5907e+04 |A: -2.2737e-12|
# Iteration: 2
# |Total Norm: 1.3148e+02 |Residual Norm: 1.3142e+02 |A: 3.6499e+00|
# Iteration: 3
# |Total Norm: 1.3557e+01 |Residual Norm: 1.3550e+01 |A: 4.2612e-01|
# Iteration: 4
# |Total Norm: 1.4047e-02 |Residual Norm: 1.4045e-02 |A: 2.1937e-04|
# Iteration: 5
# |Total Norm: 2.0526e-04 |Residual Norm: 2.0519e-04 |A: 5.5082e-06|
# Iteration: 6
# |Total Norm: 3.0697e-08 |Residual Norm: 3.0697e-08 |A: 0.0000e+00|
#
# Arc-Length Step 43 :
# Iteration: 1
# |Total Norm: 3.8055e+04 |Residual Norm: 3.8055e+04 |A: -7.7307e-12|
# Iteration: 2
# |Total Norm: 1.4523e+02 |Residual Norm: 1.4518e+02 |A: 3.9222e+00|
# Iteration: 3
# |Total Norm: 2.3428e+01 |Residual Norm: 2.3419e+01 |A: 6.3523e-01|
# Iteration: 4
# |Total Norm: 4.1184e-02 |Residual Norm: 4.1180e-02 |A: 6.0889e-04|
# Iteration: 5
# |Total Norm: 2.2378e-03 |Residual Norm: 2.2371e-03 |A: 5.7917e-05|
# Iteration: 6
# |Total Norm: 4.3328e-08 |Residual Norm: 4.3328e-08 |A: 7.2760e-12|
#
# Arc-Length Step 44 :
# Iteration: 1
# |Total Norm: 4.1219e+04 |Residual Norm: 4.1219e+04 |A: 6.3665e-12|
# Iteration: 2
# |Total Norm: 1.6791e+02 |Residual Norm: 1.6785e+02 |A: 4.3651e+00|
# Iteration: 3
# |Total Norm: 4.0042e+01 |Residual Norm: 4.0029e+01 |A: 9.8946e-01|
# Iteration: 4
# |Total Norm: 1.9178e-01 |Residual Norm: 1.9175e-01 |A: 3.2877e-03|
# Iteration: 5
# |Total Norm: 4.4537e-02 |Residual Norm: 4.4523e-02 |A: 1.1172e-03|
# Iteration: 6
# |Total Norm: 2.8961e-07 |Residual Norm: 2.8957e-07 |A: 5.0431e-09|
#
# Arc-Length Step 45 :
# Iteration: 1
# |Total Norm: 4.5787e+04 |Residual Norm: 4.5787e+04 |A: 5.0431e-09|
# Iteration: 2
# |Total Norm: 2.0459e+02 |Residual Norm: 2.0453e+02 |A: 5.0546e+00|
# Iteration: 3
# |Total Norm: 6.9716e+01 |Residual Norm: 6.9698e+01 |A: 1.6177e+00|
# Iteration: 4
# |Total Norm: 1.2046e+01 |Residual Norm: 1.2042e+01 |A: 2.9798e-01|
# Iteration: 5
# |Total Norm: 2.1253e+01 |Residual Norm: 2.1246e+01 |A: 5.2226e-01|
# Iteration: 6
# |Total Norm: 1.9226e+00 |Residual Norm: 1.9220e+00 |A: 4.7250e-02|
# Iteration: 7
# |Total Norm: 2.4866e-01 |Residual Norm: 2.4859e-01 |A: 6.0416e-03|
# Iteration: 8
# |Total Norm: 2.4744e-04 |Residual Norm: 2.4736e-04 |A: 6.0863e-06|
# Iteration: 9
# |Total Norm: 3.7667e-08 |Residual Norm: 3.7666e-08 |A: 1.0004e-10|
#
# Arc-Length Step 46 :
# Iteration: 1
# |Total Norm: 5.2458e+04 |Residual Norm: 5.2458e+04 |A: 1.0368e-10|
# Iteration: 2
# |Total Norm: 2.6553e+02 |Residual Norm: 2.6546e+02 |A: 6.1396e+00|
# Iteration: 3
# |Total Norm: 1.2735e+02 |Residual Norm: 1.2732e+02 |A: 2.8240e+00|
# Iteration: 4
# |Total Norm: 4.2392e-01 |Residual Norm: 4.2388e-01 |A: 5.5484e-03|
# Iteration: 5
# |Total Norm: 6.6654e-01 |Residual Norm: 6.6635e-01 |A: 1.6049e-02|
# Iteration: 6
# |Total Norm: 1.1601e-05 |Residual Norm: 1.1600e-05 |A: 1.5377e-07|
# Iteration: 7
# |Total Norm: 3.8258e-08 |Residual Norm: 3.8258e-08 |A: 1.2733e-11|
#
# Arc-Length Step 47 :
# Iteration: 1
# |Total Norm: 6.2560e+04 |Residual Norm: 6.2560e+04 |A: 1.3642e-11|
# Iteration: 2
# |Total Norm: 3.7329e+02 |Residual Norm: 3.7321e+02 |A: 7.9313e+00|
# Iteration: 3
# |Total Norm: 2.5260e+02 |Residual Norm: 2.5254e+02 |A: 5.4171e+00|
# Iteration: 4
# |Total Norm: 4.6659e-01 |Residual Norm: 4.6655e-01 |A: 6.1962e-03|
# Iteration: 5
# |Total Norm: 1.0908e+00 |Residual Norm: 1.0905e+00 |A: 2.6176e-02|
# Iteration: 6
# |Total Norm: 6.8814e-06 |Residual Norm: 6.8804e-06 |A: 1.1779e-07|
# Iteration: 7
# |Total Norm: 3.3617e-08 |Residual Norm: 3.3617e-08 |A: 6.3665e-12|
#
# Arc-Length Step 48 :
# Iteration: 1
# |Total Norm: 7.8839e+04 |Residual Norm: 7.8839e+04 |A: 7.2760e-12|
# Iteration: 2
# |Total Norm: 5.8416e+02 |Residual Norm: 5.8406e+02 |A: 1.1155e+01|
# Iteration: 3
# |Total Norm: 5.6834e+02 |Residual Norm: 5.6821e+02 |A: 1.1914e+01|
# Iteration: 4
# |Total Norm: 8.3688e-01 |Residual Norm: 8.3660e-01 |A: 2.1368e-02|
# Iteration: 5
# |Total Norm: 3.6126e+00 |Residual Norm: 3.6116e+00 |A: 8.8821e-02|
# Iteration: 6
# |Total Norm: 1.7743e-05 |Residual Norm: 1.7714e-05 |A: 1.0224e-06|
# Iteration: 7
# |Total Norm: 4.2814e-08 |Residual Norm: 4.2814e-08 |A: 1.8190e-11|
#
# Arc-Length Step 49 :
# Iteration: 1
# |Total Norm: 1.0768e+05 |Residual Norm: 1.0768e+05 |A: 1.8190e-11|
# Iteration: 2
# |Total Norm: 1.0652e+03 |Residual Norm: 1.0650e+03 |A: 1.7783e+01|
# Iteration: 3
# |Total Norm: 1.5166e+03 |Residual Norm: 1.5163e+03 |A: 3.1470e+01|
# Iteration: 4
# |Total Norm: 2.7538e+00 |Residual Norm: 2.7500e+00 |A: 1.4542e-01|
# Iteration: 5
# |Total Norm: 1.6473e+01 |Residual Norm: 1.6467e+01 |A: 4.4538e-01|
# Iteration: 6
# |Total Norm: 1.1577e-03 |Residual Norm: 1.1572e-03 |A: 3.5636e-05|
# Iteration: 7
# |Total Norm: 1.2795e-05 |Residual Norm: 1.2791e-05 |A: 3.3276e-07|
# Iteration: 8
# |Total Norm: 3.5775e-08 |Residual Norm: 3.5775e-08 |A: -4.5475e-13|
#
# Arc-Length Step 50 :
# Iteration: 1
# |Total Norm: 1.6624e+05 |Residual Norm: 1.6624e+05 |A: -1.3642e-12|
# Iteration: 2
# |Total Norm: 2.4416e+03 |Residual Norm: 2.4413e+03 |A: 3.4386e+01|
# Iteration: 3
# |Total Norm: 4.2653e+03 |Residual Norm: 4.2644e+03 |A: 8.9682e+01|
# Iteration: 4
# |Total Norm: 1.4715e+01 |Residual Norm: 1.4645e+01 |A: 1.4368e+00|
# Iteration: 5
# |Total Norm: 2.5703e+01 |Residual Norm: 2.5685e+01 |A: 9.8622e-01|
# Iteration: 6
# |Total Norm: 4.9367e-01 |Residual Norm: 4.9336e-01 |A: 1.7398e-02|
# Iteration: 7
# |Total Norm: 3.4496e-01 |Residual Norm: 3.4478e-01 |A: 1.1114e-02|
# Iteration: 8
# |Total Norm: 7.6192e-05 |Residual Norm: 7.6146e-05 |A: 2.6436e-06|
# Iteration: 9
# |Total Norm: 3.4719e-08 |Residual Norm: 3.4718e-08 |A: 2.8922e-10|
#
# Arc-Length Step 51 :
# Iteration: 1
# |Total Norm: 3.0628e+05 |Residual Norm: 3.0628e+05 |A: 2.9013e-10|
# Iteration: 2
# |Total Norm: 7.7680e+03 |Residual Norm: 7.7675e+03 |A: 8.8126e+01|
# Iteration: 3
# |Total Norm: 3.7142e+03 |Residual Norm: 3.7130e+03 |A: 9.4799e+01|
# Iteration: 4
# |Total Norm: 2.1182e+01 |Residual Norm: 2.1093e+01 |A: 1.9449e+00|
# Iteration: 5
# |Total Norm: 1.8003e+03 |Residual Norm: 1.7986e+03 |A: 7.6687e+01|
# Iteration: 6
# |Total Norm: 6.3164e+00 |Residual Norm: 5.6812e+00 |A: 2.7605e+00|
# Iteration: 7
# |Total Norm: 6.6435e+01 |Residual Norm: 6.6207e+01 |A: 5.4920e+00|
# Iteration: 8
# |Total Norm: 3.6919e-01 |Residual Norm: 3.6516e-01 |A: 5.4386e-02|
# Iteration: 9
# |Total Norm: 6.8926e-01 |Residual Norm: 6.8751e-01 |A: 4.9045e-02|
# Iteration: 10
# |Total Norm: 8.5304e-06 |Residual Norm: 8.3480e-06 |A: 1.7546e-06|
#
# Arc-Length Step 51 :
# Iteration: 1
# |Total Norm: 8.7121e+04 |Residual Norm: 8.7121e+04 |A: 7.2532e-11|
# Iteration: 2
# |Total Norm: 7.2391e+02 |Residual Norm: 7.2382e+02 |A: 1.1591e+01|
# Iteration: 3
# |Total Norm: 2.0955e+03 |Residual Norm: 2.0948e+03 |A: 5.6108e+01|
# Iteration: 4
# |Total Norm: 9.5433e+00 |Residual Norm: 8.4833e+00 |A: 4.3713e+00|
# Iteration: 5
# |Total Norm: 1.5261e+02 |Residual Norm: 1.5219e+02 |A: 1.1214e+01|
# Iteration: 6
# |Total Norm: 5.8578e-01 |Residual Norm: 5.4816e-01 |A: 2.0653e-01|
# Iteration: 7
# |Total Norm: 2.6581e+00 |Residual Norm: 2.6545e+00 |A: 1.3892e-01|
# Iteration: 8
# |Total Norm: 2.7635e-04 |Residual Norm: 2.7621e-04 |A: 9.0212e-06|
# Iteration: 9
# |Total Norm: 7.3026e-07 |Residual Norm: 7.2929e-07 |A: 3.7649e-08|
#
# Arc-Length Step 52 :
# Iteration: 1
# |Total Norm: 8.1948e+04 |Residual Norm: 8.1948e+04 |A: 3.7649e-08|
# Iteration: 2
# |Total Norm: 6.7766e+02 |Residual Norm: 6.7756e+02 |A: 1.1824e+01|
# Iteration: 3
# |Total Norm: 1.4455e+03 |Residual Norm: 1.4443e+03 |A: 5.8366e+01|
# Iteration: 4
# |Total Norm: 1.7223e+01 |Residual Norm: 1.0583e+01 |A: 1.3588e+01|
# Iteration: 5
# |Total Norm: 1.0651e+02 |Residual Norm: 1.0199e+02 |A: 3.0683e+01|
# Iteration: 6
# |Total Norm: 2.2719e+01 |Residual Norm: 2.1108e+01 |A: 8.4042e+00|
# Iteration: 7
# |Total Norm: 1.1619e+02 |Residual Norm: 1.1482e+02 |A: 1.7823e+01|
# Iteration: 8
# |Total Norm: 2.0681e+00 |Residual Norm: 2.0567e+00 |A: 2.1631e-01|
# Iteration: 9
# |Total Norm: 1.2045e+01 |Residual Norm: 1.1995e+01 |A: 1.0980e+00|
# Iteration: 10
# |Total Norm: 1.5071e-01 |Residual Norm: 1.5058e-01 |A: 6.2524e-03|
#
# Arc-Length Step 52 :
# Iteration: 1
# |Total Norm: 2.4861e+04 |Residual Norm: 2.4861e+04 |A: 9.4121e-09|
# Iteration: 2
# |Total Norm: 8.5868e+01 |Residual Norm: 8.5858e+01 |A: 1.3060e+00|
# Iteration: 3
# |Total Norm: 1.1722e+02 |Residual Norm: 1.1712e+02 |A: 4.7950e+00|
# Iteration: 4
# |Total Norm: 2.4839e+00 |Residual Norm: 2.3896e+00 |A: 6.7812e-01|
# Iteration: 5
# |Total Norm: 1.0372e+01 |Residual Norm: 1.0314e+01 |A: 1.0940e+00|
# Iteration: 6
# |Total Norm: 4.9935e-02 |Residual Norm: 4.9884e-02 |A: 2.2635e-03|
# Iteration: 7
# |Total Norm: 2.5356e-03 |Residual Norm: 2.5263e-03 |A: 2.1714e-04|
# Iteration: 8
# |Total Norm: 4.4010e-08 |Residual Norm: 4.4008e-08 |A: 3.5689e-10|
#
# Arc-Length Step 53 :
# Iteration: 1
# |Total Norm: 1.8627e+04 |Residual Norm: 1.8627e+04 |A: 3.5689e-10|
# Iteration: 2
# |Total Norm: 6.0131e+01 |Residual Norm: 6.0126e+01 |A: 7.8925e-01|
# Iteration: 3
# |Total Norm: 4.0217e+01 |Residual Norm: 4.0147e+01 |A: 2.3715e+00|
# Iteration: 4
# |Total Norm: 7.0874e+00 |Residual Norm: 7.0624e+00 |A: 5.9487e-01|
# Iteration: 5
# |Total Norm: 4.5474e+00 |Residual Norm: 4.5112e+00 |A: 5.7256e-01|
# Iteration: 6
# |Total Norm: 2.0718e-01 |Residual Norm: 2.0676e-01 |A: 1.3226e-02|
# Iteration: 7
# |Total Norm: 1.0536e-03 |Residual Norm: 1.0381e-03 |A: 1.8038e-04|
# Iteration: 8
# |Total Norm: 4.6443e-08 |Residual Norm: 4.6400e-08 |A: 1.9985e-09|
#
# Arc-Length Step 54 :
# Iteration: 1
# |Total Norm: 8.0779e+04 |Residual Norm: 8.0779e+04 |A: 7.9939e-09|
# Iteration: 2
# |Total Norm: 6.8287e+02 |Residual Norm: 6.8273e+02 |A: 1.3488e+01|
# Iteration: 3
# |Total Norm: 4.0510e+02 |Residual Norm: 4.0376e+02 |A: 3.3017e+01|
# Iteration: 4
# |Total Norm: 1.2444e+02 |Residual Norm: 4.5640e+01 |A: 1.1577e+02|
# Iteration: 5
# |Total Norm: 1.2117e+02 |Residual Norm: 5.3626e+01 |A: 1.0866e+02|
# Iteration: 6
# |Total Norm: 5.2567e+02 |Residual Norm: 5.1915e+02 |A: 8.2504e+01|
# Iteration: 7
# |Total Norm: 1.2415e+01 |Residual Norm: 5.8974e+00 |A: 1.0925e+01|
# Iteration: 8
# |Total Norm: 6.5989e+01 |Residual Norm: 6.4346e+01 |A: 1.4636e+01|
# Iteration: 9
# |Total Norm: 2.7609e+01 |Residual Norm: 2.7149e+01 |A: 5.0202e+00|
# Iteration: 10
# |Total Norm: 3.1282e+01 |Residual Norm: 2.9869e+01 |A: 9.2942e+00|
#
# Arc-Length Step 54 :
# Iteration: 1
# |Total Norm: 2.1077e+04 |Residual Norm: 2.1077e+04 |A: 1.9986e-09|
# Iteration: 2
# |Total Norm: 7.4365e+01 |Residual Norm: 7.4358e+01 |A: 1.0559e+00|
# Iteration: 3
# |Total Norm: 2.8742e+01 |Residual Norm: 2.8650e+01 |A: 2.2925e+00|
# Iteration: 4
# |Total Norm: 1.5243e+00 |Residual Norm: 1.5204e+00 |A: 1.0950e-01|
# Iteration: 5
# |Total Norm: 1.4559e-01 |Residual Norm: 1.3903e-01 |A: 4.3203e-02|
# Iteration: 6
# |Total Norm: 3.7782e-04 |Residual Norm: 3.7743e-04 |A: 1.7084e-05|
# Iteration: 7
# |Total Norm: 3.4206e-08 |Residual Norm: 3.4205e-08 |A: 2.9311e-10|
#
# Arc-Length Step 55 :
# Iteration: 1
# |Total Norm: 2.3072e+04 |Residual Norm: 2.3072e+04 |A: 2.9314e-10|
# Iteration: 2
# |Total Norm: 8.8257e+01 |Residual Norm: 8.8244e+01 |A: 1.4936e+00|
# Iteration: 3
# |Total Norm: 1.6513e+01 |Residual Norm: 1.6427e+01 |A: 1.6769e+00|
# Iteration: 4
# |Total Norm: 4.1620e-01 |Residual Norm: 4.1535e-01 |A: 2.6628e-02|
# Iteration: 5
# |Total Norm: 3.4984e-03 |Residual Norm: 2.2081e-03 |A: 2.7135e-03|
# Iteration: 6
# |Total Norm: 8.6055e-07 |Residual Norm: 8.6015e-07 |A: 2.6016e-08|
#
# Arc-Length Step 56 :
# Iteration: 1
# |Total Norm: 9.4500e+04 |Residual Norm: 9.4500e+04 |A: 1.0406e-07|
# Iteration: 2
# |Total Norm: 9.4959e+02 |Residual Norm: 9.4833e+02 |A: 4.8883e+01|
# Iteration: 3
# |Total Norm: 1.3711e+02 |Residual Norm: 1.3593e+02 |A: 1.7969e+01|
# Iteration: 4
# |Total Norm: 5.0153e+00 |Residual Norm: 4.1021e+00 |A: 2.8856e+00|
# Iteration: 5
# |Total Norm: 7.1572e-01 |Residual Norm: 2.5487e-01 |A: 6.6880e-01|
# Iteration: 6
# |Total Norm: 1.0148e-02 |Residual Norm: 1.0145e-02 |A: 2.1638e-04|
# Iteration: 7
# |Total Norm: 4.6094e-08 |Residual Norm: 4.0761e-08 |A: 2.1522e-08|
#
# Arc-Length Step 57 :
# Iteration: 1
# |Total Norm: 6.1891e+05 |Residual Norm: 6.1891e+05 |A: 8.6085e-08|
# Iteration: 2
# |Total Norm: 3.1053e+04 |Residual Norm: 3.1052e+04 |A: 3.0993e+02|
# Iteration: 3
# |Total Norm: 8.0954e+02 |Residual Norm: 8.0399e+02 |A: 9.4645e+01|
# Iteration: 4
# |Total Norm: 4.8261e+02 |Residual Norm: 3.8121e+02 |A: 2.9596e+02|
# Iteration: 5
# |Total Norm: 5.5165e+01 |Residual Norm: 1.6988e+01 |A: 5.2484e+01|
# Iteration: 6
# |Total Norm: 5.2239e+00 |Residual Norm: 5.1197e+00 |A: 1.0382e+00|
# Iteration: 7
# |Total Norm: 1.4603e-02 |Residual Norm: 1.4577e-02 |A: 8.7547e-04|
# Iteration: 8
# |Total Norm: 2.4205e-05 |Residual Norm: 2.1924e-05 |A: 1.0256e-05|
# Iteration: 9
# |Total Norm: 4.0011e-08 |Residual Norm: 4.0011e-08 |A: 3.1832e-12|
#
# Arc-Length Step 58 :
# Iteration: 1
# |Total Norm: 9.0231e+05 |Residual Norm: 9.0231e+05 |A: 3.1832e-12|
# Iteration: 2
# |Total Norm: 6.2019e+04 |Residual Norm: 6.2017e+04 |A: 5.2680e+02|
# Iteration: 3
# |Total Norm: 9.7332e+02 |Residual Norm: 9.7016e+02 |A: 7.8428e+01|
# Iteration: 4
# |Total Norm: 8.6251e+02 |Residual Norm: 8.4800e+02 |A: 1.5756e+02|
# Iteration: 5
# |Total Norm: 5.5740e+01 |Residual Norm: 5.4127e+01 |A: 1.3315e+01|
# Iteration: 6
# |Total Norm: 2.0340e+01 |Residual Norm: 2.0118e+01 |A: 2.9934e+00|
# Iteration: 7
# |Total Norm: 2.5687e-02 |Residual Norm: 1.7272e-02 |A: 1.9012e-02|
# Iteration: 8
# |Total Norm: 2.6885e-04 |Residual Norm: 2.5989e-04 |A: 6.8843e-05|
# Iteration: 9
# |Total Norm: 4.5647e-08 |Residual Norm: 4.5647e-08 |A: 5.0022e-12|
#
# Arc-Length Step 59 :
# Iteration: 1
# |Total Norm: 8.5922e+05 |Residual Norm: 8.5922e+05 |A: 5.4570e-12|
# Iteration: 2
# |Total Norm: 5.6600e+04 |Residual Norm: 5.6598e+04 |A: 4.9412e+02|
# Iteration: 3
# |Total Norm: 9.8059e+02 |Residual Norm: 9.7822e+02 |A: 6.8157e+01|
# Iteration: 4
# |Total Norm: 8.8227e+02 |Residual Norm: 8.7249e+02 |A: 1.3099e+02|
# Iteration: 5
# |Total Norm: 5.4731e+01 |Residual Norm: 5.3653e+01 |A: 1.0809e+01|
# Iteration: 6
# |Total Norm: 5.9486e+01 |Residual Norm: 5.9019e+01 |A: 7.4394e+00|
# Iteration: 7
# |Total Norm: 1.3192e-01 |Residual Norm: 8.9010e-02 |A: 9.7371e-02|
# Iteration: 8
# |Total Norm: 7.8714e-03 |Residual Norm: 7.6407e-03 |A: 1.8919e-03|
# Iteration: 9
# |Total Norm: 4.3969e-08 |Residual Norm: 4.3965e-08 |A: 5.7435e-10|
#
# Arc-Length Step 60 :
# Iteration: 1
# |Total Norm: 8.5411e+05 |Residual Norm: 8.5411e+05 |A: 5.7435e-10|
# Iteration: 2
# |Total Norm: 5.5930e+04 |Residual Norm: 5.5928e+04 |A: 4.9485e+02|
# Iteration: 3
# |Total Norm: 9.9961e+02 |Residual Norm: 9.9759e+02 |A: 6.3499e+01|
# Iteration: 4
# |Total Norm: 9.9072e+02 |Residual Norm: 9.7817e+02 |A: 1.5721e+02|
# Iteration: 5
# |Total Norm: 5.6676e+01 |Residual Norm: 5.4778e+01 |A: 1.4545e+01|
# Iteration: 6
# |Total Norm: 6.9986e+01 |Residual Norm: 6.9317e+01 |A: 9.6554e+00|
# Iteration: 7
# |Total Norm: 1.3862e-01 |Residual Norm: 5.2942e-02 |A: 1.2811e-01|
# Iteration: 8
# |Total Norm: 1.0224e-03 |Residual Norm: 9.4861e-04 |A: 3.8139e-04|
# Iteration: 9
# |Total Norm: 3.5102e-08 |Residual Norm: 3.5102e-08 |A: 2.0918e-11|
#
# Arc-Length Step 61 :
# Iteration: 1
# |Total Norm: 8.6023e+05 |Residual Norm: 8.6023e+05 |A: 2.1828e-11|
# Iteration: 2
# |Total Norm: 5.6640e+04 |Residual Norm: 5.6637e+04 |A: 5.0708e+02|
# Iteration: 3
# |Total Norm: 1.0220e+03 |Residual Norm: 1.0198e+03 |A: 6.7017e+01|
# Iteration: 4
# |Total Norm: 1.1690e+03 |Residual Norm: 1.1425e+03 |A: 2.4758e+02|
# Iteration: 5
# |Total Norm: 6.2350e+01 |Residual Norm: 5.5197e+01 |A: 2.8997e+01|
# Iteration: 6
# |Total Norm: 4.2679e+01 |Residual Norm: 4.1917e+01 |A: 8.0286e+00|
# Iteration: 7
# |Total Norm: 7.0869e-02 |Residual Norm: 2.4236e-02 |A: 6.6596e-02|
# Iteration: 8
# |Total Norm: 2.9535e-04 |Residual Norm: 2.9345e-04 |A: 3.3471e-05|
# Iteration: 9
# |Total Norm: 3.7814e-08 |Residual Norm: 3.7814e-08 |A: -1.8190e-12|
#
# Arc-Length Step 62 :
# Iteration: 1
# |Total Norm: 8.5449e+05 |Residual Norm: 8.5449e+05 |A: -3.6380e-12|
# Iteration: 2
# |Total Norm: 5.5895e+04 |Residual Norm: 5.5893e+04 |A: 5.1076e+02|
# Iteration: 3
# |Total Norm: 1.0518e+03 |Residual Norm: 1.0487e+03 |A: 8.0482e+01|
# Iteration: 4
# |Total Norm: 1.4030e+03 |Residual Norm: 1.3337e+03 |A: 4.3556e+02|
# Iteration: 5
# |Total Norm: 8.1466e+01 |Residual Norm: 5.3513e+01 |A: 6.1426e+01|
# Iteration: 6
# |Total Norm: 4.9188e+00 |Residual Norm: 3.8982e+00 |A: 2.9997e+00|
# Iteration: 7
# |Total Norm: 1.4635e-02 |Residual Norm: 1.4486e-02 |A: 2.0817e-03|
# Iteration: 8
# |Total Norm: 6.6359e-06 |Residual Norm: 6.5737e-06 |A: 9.0662e-07|
# Iteration: 9
# |Total Norm: 3.2231e-08 |Residual Norm: 3.2231e-08 |A: -1.3642e-12|
#
# Arc-Length Step 63 :
# Iteration: 1
# |Total Norm: 8.0848e+05 |Residual Norm: 8.0848e+05 |A: -9.0949e-13|
# Iteration: 2
# |Total Norm: 5.0350e+04 |Residual Norm: 5.0348e+04 |A: 4.7732e+02|
# Iteration: 3
# |Total Norm: 1.1380e+03 |Residual Norm: 1.1343e+03 |A: 9.1250e+01|
# Iteration: 4
# |Total Norm: 1.4110e+03 |Residual Norm: 1.3230e+03 |A: 4.9065e+02|
# Iteration: 5
# |Total Norm: 7.2692e+01 |Residual Norm: 5.2896e+01 |A: 4.9861e+01|
# Iteration: 6
# |Total Norm: 1.1608e+02 |Residual Norm: 1.1580e+02 |A: 8.0102e+00|
# Iteration: 7
# |Total Norm: 1.7146e+00 |Residual Norm: 1.7142e+00 |A: 3.6602e-02|
# Iteration: 8
# |Total Norm: 4.3388e+00 |Residual Norm: 4.3269e+00 |A: 3.2076e-01|
# Iteration: 9
# |Total Norm: 3.7616e-03 |Residual Norm: 3.7603e-03 |A: 9.8326e-05|
# Iteration: 10
# |Total Norm: 1.5373e-05 |Residual Norm: 1.5334e-05 |A: 1.0876e-06|
#
# Arc-Length Step 63 :
# Iteration: 1
# |Total Norm: 2.3088e+05 |Residual Norm: 2.3088e+05 |A: -6.8212e-13|
# Iteration: 2
# |Total Norm: 4.6285e+03 |Residual Norm: 4.6281e+03 |A: 6.4518e+01|
# Iteration: 3
# |Total Norm: 4.1800e+02 |Residual Norm: 4.1296e+02 |A: 6.4703e+01|
# Iteration: 4
# |Total Norm: 1.3069e+01 |Residual Norm: 1.2143e+01 |A: 4.8306e+00|
# Iteration: 5
# |Total Norm: 3.0706e+00 |Residual Norm: 3.0613e+00 |A: 2.3861e-01|
# Iteration: 6
# |Total Norm: 3.6282e-03 |Residual Norm: 3.6271e-03 |A: 9.1710e-05|
# Iteration: 7
# |Total Norm: 6.4182e-06 |Residual Norm: 6.3910e-06 |A: 5.9033e-07|
# Iteration: 8
# |Total Norm: 3.8155e-08 |Residual Norm: 3.8155e-08 |A: 0.0000e+00|
#
# Arc-Length Step 64 :
# Iteration: 1
# |Total Norm: 1.1048e+05 |Residual Norm: 1.1048e+05 |A: 2.2737e-13|
# Iteration: 2
# |Total Norm: 1.2733e+03 |Residual Norm: 1.2731e+03 |A: 2.1341e+01|
# Iteration: 3
# |Total Norm: 2.1410e+02 |Residual Norm: 2.1147e+02 |A: 3.3408e+01|
# Iteration: 4
# |Total Norm: 3.1203e+00 |Residual Norm: 3.0417e+00 |A: 6.9592e-01|
# Iteration: 5
# |Total Norm: 4.8529e+00 |Residual Norm: 4.8445e+00 |A: 2.8565e-01|
# Iteration: 6
# |Total Norm: 1.4709e-02 |Residual Norm: 1.4703e-02 |A: 4.2347e-04|
# Iteration: 7
# |Total Norm: 1.0508e-04 |Residual Norm: 1.0491e-04 |A: 5.9981e-06|
# Iteration: 8
# |Total Norm: 4.2203e-08 |Residual Norm: 4.2203e-08 |A: 3.4106e-13|
#
# Arc-Length Step 65 :
# Iteration: 1
# |Total Norm: 3.7930e+05 |Residual Norm: 3.7930e+05 |A: 4.5475e-13|
# Iteration: 2
# |Total Norm: 1.2550e+04 |Residual Norm: 1.2549e+04 |A: 1.5941e+02|
# Iteration: 3
# |Total Norm: 7.9190e+03 |Residual Norm: 7.8978e+03 |A: 5.7887e+02|
# Iteration: 4
# |Total Norm: 1.4159e+02 |Residual Norm: 1.3570e+02 |A: 4.0413e+01|
# Iteration: 5
# |Total Norm: 3.7551e+02 |Residual Norm: 3.7534e+02 |A: 1.1246e+01|
# Iteration: 6
# |Total Norm: 1.4096e+00 |Residual Norm: 1.4090e+00 |A: 3.9525e-02|
# Iteration: 7
# |Total Norm: 1.0154e+01 |Residual Norm: 1.0150e+01 |A: 3.0835e-01|
# Iteration: 8
# |Total Norm: 2.5807e-04 |Residual Norm: 2.5740e-04 |A: 1.8523e-05|
# Iteration: 9
# |Total Norm: 3.5858e-07 |Residual Norm: 3.5841e-07 |A: 1.1095e-08|
#
# Arc-Length Step 66 :
# Iteration: 1
# |Total Norm: 2.9910e+05 |Residual Norm: 2.9910e+05 |A: 1.1096e-08|
# Iteration: 2
# |Total Norm: 7.9225e+03 |Residual Norm: 7.9220e+03 |A: 8.8854e+01|
# Iteration: 3
# |Total Norm: 6.2948e+03 |Residual Norm: 6.2889e+03 |A: 2.7207e+02|
# Iteration: 4
# |Total Norm: 5.6634e+01 |Residual Norm: 5.5926e+01 |A: 8.9312e+00|
# Iteration: 5
# |Total Norm: 3.8017e+02 |Residual Norm: 3.8006e+02 |A: 9.4669e+00|
# Iteration: 6
# |Total Norm: 5.7765e-01 |Residual Norm: 5.7758e-01 |A: 8.8240e-03|
# Iteration: 7
# |Total Norm: 1.4057e+00 |Residual Norm: 1.4054e+00 |A: 2.9831e-02|
# Iteration: 8
# |Total Norm: 1.7811e-05 |Residual Norm: 1.7811e-05 |A: 9.4030e-08|
# Iteration: 9
# |Total Norm: 4.0946e-08 |Residual Norm: 4.0946e-08 |A: 2.9104e-11|
#
# Arc-Length Step 67 :
# Iteration: 1
# |Total Norm: 7.5493e+04 |Residual Norm: 7.5493e+04 |A: 2.9559e-11|
# Iteration: 2
# |Total Norm: 6.7729e+02 |Residual Norm: 6.7726e+02 |A: 6.6669e+00|
# Iteration: 3
# |Total Norm: 2.5015e+03 |Residual Norm: 2.5008e+03 |A: 6.0997e+01|
# Iteration: 4
# |Total Norm: 8.4217e+00 |Residual Norm: 8.4137e+00 |A: 3.6846e-01|
# Iteration: 5
# |Total Norm: 1.3422e+02 |Residual Norm: 1.3419e+02 |A: 2.5981e+00|
# Iteration: 6
# |Total Norm: 4.2581e-02 |Residual Norm: 4.2576e-02 |A: 6.6343e-04|
# Iteration: 7
# |Total Norm: 4.4814e-03 |Residual Norm: 4.4805e-03 |A: 8.5729e-05|
# Iteration: 8
# |Total Norm: 3.7984e-08 |Residual Norm: 3.7984e-08 |A: 9.0949e-13|
#
# Arc-Length Step 68 :
# Iteration: 1
# |Total Norm: 2.0410e+04 |Residual Norm: 2.0410e+04 |A: 9.0949e-13|
# Iteration: 2
# |Total Norm: 6.2303e+01 |Residual Norm: 6.2299e+01 |A: 7.1306e-01|
# Iteration: 3
# |Total Norm: 9.4260e+02 |Residual Norm: 9.4241e+02 |A: 1.8716e+01|
# Iteration: 4
# |Total Norm: 1.0234e+00 |Residual Norm: 1.0228e+00 |A: 3.4461e-02|
# Iteration: 5
# |Total Norm: 9.8124e-01 |Residual Norm: 9.8107e-01 |A: 1.8406e-02|
# Iteration: 6
# |Total Norm: 7.0787e-06 |Residual Norm: 7.0786e-06 |A: 4.0514e-08|
# Iteration: 7
# |Total Norm: 3.8104e-08 |Residual Norm: 3.8104e-08 |A: 1.8190e-12|
#
# Arc-Length Step 69 :
# Iteration: 1
# |Total Norm: 7.7202e+03 |Residual Norm: 7.7202e+03 |A: 6.3665e-12|
# Iteration: 2
# |Total Norm: 1.6202e+01 |Residual Norm: 1.6200e+01 |A: 2.3477e-01|
# Iteration: 3
# |Total Norm: 2.9089e+02 |Residual Norm: 2.9084e+02 |A: 5.5595e+00|
# Iteration: 4
# |Total Norm: 9.3849e-02 |Residual Norm: 9.3800e-02 |A: 3.0418e-03|
# Iteration: 5
# |Total Norm: 4.5324e-03 |Residual Norm: 4.5316e-03 |A: 8.4909e-05|
# Iteration: 6
# |Total Norm: 4.0252e-08 |Residual Norm: 4.0252e-08 |A: 9.0949e-13|
#
# Arc-Length Step 70 :
# Iteration: 1
# |Total Norm: 3.9168e+03 |Residual Norm: 3.9168e+03 |A: -4.0927e-12|
# Iteration: 2
# |Total Norm: 1.5227e+01 |Residual Norm: 1.5226e+01 |A: 1.5500e-01|
# Iteration: 3
# |Total Norm: 9.8422e+01 |Residual Norm: 9.8404e+01 |A: 1.8745e+00|
# Iteration: 4
# |Total Norm: 1.6948e-02 |Residual Norm: 1.6945e-02 |A: 3.4635e-04|
# Iteration: 5
# |Total Norm: 2.0945e-04 |Residual Norm: 2.0942e-04 |A: 3.9046e-06|
# Iteration: 6
# |Total Norm: 4.1452e-08 |Residual Norm: 4.1452e-08 |A: 0.0000e+00|
#
# Arc-Length Step 71 :
# Iteration: 1
# |Total Norm: 2.5291e+03 |Residual Norm: 2.5291e+03 |A: 2.7285e-12|
# Iteration: 2
# |Total Norm: 1.2881e+01 |Residual Norm: 1.2880e+01 |A: 1.3299e-01|
# Iteration: 3
# |Total Norm: 3.6698e+01 |Residual Norm: 3.6691e+01 |A: 7.1627e-01|
# Iteration: 4
# |Total Norm: 5.4801e-03 |Residual Norm: 5.4799e-03 |A: 5.3928e-05|
# Iteration: 5
# |Total Norm: 2.1364e-05 |Residual Norm: 2.1360e-05 |A: 3.9646e-07|
# Iteration: 6
# |Total Norm: 4.3336e-08 |Residual Norm: 4.3336e-08 |A: 0.0000e+00|
#
# Arc-Length Step 72 :
# Iteration: 1
# |Total Norm: 1.9442e+03 |Residual Norm: 1.9442e+03 |A: 2.7285e-12|
# Iteration: 2
# |Total Norm: 1.1170e+01 |Residual Norm: 1.1169e+01 |A: 1.2453e-01|
# Iteration: 3
# |Total Norm: 1.4595e+01 |Residual Norm: 1.4592e+01 |A: 3.0666e-01|
# Iteration: 4
# |Total Norm: 1.5890e-03 |Residual Norm: 1.5890e-03 |A: 1.1669e-05|
# Iteration: 5
# |Total Norm: 1.4468e-06 |Residual Norm: 1.4466e-06 |A: 2.6737e-08|
# Iteration: 6
# |Total Norm: 4.1388e-08 |Residual Norm: 4.1388e-08 |A: -4.5475e-13|
#
# Arc-Length Step 73 :
# Iteration: 1
# |Total Norm: 1.6542e+03 |Residual Norm: 1.6542e+03 |A: -3.6380e-12|
# Iteration: 2
# |Total Norm: 1.0028e+01 |Residual Norm: 1.0028e+01 |A: 1.1979e-01|
# Iteration: 3
# |Total Norm: 6.0672e+00 |Residual Norm: 6.0653e+00 |A: 1.4920e-01|
# Iteration: 4
# |Total Norm: 4.0404e-04 |Residual Norm: 4.0403e-04 |A: 3.1613e-06|
# Iteration: 5
# |Total Norm: 8.9959e-08 |Residual Norm: 8.9949e-08 |A: 1.3729e-09|
#
# Arc-Length Step 74 :
# Iteration: 1
# |Total Norm: 1.4816e+03 |Residual Norm: 1.4816e+03 |A: 1.3824e-09|
# Iteration: 2
# |Total Norm: 9.1790e+00 |Residual Norm: 9.1782e+00 |A: 1.1578e-01|
# Iteration: 3
# |Total Norm: 2.6271e+00 |Residual Norm: 2.6257e+00 |A: 8.4358e-02|
# Iteration: 4
# |Total Norm: 9.5784e-05 |Residual Norm: 9.5778e-05 |A: 9.9583e-07|
# Iteration: 5
# |Total Norm: 4.5698e-08 |Residual Norm: 4.5698e-08 |A: 6.1846e-11|
#
# Arc-Length Step 75 :
# Iteration: 1
# |Total Norm: 1.3609e+03 |Residual Norm: 1.3609e+03 |A: 7.7307e-11|
# Iteration: 2
# |Total Norm: 8.4773e+00 |Residual Norm: 8.4765e+00 |A: 1.1160e-01|
# Iteration: 3
# |Total Norm: 1.1960e+00 |Residual Norm: 1.1948e+00 |A: 5.5226e-02|
# Iteration: 4
# |Total Norm: 2.2245e-05 |Residual Norm: 2.2242e-05 |A: 3.7746e-07|
# Iteration: 5
# |Total Norm: 4.2666e-08 |Residual Norm: 4.2666e-08 |A: 2.7285e-12|
#
# Arc-Length Step 76 :
# Iteration: 1
# |Total Norm: 1.2663e+03 |Residual Norm: 1.2663e+03 |A: 5.0022e-12|
# Iteration: 2
# |Total Norm: 7.8616e+00 |Residual Norm: 7.8609e+00 |A: 1.0716e-01|
# Iteration: 3
# |Total Norm: 5.8339e-01 |Residual Norm: 5.8199e-01 |A: 4.0332e-02|
# Iteration: 4
# |Total Norm: 5.3318e-06 |Residual Norm: 5.3288e-06 |A: 1.7969e-07|
# Iteration: 5
# |Total Norm: 4.2093e-08 |Residual Norm: 4.2093e-08 |A: 4.5475e-13|
#
# Arc-Length Step 77 :
# Iteration: 1
# |Total Norm: 1.1868e+03 |Residual Norm: 1.1868e+03 |A: 5.9117e-12|
# Iteration: 2
# |Total Norm: 7.3037e+00 |Residual Norm: 7.3030e+00 |A: 1.0256e-01|
# Iteration: 3
# |Total Norm: 3.1281e-01 |Residual Norm: 3.1123e-01 |A: 3.1399e-02|
# Iteration: 4
# |Total Norm: 1.4355e-06 |Residual Norm: 1.4318e-06 |A: 1.0291e-07|
# Iteration: 5
# |Total Norm: 4.1888e-08 |Residual Norm: 4.1888e-08 |A: 0.0000e+00|
#
# Arc-Length Step 78 :
# Iteration: 1
# |Total Norm: 1.1170e+03 |Residual Norm: 1.1170e+03 |A: 1.3642e-12|
# Iteration: 2
# |Total Norm: 6.7883e+00 |Residual Norm: 6.7876e+00 |A: 9.7884e-02|
# Iteration: 3
# |Total Norm: 1.8867e-01 |Residual Norm: 1.8698e-01 |A: 2.5208e-02|
# Iteration: 4
# |Total Norm: 5.3345e-07 |Residual Norm: 5.2946e-07 |A: 6.5138e-08|
#
# Arc-Length Step 79 :
# Iteration: 1
# |Total Norm: 1.0544e+03 |Residual Norm: 1.0544e+03 |A: 6.5133e-08|
# Iteration: 2
# |Total Norm: 6.3063e+00 |Residual Norm: 6.3056e+00 |A: 9.3171e-02|
# Iteration: 3
# |Total Norm: 1.2803e-01 |Residual Norm: 1.2638e-01 |A: 2.0481e-02|
# Iteration: 4
# |Total Norm: 2.9484e-07 |Residual Norm: 2.9170e-07 |A: 4.2912e-08|
#
# Arc-Length Step 80 :
# Iteration: 1
# |Total Norm: 9.9731e+02 |Residual Norm: 9.9731e+02 |A: 4.2911e-08|
# Iteration: 2
# |Total Norm: 5.8524e+00 |Residual Norm: 5.8517e+00 |A: 8.8446e-02|
# Iteration: 3
# |Total Norm: 9.5071e-02 |Residual Norm: 9.3595e-02 |A: 1.6685e-02|
# Iteration: 4
# |Total Norm: 1.9023e-07 |Residual Norm: 1.8807e-07 |A: 2.8575e-08|
#
# Arc-Length Step 81 :
# Iteration: 1
# |Total Norm: 9.4486e+02 |Residual Norm: 9.4486e+02 |A: 2.8579e-08|
# Iteration: 2
# |Total Norm: 5.4235e+00 |Residual Norm: 5.4229e+00 |A: 8.3726e-02|
# Iteration: 3
# |Total Norm: 7.4556e-02 |Residual Norm: 7.3310e-02 |A: 1.3573e-02|
# Iteration: 4
# |Total Norm: 1.3749e-07 |Residual Norm: 1.3617e-07 |A: 1.9004e-08|
#
# Arc-Length Step 82 :
# Iteration: 1
# |Total Norm: 8.9640e+02 |Residual Norm: 8.9640e+02 |A: 1.9007e-08|
# Iteration: 2
# |Total Norm: 5.0183e+00 |Residual Norm: 5.0176e+00 |A: 7.9035e-02|
# Iteration: 3
# |Total Norm: 6.0152e-02 |Residual Norm: 5.9136e-02 |A: 1.1008e-02|
# Iteration: 4
# |Total Norm: 9.6309e-08 |Residual Norm: 9.5486e-08 |A: 1.2568e-08|
#
# Arc-Length Step 83 :
# Iteration: 1
# |Total Norm: 8.5145e+02 |Residual Norm: 8.5145e+02 |A: 1.2577e-08|
# Iteration: 2
# |Total Norm: 4.6360e+00 |Residual Norm: 4.6354e+00 |A: 7.4398e-02|
# Iteration: 3
# |Total Norm: 4.9190e-02 |Residual Norm: 4.8379e-02 |A: 8.8959e-03|
# Iteration: 4
# |Total Norm: 7.3560e-08 |Residual Norm: 7.3095e-08 |A: 8.2559e-09|
#
# Arc-Length Step 84 :
# Iteration: 1
# |Total Norm: 8.0966e+02 |Residual Norm: 8.0966e+02 |A: 8.2482e-09|
# Iteration: 2
# |Total Norm: 4.2763e+00 |Residual Norm: 4.2757e+00 |A: 6.9844e-02|
# Iteration: 3
# |Total Norm: 4.0462e-02 |Residual Norm: 3.9822e-02 |A: 7.1654e-03|
# Iteration: 4
# |Total Norm: 5.8489e-08 |Residual Norm: 5.8240e-08 |A: 5.3865e-09|
#
# Arc-Length Step 85 :
# Iteration: 1
# |Total Norm: 7.7072e+02 |Residual Norm: 7.7072e+02 |A: 5.4042e-09|
# Iteration: 2
# |Total Norm: 3.9391e+00 |Residual Norm: 3.9385e+00 |A: 6.5403e-02|
# Iteration: 3
# |Total Norm: 3.3355e-02 |Residual Norm: 3.2855e-02 |A: 5.7546e-03|
# Iteration: 4
# |Total Norm: 5.3900e-08 |Residual Norm: 5.3787e-08 |A: 3.4952e-09|
#
# Arc-Length Step 86 :
# Iteration: 1
# |Total Norm: 7.3438e+02 |Residual Norm: 7.3438e+02 |A: 3.4715e-09|
# Iteration: 2
# |Total Norm: 3.6239e+00 |Residual Norm: 3.6234e+00 |A: 6.1099e-02|
# Iteration: 3
# |Total Norm: 2.7509e-02 |Residual Norm: 2.7120e-02 |A: 4.6104e-03|
# Iteration: 4
# |Total Norm: 4.4797e-08 |Residual Norm: 4.4741e-08 |A: 2.2574e-09|
#
# Arc-Length Step 87 :
# Iteration: 1
# |Total Norm: 7.0042e+02 |Residual Norm: 7.0042e+02 |A: 2.2424e-09|
# Iteration: 2
# |Total Norm: 3.3304e+00 |Residual Norm: 3.3300e+00 |A: 5.6955e-02|
# Iteration: 3
# |Total Norm: 2.2683e-02 |Residual Norm: 2.2382e-02 |A: 3.6866e-03|
# Iteration: 4
# |Total Norm: 5.1908e-08 |Residual Norm: 5.1888e-08 |A: 1.4516e-09|
#
# Arc-Length Step 88 :
# Iteration: 1
# |Total Norm: 6.6865e+02 |Residual Norm: 6.6865e+02 |A: 1.4375e-09|
# Iteration: 2
# |Total Norm: 3.0581e+00 |Residual Norm: 3.0576e+00 |A: 5.2989e-02|
# Iteration: 3
# |Total Norm: 1.8697e-02 |Residual Norm: 1.8463e-02 |A: 2.9438e-03|
# Iteration: 4
# |Total Norm: 5.0686e-08 |Residual Norm: 5.0677e-08 |A: 9.3087e-10|
#
# Arc-Length Step 89 :
# Iteration: 1
# |Total Norm: 6.3888e+02 |Residual Norm: 6.3888e+02 |A: 9.2905e-10|
# Iteration: 2
# |Total Norm: 2.8060e+00 |Residual Norm: 2.8055e+00 |A: 4.9215e-02|
# Iteration: 3
# |Total Norm: 1.5406e-02 |Residual Norm: 1.5226e-02 |A: 2.3486e-03|
# Iteration: 4
# |Total Norm: 4.7270e-08 |Residual Norm: 4.7266e-08 |A: 5.9617e-10|
#
# Arc-Length Step 90 :
# Iteration: 1
# |Total Norm: 6.1096e+02 |Residual Norm: 6.1096e+02 |A: 6.1937e-10|
# Iteration: 2
# |Total Norm: 2.5733e+00 |Residual Norm: 2.5729e+00 |A: 4.5640e-02|
# Iteration: 3
# |Total Norm: 1.2692e-02 |Residual Norm: 1.2553e-02 |A: 1.8728e-03|
# Iteration: 4
# |Total Norm: 5.9553e-08 |Residual Norm: 5.9552e-08 |A: 3.8108e-10|
#
# Arc-Length Step 91 :
# Iteration: 1
# |Total Norm: 5.8475e+02 |Residual Norm: 5.8475e+02 |A: 3.7016e-10|
# Iteration: 2
# |Total Norm: 2.3592e+00 |Residual Norm: 2.3588e+00 |A: 4.2271e-02|
# Iteration: 3
# |Total Norm: 1.0458e-02 |Residual Norm: 1.0351e-02 |A: 1.4934e-03|
# Iteration: 4
# |Total Norm: 3.9692e-08 |Residual Norm: 3.9691e-08 |A: 2.4284e-10|
#
# Arc-Length Step 92 :
# Iteration: 1
# |Total Norm: 5.6012e+02 |Residual Norm: 5.6012e+02 |A: 2.5375e-10|
# Iteration: 2
# |Total Norm: 2.1624e+00 |Residual Norm: 2.1620e+00 |A: 3.9107e-02|
# Iteration: 3
# |Total Norm: 8.6215e-03 |Residual Norm: 8.5388e-03 |A: 1.1912e-03|
# Iteration: 4
# |Total Norm: 4.1384e-08 |Residual Norm: 4.1384e-08 |A: 1.5643e-10|

# %% [markdown]
# ## Post Processing
# Here we plot the final deformed shape and the equilibrium path. To verify or solution, we also compare our solutions to ones found in literature.
#
# Solutions are obtained from the paper: [A simple extrapolated predictor for overcoming the starting and tracking issues in the arc-length method for nonlinear structural mechanics](https://www.sciencedirect.com/science/article/pii/S014102962034356X)

# %%
# Get dof coordinates:
x_dofs = V.sub(0).sub(0).dofmap().dofs()
y_dofs = V.sub(0).sub(1).dofmap().dofs()
theta_dofs = V.sub(1).dofmap().dofs()
dofs = V.tabulate_dof_coordinates()
dof_coords = dofs.reshape((-1, 2))

eps = 1e-5
dof = []
# Identify y-dof at the center of the arch for force application
for ii in y_dofs:
    if abs(dof_coords[ii,0]) <= eps:
        force_dof = ii

# %%
# Get nodal values 
x_nodal_coord = dof_coords[x_dofs][:,0]
y_nodal_coord = dof_coords[y_dofs][:,1]

# Plot displacement field
disp_x = x_nodal_coord + disp[-1][x_dofs]
disp_y = y_nodal_coord + disp[-1][y_dofs]

plt.figure(figsize=(7,7))
plt.plot(x_nodal_coord,y_nodal_coord, c = 'r', lw = 5, label = 'Initial Configuration')
plt.plot(disp_x, disp_y, c = 'k', lw = 5, label = 'Deformed Configuration')

plt.xlabel('x-coordinates')
plt.ylabel('y-coordinates')
plt.axis('equal')
plt.legend()
plt.show()

# %%
# Get displacment at force application
force_disp = []
for ii in range(len(disp)):
    force_disp.append(disp[ii][force_dof])
# Normalize values
displacement_normalized = -np.array(force_disp)/r


lamda_normalized = (np.array(lmbda)*r**2)/EI

plt.figure(figsize=(7,7))
plt.plot(displacement_normalized, lamda_normalized, c = 'k', marker = 'o')
plt.title('Equilibrium Path')
plt.ylabel('Normalized Load')
plt.xlabel('Normalized Displacement')
# Out:
# Text(0.5, 0, 'Normalized Displacement')

# %%
# get paper solution
import scipy.io
paper_soln = scipy.io.loadmat(os.getcwd()+'/examples/force_control/beam/beam_2D/lit_soln/solution_215.mat')

# %%
plt.figure(figsize=(7,7))
plt.scatter(paper_soln['soln'][:,0],paper_soln['soln'][:,1], label = 'Paper implementation', facecolors = 'None', edgecolors = 'r', marker = 's')
plt.scatter(disp_x, disp_y, marker = '.', label = 'Our implementation')
plt.plot(x_nodal_coord,y_nodal_coord,label = 'Undeformed', color = 'k')

plt.xlabel('x-coordinates')
plt.ylabel('y-coordinates')
plt.title('Beam Deformation')
plt.axis('equal')
plt.legend()
plt.show()

# %%
# get paper equilibrium path
paper_eq = np.loadtxt(os.getcwd()+'/examples/force_control/beam/beam_2D/lit_soln/path_215.dat')

# %%
plt.figure(figsize=(7,7))
plt.scatter(-paper_eq[:,2]/r, paper_eq[:,0]*r**2/EI, label = 'Paper implementation', facecolors = 'None', edgecolors = 'r', marker = 's')

plt.scatter(displacement_normalized, lamda_normalized, marker = '.', label = 'Our Implementation')
plt.title('Equilibrium Path (215 degree arch 2D)')
plt.ylabel('Normalized Load')
plt.xlabel('Normalized Y-Displacement')
plt.legend()

idx = np.where(displacement_normalized<1.5)

print('buckling load:',np.max(lamda_normalized[idx]))
print('Error:',(np.max(lamda_normalized[idx]) - 8.97)/8.97)
# Out:
# buckling load: 8.963047469772224
# Error: -0.0007750869819148741

# %% [markdown]
# ## Optional: Creating an animation from solution snapshots

# %%
from matplotlib import animation, rc

plt.rcParams["animation.html"] = "jshtml"

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)

ax.set_xlim([-150,150])
ax.set_ylim([-150,150])

deformed, = ax.plot([], [], lw = 7, c = 'r', label = 'Deformed Configuration')
init, = ax.plot(x_nodal_coord, y_nodal_coord, c='k', lw = 5, ls = ':', label = 'Initial Configuration')
ax.legend(loc = 'lower right')

def drawframe(n):
    disp_x = x_nodal_coord + disp[n][x_dofs]
    disp_y = y_nodal_coord + disp[n][y_dofs]
    
    deformed.set_data(disp_x,disp_y)
    return deformed,

plt.close()
# Note: blit=True re-draws only the parts that have changed.
anim = animation.FuncAnimation(fig, drawframe, frames=len(lmbda), interval=40, blit=True)

anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgd59db9c2571645df8047dc03bd272430">
#   <div class="anim-controls">
#     <input id="_anim_sliderd59db9c2571645df8047dc03bd272430" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animd59db9c2571645df8047dc03bd272430.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animd59db9c2571645df8047dc03bd272430.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animd59db9c2571645df8047dc03bd272430.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animd59db9c2571645df8047dc03bd272430.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animd59db9c2571645df8047dc03bd272430.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animd59db9c2571645df8047dc03bd272430.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animd59db9c2571645df8047dc03bd272430.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animd59db9c2571645df8047dc03bd272430.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animd59db9c2571645df8047dc03bd272430.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animd59db9c2571645df8047dc03bd272430.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectd59db9c2571645df8047dc03bd272430" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_d59db9c2571645df8047dc03bd272430"
#              >
#       <label for="_anim_radio1_d59db9c2571645df8047dc03bd272430">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_d59db9c2571645df8047dc03bd272430"
#              checked>
#       <label for="_anim_radio2_d59db9c2571645df8047dc03bd272430">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_d59db9c2571645df8047dc03bd272430"
#              >
#       <label for="_anim_radio3_d59db9c2571645df8047dc03bd272430">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgd59db9c2571645df8047dc03bd272430";
#     var slider_id = "_anim_sliderd59db9c2571645df8047dc03bd272430";
#     var loop_select_id = "_anim_loop_selectd59db9c2571645df8047dc03bd272430";
#     var frames = new Array(93);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy8li6FKAAAgAElEQVR4nOzdeXxTVf7/8Ve6UHZkay0UZCkWaCkV\
# yiqy72gZGHYUkMEOuIsbOl8V/Q0DiOLKgHVQ0EFBVBYVcBlBQMFStCN7GQShpZSKUPa2tPf3x4XY\
# JQkgbZLevJ+PRx6Qe27STwPJO/fcc8+xGYZhICIiIpbi5+kCREREpOQp4EVERCxIAS8iImJBCngR\
# ERELUsCLiIhYkAJeRETEghTwIiIiFqSAFxERsSAFvIiIiAUp4EVERCxIAS8iImJBCngRERELUsCL\
# iIhYkAJeRETEghTwIiIiFqSAFxERsSAFvIiIiAUp4EVERCxIAS8iImJBCngRERELUsCLiIhYkAJe\
# RETEghTwIiIiFqSAFxERsSAFvIiIiAUp4EVERCxIAS8iImJBCngRERELUsCLiIhYkAJeRETEghTw\
# IiIiFqSAFxERsSAFvIiIiAUp4E
